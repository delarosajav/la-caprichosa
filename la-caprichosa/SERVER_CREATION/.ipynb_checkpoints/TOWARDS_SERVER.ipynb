# %%
# !pip install stanza
import stanza
import sqlite3
# Out:
# Collecting stanza
#   Downloading stanza-1.10.1-py3-none-any.whl.metadata (13 kB)
# Collecting emoji (from stanza)
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from stanza) (2.0.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (5.29.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from stanza) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from stanza) (3.4.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stanza) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (4.13.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.3.0->stanza)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3.0->stanza) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3.0->stanza) (3.0.2)
# Downloading stanza-1.10.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 73.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 66.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.8 MB/s eta 0:00:00
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 40.0 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, emoji, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stanza
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed emoji-2.14.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stanza-1.10.1

# %%
con = sqlite3.connect("proyectoPura.db")
cur = con.cursor()

query = """
SELECT Título_Obra FROM OBRAS
UNION ALL
SELECT Título_Complemento FROM COMPLEMENTOS
UNION ALL
SELECT Título_Sección FROM SECCIONES_PUBLICADAS
"""

cur.execute(query)
titles = cur.fetchall()
#print(titles)

titles_list = []
for title in titles:
  if title[0] is not None:
    titles_list.append(title[0])
  if title[0] is None:
    titles_list.append("NULL") #we take into account "NULL" titles, to keep the same structure as original DB.
print(titles_list)

con.close()
# Out:
# ['Al Sr. D. R. P. Enviándole mis obras', 'La mujer piadosa (Fragmentos)', 'Desvarío', 'Soneto. "¡Gloria y pobreza! El inmortal Quintana..."', 'Balada. La despedida de una hija', 'Un viaje a la Luna. Prólogo: La pesadilla de Mocquet', 'En el álbum de la señora M…', 'La primavera', 'La perejilera', 'Un viaje a la Luna. (Continuación)', 'Al señor Don B. M.', 'A orillas del Manzanares. La súplica', 'Un viaje a la Luna. (Continuación)', 'Fragmentos de la Rosa de Alejandra', 'Gente morena', 'Un viaje a la Luna. (Continuación)', 'Al excmo. Sr. D. Agustín Esteban Collantes, en el día de su santo', 'A la niña Margarita Aurora de Wilson y Serrano, el día de su cumpleaños', 'Costumbres del siglo XIX. I', 'Margarita. Novela bretona', 'Los escondidos y la tapada. Fragmentos', 'A mi apreciable amiga la Señora doña M. Del Pilar Sinués de Marco en su álbum', 'Costumbres del siglo XIX.II', 'Margarita. Novela bretona. (Continuación)', 'A la niña Margarita Aurora de Wilson y Serrano', 'A María', 'A su Alteza Real el Príncipe de Asturias', 'Margarita. Novela bretona. (Conclusión)', 'El otoño', 'Soneto. "Aún eco tienen en el alma mía..."', 'Atentado contra SS. MM. II.', '"El matrimonio de la Princesa real de Inglaterra [...]"- "Hace algunos años que un banquero muy rico [...]"-"Varios periódicos franceses y del extranjero [...]"', 'A la Poesía. Oda', 'A mi buen amigo el distinguido escritor don Alejandro Dumas en prueba de sincera amistad', 'A la luna. Soneto', 'Las apariencias engañan. Historia-cuento', '"El viaje de SS. AA. [...]"-"El sábado a la una [...]"-"El príncipe Mirza-Ally-Kan-Bahadoor [...]"-"Habláse mucho en los círculos aristocrático de un matrimonio [...]"', 'El invierno', 'La hada azul', '"El lunes 5 del corriente se ha inaugurado [...]"-"Vamos a contar una historia ocurrida en estos días de Pascua"-"Cuando Ismail, generalísimo del ejército otomano [...]"', 'El navío Leviatán', 'Ayes del corazón', 'Carta de M. de Lamartine', 'Introducción', 'Isabel II', 'Hamlet', '"Lo que cada lector pide [...]"-La trata de blancas-De la decadencia de las costumbres-"La Malibran recibía en Londres [...]"-"El gobierno del Brasil [...]"', '"Consignamos la acarta original qu enos ha dirigido M. de Lamartine [...]"', 'Porvenir de la raza latina y de la Francia en el Nuevo-Mundo. Introducción', 'Confederación Argentina y república del Uruguay-Le Paraguay', 'S. M. La emperatriz de los franceses', 'Cursos familiares de literatura. La pintura', 'El perro de Zurbarán', 'Serenatas. Introducción. (Fragmentos)', 'Lo que viene a ser un periodista inglés-"Ha sucedido en los alrededores de Filadelfia [...]"-Máximas', 'Recuerdo. Un baile en el hotel de Ville, en 1859', 'Abertura del Paraguay y de los ríos', 'La Escma. Sra. Dª Gertrudis Gómez de Avellaneda', 'El 20 de marzo', 'Cursos familiares de literatura. Leopoldo Robert', 'Leyenda pastoral', 'La dalia', '"Leemos en el Monitor  [...]"-"Según el \'Anuario diplomático de 1859\' [...]"-"Hace algunas semanas que los diarios del Alto y del Bajo Rin [...]"-"He aquí la siguiente anécdota [...]"-"Un curioso ha dicho [...]"-"El matrimonio del hijo mayor [...]"-Savonnette a vilain', 'Carta de Ramón de la Sagra', 'Artículo I. Los Estados-Unidos y el Paraguay', 'Costumbres andaluzas. Los dos marineros', 'Viaje por un vestido de boda', 'SS. AA. II el príncipe y la princesa Napoleón', 'El miércoles de ceniza', 'Cursos familiares de literatura. Leopoldo Robert. (Conclusión)', '"Pues que en nuestros días se hacen tantos adelantos en la fotografía [...]"-"Acaba de llegar de San Petesburgo [...]"-"El Entreacto publica un acarta fechada en Génova [...]"', 'Memorándum especial por la guerra de Italia', 'Introducción', 'Pbro. D. Félix Varela', 'Las flores de mayo', 'A la catedral de Bron', 'NULL', 'Viaje al rededpr de un vestido de boda. (Conclusiones)', 'Artículo II. Los Estados-Unidos y el Paraguay', 'Una de tantas', '"Para que se vea cómo los principales intereses y amortización de la Deuda pública [...]"', 'Carta de M. Alejandro ...

# %%
#we start complete formatting before NER:

import re

def subtitle_format(matchobj):
  match = matchobj.group(0)
  if re.fullmatch(r'\s*"\s*-\s*', match):
    return '" | '
  elif re.fullmatch(r'\s*-\s*"\s*', match):
    return ' | "'
  elif re.fullmatch(r'\s*-\s*"\s*-\s*', match):
    return '" | '
  elif re.fullmatch(r'\s*\[\.\.\.\]\s*"\s*-\s*', match):
    submatch = re.fullmatch(r'(\s*)\[\.\.\.\]\s*"\s*-\s*', match)
    return submatch.group(1)+'[...]" | '

def formatting_subtitles(text):
    subtit_re = r'\s*"\s*-\s*|\s*-\s*"\s*|\s*-\s*"\s*-\s*|\s*\[\.\.\.\]\s*"\s*-\s*'
    new_text = re.sub(subtit_re, subtitle_format, text)
    return new_text

def formatting_century(text):
  re_century_1 = r'(siglo|siglos)\s*(I|II|III|IV|V|VI|VII|VIII|IX|X|XI|XII|XIII|XIV|XV|XVI|XVII|XVIII|XIX|XX|XXI)\.\s*'
  re_century_2 = r'(siglo|siglos)\s*(I|II|III|IV|V|VI|VII|VIII|IX|X|XI|XII|XIII|XIV|XV|XVI|XVII|XVIII|XIX|XX|XXI)\s+\.'
  if re.search(re_century_1, text):
    return re.sub(re_century_1, r'[("\1 \2", "DATE")] ', text).strip()
  if re.search(re_century_2, text):
    return re.sub(re_century_2, r'[("\1 \2", "DATE")]', text).strip()
  else:
    return text

encontrar_subtit = [formatting_subtitles(row) for row in titles_list]
list_titsub = [row for row in encontrar_subtit if " | " in row]

#only this exceptions do not adjust to pattern (2 rows):
excepcion_1 = """Piquer-Oda "Alzad vuestras"""
excepcion_2 = """Matrimonios por anuncios-Los baños de Biarritz"""
def subadhoc(matchobj):
  return ' "'+ matchobj.group(0)[1:]
for i, row in enumerate(encontrar_subtit):
  if excepcion_1 in row:
    encontrar_subtit[i] = row.replace('Piquer-Oda "Alzad', 'Piquer-Oda. "Alzad') #Mismo formato que algunos sonetos.
  if excepcion_2 in row:
    encontrar_subtit[i]= row.replace('-', ' | ')
    #encontrar_subtit[i] = re.sub(r'[^|]+\]"', subadhoc, encontrar_subtit[i])##N: añadido mío (con la definición de subadhoc)
#print(encontrar_subtit[249])
#print(encontrar_subtit[207])

encontrar_century = [formatting_century(row).strip() for row in encontrar_subtit]

encontrar_century[:30]
# Out:
# ['Al Sr. D. R. P. Enviándole mis obras',
#  'La mujer piadosa (Fragmentos)',
#  'Desvarío',
#  'Soneto. "¡Gloria y pobreza! El inmortal Quintana..."',
#  'Balada. La despedida de una hija',
#  'Un viaje a la Luna. Prólogo: La pesadilla de Mocquet',
#  'En el álbum de la señora M…',
#  'La primavera',
#  'La perejilera',
#  'Un viaje a la Luna. (Continuación)',
#  'Al señor Don B. M.',
#  'A orillas del Manzanares. La súplica',
#  'Un viaje a la Luna. (Continuación)',
#  'Fragmentos de la Rosa de Alejandra',
#  'Gente morena',
#  'Un viaje a la Luna. (Continuación)',
#  'Al excmo. Sr. D. Agustín Esteban Collantes, en el día de su santo',
#  'A la niña Margarita Aurora de Wilson y Serrano, el día de su cumpleaños',
#  'Costumbres del [("siglo XIX", "DATE")] I',
#  'Margarita. Novela bretona',
#  'Los escondidos y la tapada. Fragmentos',
#  'A mi apreciable amiga la Señora doña M. Del Pilar Sinués de Marco en su álbum',
#  'Costumbres del [("siglo XIX", "DATE")] II',
#  'Margarita. Novela bretona. (Continuación)',
#  'A la niña Margarita Aurora de Wilson y Serrano',
#  'A María',
#  'A su Alteza Real el Príncipe de Asturias',
#  'Margarita. Novela bretona. (Conclusión)',
#  'El otoño',
#  'Soneto. "Aún eco tienen en el alma mía..."']

# %%
#we continue preparing each title to process it through model (ner)

#def clean_per_title(title):
  #cleaned_text = re.sub(
    #r'\s*\(\s*(Continuación|Fragmentos?|Conclusión|Conclusiones?|Conclusion)\.?\s*\)\s*', #not now, mayber after processing
    #' ',
    #title)
  #cleaned_text = re.sub(r'\s*"\s*|\s*\[\s*\.\s*\.\s*\.\s*\]\s*|\s*\[\s*\u2026\s*\]\s*', ' ', cleaned_text)
  #return cleaned_text.strip()

#cleaned_rows = [clean_per_title(row) for row in encontrar_subtit]

#print(cleaned_rows)
titles_to_NER = [row.split(" | ") if " | " in row else [row] for row in encontrar_century]

for row in titles_to_NER[:30]:
  print(row, "\n")
# Out:
# ['Al Sr. D. R. P. Enviándole mis obras']
#
# ['La mujer piadosa (Fragmentos)']
#
# ['Desvarío']
#
# ['Soneto. "¡Gloria y pobreza! El inmortal Quintana..."']
#
# ['Balada. La despedida de una hija']
#
# ['Un viaje a la Luna. Prólogo: La pesadilla de Mocquet']
#
# ['En el álbum de la señora M…']
#
# ['La primavera']
#
# ['La perejilera']
#
# ['Un viaje a la Luna. (Continuación)']
#
# ['Al señor Don B. M.']
#
# ['A orillas del Manzanares. La súplica']
#
# ['Un viaje a la Luna. (Continuación)']
#
# ['Fragmentos de la Rosa de Alejandra']
#
# ['Gente morena']
#
# ['Un viaje a la Luna. (Continuación)']
#
# ['Al excmo. Sr. D. Agustín Esteban Collantes, en el día de su santo']
#
# ['A la niña Margarita Aurora de Wilson y Serrano, el día de su cumpleaños']
#
# ['Costumbres del [("siglo XIX", "DATE")] I']
#
# ['Margarita. Novela bretona']
#
# ['Los escondidos y la tapada. Fragmentos']
#
# ['A mi apreciable amiga la Señora doña M. Del Pilar Sinués de Marco en su álbum']
#
# ['Costumbres del [("siglo XIX", "DATE")] II']
#
# ['Margarita. Novela bretona. (Continuación)']
#
# ['A la niña Margarita Aurora de Wilson y Serrano']
#
# ['A María']
#
# ['A su Alteza Real el Príncipe de Asturias']
#
# ['Margarita. Novela bretona. (Conclusión)']
#
# ['El otoño']
#
# ['Soneto. "Aún eco tienen en el alma mía..."']

# %%
#first processing, we extract NER
def processing_1(text, nlp_model):
  doc = nlp_model(text)
  if text == "NULL":
    return [("NULL")]
  if "[(" not in text:
    return [(ent.text, ent.type) for ent in doc.entities]
  if "[(" in text:
    special_categories = re.findall(r'\[\(.*\)\]', text)
    parsing_text = re.split(r'\[\(.*\)\]', text)
    exception = []
    for part in parsing_text:
      if part.startswith("[(") and part.endswith(")]"):
        exception.append(part)
      else:
        doc = nlp_model(part)
        exception.extend([(ent.text, ent.type) for ent in doc.entities])
    return exception

nlp_es = stanza.Pipeline(lang="es", processors="tokenize,mwt,pos,lemma,ner,depparse")

processed_ent_es = [[processing_1(el, nlp_es) for el in lista] for lista in titles_to_NER]

for element in processed_ent_es:
  print(element, "\n")
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.10.0/models/tokenize/combined.pt:   0%|   …
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.10.0/models/mwt/combined.pt:   0%|        …
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.10.0/models/pos/combined_charlm.pt:   0%| …
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.10.0/models/lemma/combined_nocharlm.pt:   …
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.10.0/models/depparse/combined_charlm.pt:  …
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.10.0/models/ner/conll02.pt:   0%|         …
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.10.0/models/pretrain/conll17.pt:   0%|    …
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.10.0/models/forward_charlm/newswiki.pt:   …
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.10.0/models/backward_charlm/newswiki.pt:  …
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.10.0/models/pretrain/fasttextwiki.pt:   0%…
# INFO:stanza:Loading these models for language: es (Spanish):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# | ner       | conll02           |
# =================================
#
# INFO:stanza:Using device: cuda
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!
# [[('Sr. D. R. P.', 'MISC')]]
#
# [[('Fragmentos', 'MISC')]]
#
# [[('Desvarío', 'MISC')]]
#
# [[('Soneto', 'PER'), ('inmortal Quintana...', 'MISC')]]
#
# [[('Balada', 'PER')]]
#
# [[('Luna', 'MISC'), ('Mocquet', 'PER')]]
#
# [[('señora M…', 'PER')]]
#
# [[]]
#
# [[]]
#
# [[('Luna', 'MISC')]]
#
# [[('Don B. M.', 'PER')]]
#
# [[('Manzanares', 'LOC')]]
#
# [[('Luna', 'MISC')]]
#
# [[('de la Rosa de Alejandra', 'PER')]]
#
# [[]]
#
# [[('Luna', 'MISC')]]
#
# [[('Sr. D. Agustín Esteban Collantes', 'MISC')]]
#
# [[('Margarita Aurora de Wilson', 'PER'), ('Serrano', 'PER')]]
#
# [[('I', 'PER')]]
#
# [[('Margarita', 'PER')]]
#
# [[]]
#
# [[('Señora doña M. Del Pilar Sinués de Marco', 'PER')]]
#
# [[('II', 'MISC')]]
#
# [[('Margarita', 'PER')]]
#
# [[('Margarita Aurora de Wilson', 'PER'), ('Serrano', 'PER')]]
#
# [[('María', 'PER')]]
#
# [[('Alteza Real', 'PER'), ('Príncipe de Asturias', 'PER')]]
#
# [[('Margarita', 'PER')]]
#
# [[]]
#
# [[('Soneto', 'PER')]]
#
# [[('SS. MM. II', 'PER')]]
#
# [[('El matrimonio de la Princesa real de Inglaterra [...]', 'MISC')], [], []]
#
# [[('Poesía', 'MISC'), ('Oda', 'PER')]]
#
# [[('Alejandro Dumas', 'PER')]]
#
# [[('Soneto', 'PER')]]
#
# [[]]
#
# [[('SS.', 'MISC'), ('AA. [...', 'MISC')], [], [('El príncipe Mirza-Ally-Kan-Bahadoor [...]', 'MISC')], []]
#
# [[]]
#
# [[]]
#
# [[], [], [('Ismail', 'PER')]]
#
# [[('Leviatán', 'MISC')]]
#
# [[]]
#
# [[('M. de Lamartine', 'PER')]]
#
# [[]]
#
# [[('Isabel II', 'PER')]]
#
# [[('Hamlet', 'PER')]]
#
# [[], [], [('Malibran', 'ORG'), ('Londres', 'LOC')], [('Brasil', 'ORG')]]
#
# [[('M. de Lamartine', 'PER')]]
#
# [[('Porvenir', 'PER'), ('Francia', 'ORG'), ('Nuevo-Mundo', 'LOC')]]
#
# [[('Confederación Argentina', 'ORG'), ('Uruguay-Le Paraguay', 'ORG')]]
#
# [[('S. M. La emperatriz de los franceses', 'MISC')]]
#
# [[]]
#
# [[('Zurbarán', 'LOC')]]
#
# [[]]
#
# [[], [('Filadelfia', 'LOC')], []]
#
# [[('Ville', 'LOC')]]
#
# [[('Paraguay', 'LOC')]]
#
# [[('Escma', 'ORG'), ('Dª Gertrudis Gómez de Avellaneda', 'PER')]]
#
# [[]]
#
# [[('Leopoldo Robert', 'PER')]]
#
# [[]]
#
# [[]]
#
# [[('Leemos en el Monitor  [...]', 'MISC')], [("'Anuario diplomático de 1859' [...]", 'MISC')], [('Alto', 'LOC'), ('Bajo Rin', 'LOC')], [], [], [('El matrimonio del hijo mayor [...]', 'MISC')], [('Savonnette', 'PER')]]
#
# [[('Ramón de la Sagra', 'PER')]]
#
# [[('Estados-Unidos', 'ORG'), ('Paraguay', 'ORG')]]
#
# [[]]
#
# [[]]
#
# [[('SS. AA. II', 'MISC'), ('princesa Napoleón', 'PER')]]
#
# [[]]
#
# [[('Leopoldo Robert', 'PER'), ('Conclusión', 'ORG')]]
#
# [[], [('San Petesburgo', 'MISC')], [('El Entreacto publica un acarta fechada en Génova', 'MISC')]]
#
# [[('Memorándum especial por la guerra de Italia', 'MISC')]]
#
# [[]]
#
# [[('Pbro', 'PER'), ('D. Félix Varela', 'PER')]]
#
# [[]]
#
# [[('catedral de Bron', 'LOC')]]
#
# [['NULL']]
#
# [[]]
#
# [[('Artículo II', 'MISC'), ('Estados-Unidos', 'ORG'), ('Paraguay', 'ORG')]]
#
# [[]]
#
# [[('Deuda', 'MISC')]]
#
# [[('M. Alejandro Dumas', 'PER')]]
#
# [[('Carta del Sr.', 'MISC'), ('Guillemot', 'PER')]]
#
# [[('Napoleón III', 'PER')]]
#
# [[('Víctor Manuel II', 'PER')]]
#
# [[]]
#
# [[('Poesía', 'MISC'), ('Mariano G. Manrique', 'PER')]]
#
# [[]]
#
# [[]]
#
# [[('Poesía', 'MISC'), ('Napoleón III', 'PER')]]
#
# [[('Montmartre', 'LOC'), ('Fragmento', 'MISC')]]
#
# [[]]
#
# [[('Solferino', 'PER')]]
#
# [[('Memorándum especial por la guerra de Italia', 'MISC')]]
#
# [[('Batalla de Solferino', 'MISC')]]
#
# [[('Ejército de Italia', 'ORG')]]
#
# [[('Villafranca', 'LOC')]]
#
# [[('mariscal Vaillant', 'PER'), ('Italia', 'LOC')]]
#
# [[('Poesía', 'MISC')]]
#
# [[('S. M.', 'PER'), ('Napoleón III', 'PER'), ('Fragmentos', 'ORG')]]
#
# [[]]
#
# [[('Baltasar', 'PER')]]
#
# [[]]
#
# [[]]
#
# [[('Garibaldi', 'PER')]]
#
# [[]]
#
# [[('Señora Doña Emilia Serrano de Wilson', 'PER')]]
#
# [[('Offland', 'PER')]]
#
# [[('doña María Verdejo', 'PER'), ('Durán', 'PER')]]
#
# [[]]
#
# [[('María Leczinska', 'PER')]]
#
# [[('Otello', 'MISC'), ('Rossini', 'PER')]]
#
# [[('señora Hua', 'PER')]]
#
# [[('doña Carolina Coronado', 'PER')]]
#
# [[]]
#
# [[]]
#
# [[('María Leczinska', 'PER')]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[('niña Adelaida', 'PER')]]
#
# [[('Esther', 'PER')]]
#
# [[]]
#
# [[('Tetuán', 'LOC')]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[('Balada', 'PER')]]
#
# [[]]
#
# [[('Velázquez', 'PER')]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[('doña Eulogia', 'PER')]]
#
# [[('Velázquez', 'PER')]]
#
# [[('España', 'ORG'), ('Marruecos', 'ORG')]]
#
# [[('D. José Piquer', 'PER')]]
#
# [[]]
#
# [[('Velázquez', 'PER')]]
#
# [[]]
#
# [[]]
#
# [[('Cuba', 'LOC'), ('Cojimar', 'PER')]]
#
# [[], [('La ópera de Verdi [...]', 'MISC')], [('El marqués de Casa-Riera [...]', 'MISC')], []]
#
# [[('Balada', 'PER')]]
#
# [[('Dolora', 'PER')]]
#
# [[('Colón', 'LOC')]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[('Macahé', 'PER')]]
#
# [[('Emilia', 'PER')]]
#
# [[('Señor', 'PER')]]
#
# [[]]
#
# [[('Cuba', 'LOC')]]
#
# [[]]
#
# [[]]
#
# [[('Griseldina', 'PER')]]
#
# [[('Araceli Abril de Armendi', 'PER')]]
#
# [[]]
#
# [[('Griseldina', 'PER')]]
#
# [[('Cuba', 'LOC')]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[('Oda', 'PER')]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[('Periquito el Veleidoso', 'PER')]]
#
# [[('Cuba', 'LOC')]]
#
# [[('Santo Domingo', 'LOC')]]
#
# [[]]
#
# [[('Soledad', 'PER')]]
#
# [[]]
#
# [[('Santander', 'LOC')]]
#
# [[('Periquito el Veleidoso', 'PER'), ('Conclusion', 'ORG')]]
#
# [[]]
#
# [[('Allende los mares mora [...]', 'MISC')]]
#
# [[('doña Emila Serrano de Wilson', 'PER')]]
#
# [[('J. R.', 'PER')]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[('Rolandseck', 'PER')]]
#
# [[]]
#
# [[('marquesa', 'PER')]]
#
# [[('Poesía', 'MISC')]]
#
# [[]]
#
# [[('Soneto', 'PER')]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[('SS. MM', 'MISC')]]
#
# [[('Mariquita', 'PER')]]
#
# [[], [('Bonaparte', 'PER')], []]
#
# [[]]
#
# [[('sargento Pérez', 'PER'), ('Santo Domingo', 'LOC')]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[], [('Biarritz', 'LOC')], []]
#
# [[]]
#
# [[('Sevilla', 'LOC')]]
#
# [[('Soneto', 'PER')]]
#
# [[('Carta I. Monserrat', 'PER')]]
#
# [[]]
#
# [[]]
#
# [[('Ucles', 'MISC')]]
#
# [[]]
#
# [[('Fábula', 'PER')]]
#
# [[('Carta II', 'MISC'), ('Valencia', 'LOC')]]
#
# [[('Ucles', 'MISC')]]
#
# [[]]
#
# [[]]
#
# [[], [('La señora de J [...]', 'MISC')], [('El señor X [...]', 'MISC')], []]
#
# [[]]
#
# [[('Carta III', 'MISC'), ('Barcelona', 'LOC')]]
#
# [[('Conclusión', 'MISC')]]
#
# [[('Brasil', 'ORG')]]
#
# [[]]
#
# [[('Panamá', 'LOC')]]
#
# [[('Saint-Point', 'LOC')]]
#
# [[]]
#
# [[('Austria', 'LOC')]]
#
# [[]]
#
# [[('Feria', 'MISC'), ('Sevilla', 'LOC')]]
#
# [['NULL']]
#
# [[]]
#
# [[]]
#
# [[('Soneto', 'PER')]]
#
# [[('Soneto', 'PER')]]
#
# [[]]
#
# [[('Francisco José', 'PER'), ('Emperador del Austria', 'PER')]]
#
# [[('Ministerio Inglés', 'ORG')]]
#
# [[('Monitor de París', 'ORG'), ('Solferino', 'PER')]]
#
# [[], [], [('Invento-Histórico', 'MISC')]]
#
# [[('N.', 'PER'), ('señora **', 'MISC')]]
#
# [[('Goysevox', 'MISC')]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[('D. José Piquer-Oda', 'PER'), ('Alzad vuestras tumbas [...]', 'MISC')]]
#
# [[('Rusia', 'ORG')]]
#
# [[('Rusia', 'ORG')]]
#
# [[('Safo', 'PER')]]
#
# [[]]
#
# [[('Sombreros de Alexandrine', 'ORG')]]
#
# [[("Sombreros d'Alexandrine", 'ORG')]]
#
# [[('Sombreros De Alexandrine', 'PER')]]
#
# [[('Sombreros De Alexandrine', 'PER')]]
#
# [[("Sombreros d'Alexandrine", 'ORG')]]
#
# [[("Sombreros d'Alexandrine", 'ORG')]]
#
# [[("Sombreros d'Alexandrine", 'ORG')]]
#
# [[('Planchais [...]', 'MISC')]]
#
# [[]]
#
# [[('Casa de comisión para París [...]', 'MISC')]]
#
# [[]]
#
# [[]]
#
# [[("Sombreros d'Alexandrine", 'MISC'), ('Corsets Plastiques Mme', 'ORG'), ('Bonvallet', 'PER')]]
#
# [[]]
#
# [[]]
#
# [[('Bonvallet', 'LOC'), ('Faguer Labollée', 'PER'), ('Lemnnier', 'LOC'), ('Porcelaines', 'ORG'), ("Cristaux Maison de l'Escalier de Cristal", 'ORG')]]
#
# [[]]
#
# [[('Sorré Dehsle', 'LOC'), ('Corsets plastiques de Bonvallet', 'LOC'), ('Guantes', 'LOC'), ('Faguer Labollée', 'LOC'), ('Lemnnier', 'LOC'), ("Porcelaines et Cristaux Maison de l'Escalier de Cristal", 'ORG')]]
#
# [[('Lait', 'PER')]]
#
# [[('Camisas Claudio', 'PER'), ('Hermanos', 'PER')]]
#
# [[]]
#
# [[('Huéspedes', 'LOC')]]
#
# [[('Casa Delacroix', 'ORG')]]
#
# [[('Jules Bloch', 'PER')]]
#
# [[('Gaceta de Bellas Artes', 'ORG')]]
#
# [[]]
#
# [[]]
#
# [[('Porta-monedas Despierres', 'ORG')]]
#
# [[('Tarifs des insertions', 'ORG')]]
#
# [[('Sorré Dehsle', 'LOC'), ('Corsets plastiques de Bonvallet', 'LOC'), ('Guantes', 'LOC'), ('Faguer Labollée', 'LOC'), ('Lemnnier', 'LOC'), ("Porcelaines et Cristaux Maison de l'Escalier de Cristal", 'ORG')]]
#
# [[('Camisas Claudio', 'PER'), ('Hermanos', 'PER')]]
#
# [[('Nueva Geografía Sangansan', 'MISC')]]
#
# [[('Huéspedes', 'LOC')]]
#
# [[('Casa Delacroix', 'ORG')]]
#
# [[('Jules Bloch', 'PER')]]
#
# [[('Platería Cristofle', 'ORG')]]
#
# [[]]
#
# [[('Tarifs des insertions', 'ORG')]]
#
# [[('Sorré Dehsle', 'LOC'), ('Corsets plastiques de Bonvallet', 'LOC'), ('Guantes', 'LOC'), ('Faguer Labollée', 'LOC'), ('Lemnnier', 'LOC'), ("Porcelaines et Cristaux Maison de l'Escalier de Cristal", 'ORG')]]
#
# [[('Camisas Claudio', 'PER'), ('Hermanos', 'PER')]]
#
# [[('Nueva Geografía Sangansan', 'MISC')]]
#
# [[('Huéspedes', 'LOC')]]
#
# [[('Casa Delacroix', 'ORG')]]
#
# [[('Jules Bloch', 'PER')]]
#
# [[('Platería Cristofle', 'ORG')]]
#
# [[]]
#
# [[('Tarifs des insertions', 'ORG')]]
#
# [[('Camisas Claudio', 'PER'), ('Hermanos', 'PER')]]
#
# [[('Nueva Geografía Sangansan', 'MISC')]]
#
# [[('Huéspedes', 'LOC')]]
#
# [[('Casa Delacroix', 'ORG')]]
#
# [[('Jules Bloch', 'PER')]]
#
# [[('Platería Cristofle', 'ORG')]]
#
# [[]]
#
# [[('Tarifs des insertions', 'ORG')]]
#
# [[('Camisas Claudio', 'PER'), ('Hermanos', 'PER')]]
#
# [[('Nueva Geografía Sangansan', 'MISC')]]
#
# [[('Huéspedes', 'LOC')]]
#
# [[('Casa Delacroix', 'ORG')]]
#
# [[('Jules Bloch', 'PER')]]
#
# [[('Platería Cristofle', 'ORG')]]
#
# [[]]
#
# [[('Platería Cristofle', 'ORG')]]
#
# [[('Camisas Claudio', 'PER'), ('Hermanos', 'PER')]]
#
# [[('Nueva Geografía Sangansan', 'MISC')]]
#
# [[('Huéspedes', 'LOC')]]
#
# [[('Casa Delacroix', 'ORG')]]
#
# [[('Jules Bloch', 'PER')]]
#
# [[]]
#
# [[('Sorré Dehsle', 'LOC'), ('Corsets plastiques de Bonvallet', 'LOC'), ('Guantes', 'LOC'), ('Faguer Labollée', 'LOC'), ('Lemnnier', 'LOC'), ("Porcelaines et Cristaux Maison de l'Escalier de Cristal", 'ORG')]]
#
# [[('Camisas Claudio', 'PER'), ('Hermanos', 'PER')]]
#
# [[('Nueva Geografía Sangansan', 'MISC')]]
#
# [[('Huéspedes', 'LOC')]]
#
# [[('Casa Delacroix', 'ORG')]]
#
# [[('Jules Bloch', 'PER')]]
#
# [[('Platería Cristofle', 'ORG')]]
#
# [[('Camisas Claudio', 'PER'), ('Hermanos', 'PER')]]
#
# [[('Nueva Geografía Sangansan', 'MISC')]]
#
# [[('Huéspedes', 'LOC')]]
#
# [[('Casa Delacroix', 'ORG')]]
#
# [[('Jules Bloch', 'PER')]]
#
# [[('Platería Cristofle', 'ORG')]]
#
# [[]]
#
# [[('Sorré Dehsle', 'LOC'), ('Corsets plastiques de Bonvallet', 'LOC'), ('Guantes', 'LOC'), ('Faguer Labollée', 'LOC'), ('Lemnnier', 'LOC'), ("Porcelaines et Cristaux Maison de l'Escalier de Cristal", 'ORG')]]
#
# [[('Camisas Claudio', 'PER'), ('Hermanos', 'PER')]]
#
# [[('Nueva Geografía Sangansan', 'MISC')]]
#
# [[('Huéspedes', 'LOC')]]
#
# [[('Casa Delacroix', 'ORG')]]
#
# [[('Jules Bloch', 'PER')]]
#
# [[('Platería Cristofle', 'ORG')]]
#
# [[('Sorré Dehsle', 'LOC'), ('Corsets plastiques de Bonvallet', 'LOC'), ('Guantes', 'LOC'), ('Faguer Labollée', 'LOC'), ('Lemnnier', 'LOC'), ("Porcelaines et Cristaux Maison de l'Escalier de Cristal", 'ORG')]]
#
# [[('Platería Cristofle', 'ORG')]]
#
# [[('doña Emilia Serrano de Wilson', 'PER')]]
#
# [[('Platería Cristofle', 'ORG')]]
#
# [[('doña Emilia Serrano de Wilson', 'PER')]]
#
# [[('Platería Cristofle', 'ORG')]]
#
# [[('doña Emilia Serrano de Wilson', 'PER')]]
#
# [[('Modes de Paris', 'LOC'), ('Petit Courrier des Dames', 'LOC')]]
#
# [[('Eco Hispano-Americano', 'ORG')]]
#
# [[('doña Emilia Serrano de Wilson', 'PER')]]
#
# [[('Eco Hispano-Americano', 'ORG')]]
#
# [[]]
#
# [[('doña Emilia Serrano de Wilson', 'PER')]]
#
# [['NULL']]
#
# [['NULL']]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[('Moda de Caballeros', 'MISC')]]
#
# [['NULL']]
#
# [['NULL']]
#
# [[]]
#
# [[]]
#
# [['NULL']]
#
# [[]]
#
# [[]]
#
# [['NULL']]
#
# [[]]
#
# [['NULL']]
#
# [['NULL']]
#
# [['NULL']]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [['NULL']]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [['NULL']]
#
# [['NULL']]
#
# [[]]
#
# [[]]
#
# [[('Segundo', 'PER')]]
#
# [[]]
#
# [[('Revista de París', 'ORG')]]
#
# [[]]
#
# [[('Revista de París', 'ORG')]]
#
# [[]]
#
# [[('Revista de París', 'ORG')]]
#
# [[]]
#
# [[('Revista de París', 'ORG')]]
#
# [[]]
#
# [[('Revista de París', 'ORG')]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[('Revista Parisense', 'ORG')]]
#
# [[]]
#
# [[]]
#
# [[('Revista Parisense', 'ORG')]]
#
# [[]]
#
# [[]]
#
# [[('Revista Parisense', 'ORG')]]
#
# [[]]
#
# [[('Revista Parisense', 'ORG')]]
#
# [[]]
#
# [[('Revista Parisense', 'ORG')]]
#
# [[]]
#
# [[('Revista Parisiense', 'ORG')]]
#
# [[]]
#
# [[('Revista Parisiense', 'ORG')]]
#
# [[]]
#
# [[]]
#
# [[('Revista Parisiense', 'ORG')]]
#
# [[]]
#
# [[]]
#
# [[('Revista Parisiense', 'ORG')]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[('Revista de Madrid', 'ORG')]]
#
# [[]]
#
# [[]]
#
# [[('Revista Parisiense', 'ORG')]]
#
# [[('Revista de Madrid', 'ORG')]]
#
# [[]]
#
# [[]]
#
# [[('Revista Parisiense', 'ORG')]]
#
# [[('Revista de Madrid', 'ORG')]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[('Revista Parisiense', 'ORG')]]
#
# [[('Revista de Madrid', 'ORG')]]
#
# [[]]
#
# [[]]
#
# [[('Revista Parisiense', 'ORG')]]
#
# [[('Revista de Madrid', 'ORG')]]
#
# [[]]
#
# [[('Revista Parisiense', 'ORG')]]
#
# [[('Revista de Madrid', 'ORG')]]
#
# [[]]
#
# [[('Revista Parisiense', 'ORG')]]
#
# [[('Revista de Madrid', 'ORG')]]
#
# [[('Revista Parisiense', 'ORG')]]
#
# [[('Revista de Madrid', 'ORG')]]
#
# [[]]
#
# [[('Revista de Madrid', 'ORG')]]
#
# [[('Revista de París', 'ORG')]]
#
# [[('Teatros', 'ORG')]]
#
# [[]]
#
# [[('Revista de Madrid', 'ORG')]]
#
# [[('Revista de París', 'ORG')]]
#
# [[]]
#
# [[('Revista de Madrid', 'ORG')]]
#
# [[]]
#
# [[('Revista de Madrid', 'ORG')]]
#
# [[('Revista de París', 'ORG')]]
#
# [[]]
#
# [[('Revista de Madrid', 'ORG')]]
#
# [[('Revista de París', 'ORG')]]
#
# [[]]
#
# [[('Revista de Madrid', 'ORG')]]
#
# [[('Revista de París', 'ORG')]]
#
# [[]]
#
# [[('Revista de Madrid', 'ORG')]]
#
# [[('Revista de París', 'ORG')]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[('Revista de Madrid', 'ORG')]]
#
# [[]]
#
# [[('Revista de Madrid', 'ORG')]]
#
# [[('Revista de París', 'ORG')]]
#
# [[]]
#
# [[('Revista de Madrid', 'ORG')]]
#
# [[('Revista de París', 'ORG')]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]
#
# [[]]

# %%
from ast import Pass
import copy

titles_to_NER_COPY = copy.deepcopy(titles_to_NER)

for index, row in enumerate(processed_ent_es):
  if index in [18, 22]:  # Problematic samples, we create exception
    continue
  else:
    for sub_index, entidad in enumerate(row):
      for tuple_item in entidad:
        if tuple_item is None:
          pass
        if isinstance(tuple_item, str):
          pass
        if isinstance(tuple_item, tuple):
          entity_str = tuple_item[0]
          replacement_str = f"[('{tuple_item[0]}', '{tuple_item[1]}')]"
          titles_to_NER_COPY[index][sub_index] = re.sub(re.escape(entity_str), replacement_str, titles_to_NER_COPY[index][sub_index])
        #except TypeError:
          #pass
        #except IndexError:
          #pass

for el in titles_to_NER_COPY[:50]:
    print(el, "\n")
# Out:
# ["Al [('Sr. D. R. P.', 'MISC')] Enviándole mis obras"]
#
# ["La mujer piadosa ([('Fragmentos', 'MISC')])"]
#
# ["[('Desvarío', 'MISC')]"]
#
# ['[(\'Soneto\', \'PER\')]. "¡Gloria y pobreza! El [(\'inmortal Quintana...\', \'MISC\')]"']
#
# ["[('Balada', 'PER')]. La despedida de una hija"]
#
# ["Un viaje a la [('Luna', 'MISC')]. Prólogo: La pesadilla de [('Mocquet', 'PER')]"]
#
# ["En el álbum de la [('señora M…', 'PER')]"]
#
# ['La primavera']
#
# ['La perejilera']
#
# ["Un viaje a la [('Luna', 'MISC')]. (Continuación)"]
#
# ["Al señor [('Don B. M.', 'PER')]"]
#
# ["A orillas del [('Manzanares', 'LOC')]. La súplica"]
#
# ["Un viaje a la [('Luna', 'MISC')]. (Continuación)"]
#
# ["Fragmentos [('de la Rosa de Alejandra', 'PER')]"]
#
# ['Gente morena']
#
# ["Un viaje a la [('Luna', 'MISC')]. (Continuación)"]
#
# ["Al excmo. [('Sr. D. Agustín Esteban Collantes', 'MISC')], en el día de su santo"]
#
# ["A la niña [('Margarita Aurora de Wilson', 'PER')] y [('Serrano', 'PER')], el día de su cumpleaños"]
#
# ['Costumbres del [("siglo XIX", "DATE")] I']
#
# ["[('Margarita', 'PER')]. Novela bretona"]
#
# ['Los escondidos y la tapada. Fragmentos']
#
# ["A mi apreciable amiga la [('Señora doña M. Del Pilar Sinués de Marco', 'PER')] en su álbum"]
#
# ['Costumbres del [("siglo XIX", "DATE")] II']
#
# ["[('Margarita', 'PER')]. Novela bretona. (Continuación)"]
#
# ["A la niña [('Margarita Aurora de Wilson', 'PER')] y [('Serrano', 'PER')]"]
#
# ["A [('María', 'PER')]"]
#
# ["A su [('Alteza Real', 'PER')] el [('Príncipe de Asturias', 'PER')]"]
#
# ["[('Margarita', 'PER')]. Novela bretona. (Conclusión)"]
#
# ['El otoño']
#
# ['[(\'Soneto\', \'PER\')]. "Aún eco tienen en el alma mía..."']
#
# ["Atentado contra [('SS. MM. II', 'PER')]."]
#
# ['"[(\'El matrimonio de la Princesa real de Inglaterra [...]\', \'MISC\')]"', '"Hace algunos años que un banquero muy rico [...]"', '"Varios periódicos franceses y del extranjero [...]"']
#
# ["A la [('Poesía', 'MISC')]. [('Oda', 'PER')]"]
#
# ["A mi buen amigo el distinguido escritor don [('Alejandro Dumas', 'PER')] en prueba de sincera amistad"]
#
# ["A la luna. [('Soneto', 'PER')]"]
#
# ['Las apariencias engañan. Historia-cuento']
#
# ['"El viaje de [(\'SS.\', \'MISC\')] [(\'AA. [...\', \'MISC\')]]"', '"El sábado a la una [...]"', '"[(\'El príncipe Mirza-Ally-Kan-Bahadoor [...]\', \'MISC\')]"', '"Habláse mucho en los círculos aristocrático de un matrimonio [...]"']
#
# ['El invierno']
#
# ['La hada azul']
#
# ['"El lunes 5 del corriente se ha inaugurado [...]"', '"Vamos a contar una historia ocurrida en estos días de Pascua"', '"Cuando [(\'Ismail\', \'PER\')], generalísimo del ejército otomano [...]"']
#
# ["El navío [('Leviatán', 'MISC')]"]
#
# ['Ayes del corazón']
#
# ["Carta de [('M. de Lamartine', 'PER')]"]
#
# ['Introducción']
#
# ["[('Isabel II', 'PER')]"]
#
# ["[('Hamlet', 'PER')]"]
#
# ['"Lo que cada lector pide [...]"', 'La trata de blancas-De la decadencia de las costumbres', '"La [(\'Malibran\', \'ORG\')] recibía en [(\'Londres\', \'LOC\')] [...]"', '"El gobierno del [(\'Brasil\', \'ORG\')] [...]"']
#
# ['"Consignamos la acarta original qu enos ha dirigido [(\'M. de Lamartine\', \'PER\')] [...]"']
#
# ["[('Porvenir', 'PER')] de la raza latina y de la [('Francia', 'ORG')] en el [('Nuevo-Mundo', 'LOC')]. Introducción"]
#
# ["[('Confederación Argentina', 'ORG')] y república del [('Uruguay-Le Paraguay', 'ORG')]"]

# %%
#we've gotten categories related to NER processing, after including entities [(x,y)] in each row/title
#we proceed with the second part of processing (tok,lemma,pos,depp) keeping NER categories without processing.

def processing_2(text, nlp_model):
  doc = nlp_model(text)
  if text == "NULL":
    return [("NULL")]
  if "[(" not in text:
    return [(word.text, word.lemma, word.upos) for sent in doc.sentences for word in sent.words]
  if "[(" in text:
    result = []
    current_index = 0
    for match in re.finditer(r'\[\(.*?\)\]', text):  # Find all special category patterns
      # Process text before the match
      before_match = text[current_index:match.start()]
      doc = nlp_model(before_match)
      result.extend([(word.text, word.lemma, word.upos) for sent in doc.sentences for word in sent.words])

      result.append(match.group(0))

      current_index = match.end()

    remaining_text = text[current_index:]
    doc = nlp_model(remaining_text)
    result.extend([(word.text, word.lemma, word.upos) for sent in doc.sentences for word in sent.words])

    return result

nlp_es = stanza.Pipeline(lang="es", processors="tokenize,mwt,pos,lemma")

pro_lem = [[processing_2(el, nlp_es) for el in lista] for lista in titles_to_NER_COPY]

for element in pro_lem[:50]:
  print(element, "\n")
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: es (Spanish):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cuda
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# [[('A', 'a', 'ADP'), ('el', 'el', 'DET'), "[('Sr. D. R. P.', 'MISC')]", ('Enviando', 'enviar', 'VERB'), ('le', 'él', 'PRON'), ('mis', 'mi', 'DET'), ('obras', 'obra', 'NOUN')]]
#
# [[('La', 'el', 'DET'), ('mujer', 'mujer', 'NOUN'), ('piadosa', 'piadoso', 'ADJ'), ('(', '(', 'PUNCT'), "[('Fragmentos', 'MISC')]", (')', ')', 'PUNCT')]]
#
# [["[('Desvarío', 'MISC')]"]]
#
# [["[('Soneto', 'PER')]", ('.', '.', 'PUNCT'), ('"', '"', 'PUNCT'), ('¡', '¡', 'PUNCT'), ('Gloria', 'gloria', 'PROPN'), ('y', 'y', 'CCONJ'), ('pobreza', 'pobreza', 'NOUN'), ('!', '!', 'PUNCT'), ('El', 'el', 'DET'), "[('inmortal Quintana...', 'MISC')]", ('"', '"', 'PUNCT')]]
#
# [["[('Balada', 'PER')]", ('.', '.', 'PUNCT'), ('La', 'el', 'DET'), ('despedida', 'despedida', 'NOUN'), ('de', 'de', 'ADP'), ('una', 'uno', 'DET'), ('hija', 'hija', 'NOUN')]]
#
# [[('Un', 'uno', 'DET'), ('viaje', 'viaje', 'NOUN'), ('a', 'a', 'ADP'), ('la', 'el', 'DET'), "[('Luna', 'MISC')]", ('.', '.', 'PUNCT'), ('Prólogo', 'prólogo', 'NOUN'), (':', ':', 'PUNCT'), ('La', 'el', 'DET'), ('pesadilla', 'pesadilla', 'PROPN'), ('de', 'de', 'ADP'), "[('Mocquet', 'PER')]"]]
#
# [[('En', 'en', 'ADP'), ('el', 'el', 'DET'), ('álbum', 'álbum', 'NOUN'), ('de', 'de', 'ADP'), ('la', 'el', 'DET'), "[('señora M…', 'PER')]"]]
#
# [[('La', 'el', 'DET'), ('primavera', 'primavera', 'NOUN')]]
#
# [[('La', 'el', 'DET'), ('perejilera', 'perejilera', 'NOUN')]]
#
# [[('Un', 'uno', 'DET'), ('viaje', 'viaje', 'NOUN'), ('a', 'a', 'ADP'), ('la', 'el', 'DET'), "[('Luna', 'MISC')]", ('.', '.', 'PUNCT'), ('(', '(', 'PUNCT'), ('Continuación', 'continuación', 'NOUN'), (')', ')', 'PUNCT')]]
#
# [[('A', 'a', 'ADP'), ('el', 'el', 'DET'), ('señor', 'señor', 'NOUN'), "[('Don B. M.', 'PER')]"]]
#
# [[('A', 'a', 'ADP'), ('orillas', 'orilla', 'NOUN'), ('de', 'de', 'ADP'), ('el', 'el', 'DET'), "[('Manzanares', 'LOC')]", ('.', '.', 'PUNCT'), ('La', 'el', 'DET'), ('súplica', 'súplica', 'NOUN')]]
#
# [[('Un', 'uno', 'DET'), ('viaje', 'viaje', 'NOUN'), ('a', 'a', 'ADP'), ('la', 'el', 'DET'), "[('Luna', 'MISC')]", ('.', '.', 'PUNCT'), ('(', '(', 'PUNCT'), ('Continuación', 'continuación', 'NOUN'), (')', ')', 'PUNCT')]]
#
# [[('Fragmentos', 'fragmentos', 'NOUN'), "[('de la Rosa de Alejandra', 'PER')]"]]
#
# [[('Gente', 'gente', 'NOUN'), ('morena', 'moreno', 'ADJ')]]
#
# [[('Un', 'uno', 'DET'), ('viaje', 'viaje', 'NOUN'), ('a', 'a', 'ADP'), ('la', 'el', 'DET'), "[('Luna', 'MISC')]", ('.', '.', 'PUNCT'), ('(', '(', 'PUNCT'), ('Continuación', 'continuación', 'NOUN'), (')', ')', 'PUNCT')]]
#
# [[('A', 'a', 'ADP'), ('el', 'el', 'DET'), ('excmo', 'excmo', 'NOUN'), ('.', '.', 'PUNCT'), "[('Sr. D. Agustín Esteban Collantes', 'MISC')]", (',', ',', 'PUNCT'), ('en', 'en', 'ADP'), ('el', 'el', 'DET'), ('día', 'día', 'NOUN'), ('de', 'de', 'ADP'), ('su', 'su', 'DET'), ('santo', 'santo', 'NOUN')]]
#
# [[('A', 'a', 'ADP'), ('la', 'el', 'DET'), ('niña', 'niña', 'NOUN'), "[('Margarita Aurora de Wilson', 'PER')]", ('y', 'y', 'CCONJ'), "[('Serrano', 'PER')]", (',', ',', 'PUNCT'), ('el', 'el', 'DET'), ('día', 'día', 'NOUN'), ('de', 'de', 'ADP'), ('su', 'su', 'DET'), ('cumpleaños', 'cumpleaños', 'NOUN')]]
#
# [[('Costumbres', 'costumbres', 'NOUN'), ('de', 'de', 'ADP'), ('el', 'el', 'DET'), '[("siglo XIX", "DATE")]', ('I', 'i', 'NUM')]]
#
# [["[('Margarita', 'PER')]", ('.', '.', 'PUNCT'), ('Novela', 'novela', 'NOUN'), ('bretona', 'bretono', 'ADJ')]]
#
# [[('Los', 'el', 'DET'), ('escondidos', 'esconder', 'ADJ'), ('y', 'y', 'CCONJ'), ('la', 'el', 'DET'), ('tapada', 'tapada', 'NOUN'), ('.', '.', 'PUNCT'), ('Fragmentos', 'fragmentos', 'NOUN')]]
#
# [[('A', 'a', 'ADP'), ('mi', 'mi', 'DET'), ('apreciable', 'apreciable', 'ADJ'), ('amiga', 'amiga', 'NOUN'), ('la', 'el', 'DET'), "[('Señora doña M. Del Pilar Sinués de Marco', 'PER')]", ('en', 'en', 'ADP'), ('su', 'su', 'DET'), ('álbum', 'álbum', 'NOUN')]]
#
# [[('Costumbres', 'costumbres', 'NOUN'), ('de', 'de', 'ADP'), ('el', 'el', 'DET'), '[("siglo XIX", "DATE")]', ('II', 'ii', 'NUM')]]
#
# [["[('Margarita', 'PER')]", ('.', '.', 'PUNCT'), ('Novela', 'novela', 'NOUN'), ('bretona', 'bretono', 'ADJ'), ('.', '.', 'PUNCT'), ('(', '(', 'PUNCT'), ('Continuación', 'continuación', 'NOUN'), (')', ')', 'PUNCT')]]
#
# [[('A', 'a', 'ADP'), ('la', 'el', 'DET'), ('niña', 'niña', 'NOUN'), "[('Margarita Aurora de Wilson', 'PER')]", ('y', 'y', 'CCONJ'), "[('Serrano', 'PER')]"]]
#
# [[('A', 'a', 'ADP'), "[('María', 'PER')]"]]
#
# [[('A', 'a', 'ADP'), ('su', 'su', 'DET'), "[('Alteza Real', 'PER')]", ('el', 'el', 'DET'), "[('Príncipe de Asturias', 'PER')]"]]
#
# [["[('Margarita', 'PER')]", ('.', '.', 'PUNCT'), ('Novela', 'novela', 'NOUN'), ('bretona', 'bretono', 'ADJ'), ('.', '.', 'PUNCT'), ('(', '(', 'PUNCT'), ('Conclusión', 'Conclusión', 'PROPN'), (')', ')', 'PUNCT')]]
#
# [[('El', 'el', 'DET'), ('otoño', 'otoño', 'NOUN')]]
#
# [["[('Soneto', 'PER')]", ('.', '.', 'PUNCT'), ('"', '"', 'PUNCT'), ('Aún', 'aún', 'ADV'), ('eco', 'eco', 'NOUN'), ('tienen', 'tener', 'VERB'), ('en', 'en', 'ADP'), ('el', 'el', 'DET'), ('alma', 'alma', 'NOUN'), ('mía', 'mía', 'DET'), ('...', '...', 'PUNCT'), ('"', '"', 'PUNCT')]]
#
# [[('Atentado', 'atentado', 'NOUN'), ('contra', 'contra', 'ADP'), "[('SS. MM. II', 'PER')]", ('.', '.', 'PUNCT')]]
#
# [[('"', '"', 'PUNCT'), "[('El matrimonio de la Princesa real de Inglaterra [...]', 'MISC')]", ('"', '"', 'PUNCT')], [('"', '"', 'PUNCT'), ('Hace', 'hacer', 'VERB'), ('algunos', 'alguno', 'DET'), ('años', 'año', 'NOUN'), ('que', 'que', 'SCONJ'), ('un', 'uno', 'DET'), ('banquero', 'banquero', 'NOUN'), ('muy', 'mucho', 'ADV'), ('rico', 'rico', 'ADJ'), ('[', '[', 'PUNCT'), ('...', '...', 'PUNCT'), (']', ']', 'PUNCT'), ('"', '"', 'PUNCT')], [('"', '"', 'PUNCT'), ('Varios', 'varios', 'DET'), ('periódicos', 'periódico', 'NOUN'), ('franceses', 'francés', 'ADJ'), ('y', 'y', 'CCONJ'), ('de', 'de', 'ADP'), ('el', 'el', 'DET'), ('extranjero', 'extranjero', 'NOUN'), ('[', '[', 'PUNCT'), ('...', '...', 'PUNCT'), (']', ']', 'PUNCT'), ('"', '"', 'PUNCT')]]
#
# [[('A', 'a', 'ADP'), ('la', 'el', 'DET'), "[('Poesía', 'MISC')]", ('.', '.', 'PUNCT'), "[('Oda', 'PER')]"]]
#
# [[('A', 'a', 'ADP'), ('mi', 'mi', 'DET'), ('buen', 'buen', 'ADJ'), ('amigo', 'amigo', 'NOUN'), ('el', 'el', 'DET'), ('distinguido', 'distinguir', 'ADJ'), ('escritor', 'escritor', 'NOUN'), ('don', 'don', 'ADJ'), "[('Alejandro Dumas', 'PER')]", ('en', 'en', 'ADP'), ('prueba', 'prueba', 'NOUN'), ('de', 'de', 'ADP'), ('sincera', 'sincero', 'ADJ'), ('amistad', 'amistad', 'NOUN')]]
#
# [[('A', 'a', 'ADP'), ('la', 'el', 'DET'), ('luna', 'luna', 'NOUN'), ('.', '.', 'PUNCT'), "[('Soneto', 'PER')]"]]
#
# [[('Las', 'el', 'DET'), ('apariencias', 'apariencia', 'NOUN'), ('engañan', 'engañar', 'VERB'), ('.', '.', 'PUNCT'), ('Historia-cuento', 'historia-cuento', 'NOUN')]]
#
# [[('"', '"', 'PUNCT'), ('El', 'el', 'DET'), ('viaje', 'viaje', 'NOUN'), ('de', 'de', 'ADP'), "[('SS.', 'MISC')]", "[('AA. [...', 'MISC')]", (']', ']', 'PUNCT'), ('"', '"', 'PUNCT')], [('"', '"', 'PUNCT'), ('El', 'el', 'DET'), ('sábado', 'sábado', 'NOUN'), ('a', 'a', 'ADP'), ('la', 'el', 'DET'), ('una', 'uno', 'PRON'), ('[', '[', 'PUNCT'), ('...', '...', 'PUNCT'), (']', ']', 'PUNCT'), ('"', '"', 'PUNCT')], [('"', '"', 'PUNCT'), "[('El príncipe Mirza-Ally-Kan-Bahadoor [...]', 'MISC')]", ('"', '"', 'PUNCT')], [('"', '"', 'PUNCT'), ('Habláse', 'hablar', 'VERB'), ('mucho', 'mucho', 'PRON'), ('en', 'en', 'ADP'), ('los', 'el', 'DET'), ('círculos', 'círculo', 'NOUN'), ('aristocrático', 'aristocrático', 'ADJ'), ('de', 'de', 'ADP'), ('un', 'uno', 'DET'), ('matrimonio', 'matrimonio', 'NOUN'), ('[', '[', 'PUNCT'), ('...', '...', 'PUNCT'), (']', ']', 'PUNCT'), ('"', '"', 'PUNCT')]]
#
# [[('El', 'el', 'DET'), ('invierno', 'invierno', 'NOUN')]]
#
# [[('La', 'el', 'DET'), ('hada', 'hada', 'NOUN'), ('azul', 'azul', 'ADJ')]]
#
# [[('"', '"', 'PUNCT'), ('El', 'el', 'DET'), ('lunes', 'lunes', 'NOUN'), ('5', '5', 'NUM'), ('de', 'de', 'ADP'), ('el', 'el', 'DET'), ('corriente', 'corriente', 'NOUN'), ('se', 'él', 'PRON'), ('ha', 'haber', 'AUX'), ('inaugurado', 'inaugurar', 'VERB'), ('[', '[', 'PUNCT'), ('...', '...', 'PUNCT'), (']', ']', 'PUNCT'), ('"', '"', 'PUNCT')], [('"', '"', 'PUNCT'), ('Vamos', 'ir', 'VERB'), ('a', 'a', 'ADP'), ('contar', 'contar', 'VERB'), ('una', 'uno', 'DET'), ('historia', 'historia', 'NOUN'), ('ocurrida', 'ocurrir', 'ADJ'), ('en', 'en', 'ADP'), ('estos', 'este', 'DET'), ('días', 'día', 'NOUN'), ('de', 'de', 'ADP'), ('Pascua', 'Pascua', 'PROPN'), ('"', '"', 'PUNCT')], [('"', '"', 'PUNCT'), ('Cuando', 'cuando', 'SCONJ'), "[('Ismail', 'PER')]", (',', ',', 'PUNCT'), ('generalísimo', 'generalísimo', 'ADJ'), ('de', 'de', 'ADP'), ('el', 'el', 'DET'), ('ejército', 'ejército', 'NOUN'), ('otomano', 'otomano', 'ADJ'), ('[', '[', 'PUNCT'), ('...', '...', 'PUNCT'), (']', ']', 'PUNCT'), ('"', '"', 'PUNCT')]]
#
# [[('El', 'el', 'DET'), ('navío', 'navío', 'NOUN'), "[('Leviatán', 'MISC')]"]]
#
# [[('Ayes', 'ayes', 'PROPN'), ('de', 'de', 'ADP'), ('el', 'el', 'DET'), ('corazón', 'corazón', 'NOUN')]]
#
# [[('Carta', 'carta', 'NOUN'), ('de', 'de', 'ADP'), "[('M. de Lamartine', 'PER')]"]]
#
# [[('Introducción', 'introducción', 'NOUN')]]
#
# [["[('Isabel II', 'PER')]"]]
#
# [["[('Hamlet', 'PER')]"]]
#
# [[('"', '"', 'PUNCT'), ('Lo', 'él', 'PRON'), ('que', 'que', 'PRON'), ('cada', 'cada', 'DET'), ('lector', 'lector', 'NOUN'), ('pide', 'pedir', 'VERB'), ('[', '[', 'PUNCT'), ('...', '...', 'PUNCT'), (']', ']', 'PUNCT'), ('"', '"', 'PUNCT')], [('La', 'el', 'DET'), ('trata', 'trata', 'NOUN'), ('de', 'de', 'ADP'), ('blancas-De', 'blancas-de', 'ADP'), ('la', 'el', 'DET'), ('decadencia', 'decadencia', 'NOUN'), ('de', 'de', 'ADP'), ('las', 'el', 'DET'), ('costumbres', 'costumbre', 'NOUN')], [('"', '"', 'PUNCT'), ('La', 'el', 'DET'), "[('Malibran', 'ORG')]", ('recibía', 'recibir', 'VERB'), ('en', 'en', 'ADP'), "[('Londres', 'LOC')]", ('[', '[', 'PUNCT'), ('...', '...', 'PUNCT'), (']', ']', 'PUNCT'), ('"', '"', 'PUNCT')], [('"', '"', 'PUNCT'), ('El', 'el', 'DET'), ('gobierno', 'gobierno', 'NOUN'), ('de', 'de', 'ADP'), ('el', 'el', 'DET'), "[('Brasil', 'ORG')]", ('[', '[', 'PUNCT'), ('...', '...', 'PUNCT'), (']', ']', 'PUNCT'), ('"', '"', 'PUNCT')]]
#
# [[('"', '"', 'PUNCT'), ('Consignamos', 'consignar', 'VERB'), ('la', 'el', 'DET'), ('acarta', 'acarta', 'NOUN'), ('original', 'original', 'ADJ'), ('qu', 'qu', 'CCONJ'), ('enos', 'enos', 'NOUN'), ('ha', 'haber', 'AUX'), ('dirigido', 'dirigir', 'VERB'), "[('M. de Lamartine', 'PER')]", ('[', '[', 'PUNCT'), ('...', '...', 'PUNCT'), (']', ']', 'PUNCT'), ('"', '"', 'PUNCT')]]
#
# [["[('Porvenir', 'PER')]", ('de', 'de', 'ADP'), ('la', 'el', 'DET'), ('raza', 'raza', 'NOUN'), ('latina', 'latino', 'ADJ'), ('y', 'y', 'CCONJ'), ('de', 'de', 'ADP'), ('la', 'el', 'DET'), "[('Francia', 'ORG')]", ('en', 'en', 'ADP'), ('el', 'el', 'DET'), "[('Nuevo-Mundo', 'LOC')]", ('.', '.', 'PUNCT'), ('Introducción', 'introducción', 'NOUN')]]
#
# [["[('Confederación Argentina', 'ORG')]", ('y', 'y', 'CCONJ'), ('república', 'república', 'NOUN'), ('de', 'de', 'ADP'), ('el', 'el', 'DET'), "[('Uruguay-Le Paraguay', 'ORG')]"]]

# %%
pro_lem_cleaned = copy.deepcopy(pro_lem)

for i_element, element in enumerate(pro_lem):
  for i_titulo, titulo in enumerate(element):
    #pro_lem_cleaned[i_element][i_titulo] = [tupla for tupla in titulo if isinstance(tupla, tuple) and tupla[2] in ('NOUN', 'PROPN', 'ADJ', 'VERB', 'ADV', 'INTJ')]
      pro_lem_cleaned[i_element][i_titulo] = [tupla for tupla in titulo if isinstance(tupla, tuple) and tupla[2] in ('NOUN', 'PROPN', 'ADJ', 'VERB', 'ADV', 'INTJ') or isinstance(tupla, str)]

# %%
for element in pro_lem_cleaned[:10]:
  print(element, "\n")
# Out:
# [["[('Sr. D. R. P.', 'MISC')]", ('Enviando', 'enviar', 'VERB'), ('obras', 'obra', 'NOUN')]]
#
# [[('mujer', 'mujer', 'NOUN'), ('piadosa', 'piadoso', 'ADJ'), "[('Fragmentos', 'MISC')]"]]
#
# [["[('Desvarío', 'MISC')]"]]
#
# [["[('Soneto', 'PER')]", ('Gloria', 'gloria', 'PROPN'), ('pobreza', 'pobreza', 'NOUN'), "[('inmortal Quintana...', 'MISC')]"]]
#
# [["[('Balada', 'PER')]", ('despedida', 'despedida', 'NOUN'), ('hija', 'hija', 'NOUN')]]
#
# [[('viaje', 'viaje', 'NOUN'), "[('Luna', 'MISC')]", ('Prólogo', 'prólogo', 'NOUN'), ('pesadilla', 'pesadilla', 'PROPN'), "[('Mocquet', 'PER')]"]]
#
# [[('álbum', 'álbum', 'NOUN'), "[('señora M…', 'PER')]"]]
#
# [[('primavera', 'primavera', 'NOUN')]]
#
# [[('perejilera', 'perejilera', 'NOUN')]]
#
# [[('viaje', 'viaje', 'NOUN'), "[('Luna', 'MISC')]", ('Continuación', 'continuación', 'NOUN')]]

# %%
with open("FINAL_CATEGORIES.txt", "a") as f:
  for element in pro_lem_cleaned:
    f.write(str(element)+"\n")

# %%
#pro_lem_cleaned[:388]
import csv

with open("FINAL_CATEGORIES.csv", "w", newline="", encoding="utf-8") as f:
  writer = csv.writer(f)
  writer.writerow(["Categorías"])
  for element in pro_lem_cleaned[:388]:
    writer.writerow([str(element)])

# %%
''' con = sqlite3.connect("proyectoPura.db")
cur = con.cursor()

cur.execute("""
CREATE TABLE Titles_Obras_Complementos_2
(ID_título TEXT, Título TEXT,
ID_NumRevista INTEGER, ID_Autor INTEGER, Num_row INTEGER PRIMARY KEY AUTOINCREMENT)
""")

with open("MERGED.csv","r", encoding="utf-8") as file:
  csv_reader = csv.reader(file)
  next(csv_reader) #ignoring head row
  for row in csv_reader:
    cur.execute("INSERT INTO Titles_Obras_Complementos (ID_título, Título, ID_NumRevista, ID_Autor) VALUES (?, ?, ?, ?)", row)

con.commit()
con.close()

# %%
con = sqlite3.connect("ProyectoPura_Javier.db")
cur = con.cursor()

cur.execute("""
CREATE TABLE Categorías_RAW_Javier
(Categorías)
""")

with open("FINAL_CATEGORIES.csv","r", encoding="utf-8") as file:
  csv_reader = csv.reader(file)
  next(csv_reader) #ignoring head row
  for row in csv_reader:
    cur.execute("INSERT INTO Categorías_RAW_Javier (Categorías) VALUES (?)", row)

con.commit()
con.close()

# %%
from collections import Counter

lema_freq = Counter()

for element in pro_lem_cleaned:
  for titulo_ in element:
    for cat in titulo_:
      if isinstance(cat, tuple):
        lema_freq.update([cat[1]])
        #lema_freq.update([cat[0]])

lema_freq.most_common()
# Out:
# [('revista', 65),
#  ('moda', 39),
#  ('mes', 19),
#  ('casa', 18),
#  ('histórico', 18),
#  ('figurín', 16),
#  ('explicación', 14),
#  ('teatro', 12),
#  ('continuación', 11),
#  ('crónica', 10),
#  ('parisiense', 10),
#  ('cabello', 9),
#  ('recomendado', 9),
#  ('particular', 9),
#  ('dentista', 9),
#  ('viaje', 8),
#  ('álbum', 8),
#  ('día', 8),
#  ('mujer', 7),
#  ('primero', 7),
#  ('señora', 7),
#  ('madre', 7),
#  ('abanico', 7),
#  ('paráume', 7),
#  ('joyas', 7),
#  ('novela', 6),
#  ('duelo', 6),
#  ('cintas', 6),
#  ('pasamanería', 6),
#  ('fábrica', 6),
#  ('amor', 5),
#  ('obras', 5),
#  ('salón', 5),
#  ('niña', 4),
#  ('costumbres', 4),
#  ('hacer', 4),
#  ('carta', 4),
#  ('introducción', 4),
#  ('costumbre', 4),
#  ('baile', 4),
#  ('secreto', 4),
#  ('descripción', 4),
#  ('cartas', 4),
#  ('princpio', 4),
#  ('fin', 4),
#  ('moneda', 4),
#  ('oro', 4),
#  ('bretono', 3),
#  ('Conclusión', 3),
#  ('amigo', 3),
#  ('lector', 3),
#  ('curso', 3),
#  ('familiar', 3),
#  ('literatura', 3),
#  ('inglés', 3),
#  ('siguiente', 3),
#  ('vestido', 3),
#  ('emperador', 3),
#  ('general', 3),
#  ('hermosura', 3),
#  ('hermana', 3),
#  ('cuadro', 3),
#  ('conuco', 3),
#  ('indio', 3),
#  ('contemporáneo', 3),
#  ('marquesa', 3),
#  ('Continuación', 3),
#  ('histórico-política', 3),
#  ('prólogo', 2),
#  ('señor', 2),
#  ('fragmentos', 2),
#  ('alma', 2),
#  ('año', 2),
#  ('mucho', 2),
#  ('periódico', 2),
#  ('francés', 2),
#  ('matrimonio', 2),
#  ('ejército', 2),
#  ('Fragmentos', 2),
#  ('artículo', 2),
#  ('andaluza', 2),
#  ('boda', 2),
#  ('fotografía', 2),
#  ('flor', 2),
#  ('tumba', 2),
#  ('nuevo', 2),
#  ('señorita', 2),
#  ('ángel', 2),
#  ('no', 2),
#  ('felicidad', 2),
#  ('duelos', 2),
#  ('lugar', 2),
#  ('poesía', 2),
#  ('oportunidad', 2),
#  ('objeto', 2),
#  ('episodio', 2),
#  ('anuncio', 2),
#  ('feria', 2),
#  ('mundo', 2),
#  ('estudios', 2),
#  ('tiempo', 2),
#  ('pecas', 2),
#  ('mancha', 2),
#  ('cara', 2),
#  ('lámina', 2),
#  ('tapicería', 2),
#  ('traje', 2),
#  ('enviar', 1),
#  ('obra', 1),
#  ('piadoso', 1),
#  ('gloria', 1),
#  ('pobreza', 1),
#  ('despedida', 1),
#  ('hija', 1),
#  ('pesadilla', 1),
#  ('primavera', 1),
#  ('perejilera', 1),
#  ('orilla', 1),
#  ('súplica', 1),
#  ('gente', 1),
#  ('moreno', 1),
#  ('excmo', 1),
#  ('santo', 1),
#  ('cumpleaños', 1),
#  ('esconder', 1),
#  ('tapada', 1),
#  ('apreciable', 1),
#  ('amiga', 1),
#  ('otoño', 1),
#  ('aún', 1),
#  ('eco', 1),
#  ('tener', 1),
#  ('atentado', 1),
#  ('banquero', 1),
#  ('rico', 1),
#  ('extranjero', 1),
#  ('buen', 1),
#  ('distinguir', 1),
#  ('escritor', 1),
#  ('don', 1),
#  ('prueba', 1),
#  ('sincero', 1),
#  ('amistad', 1),
#  ('luna', 1),
#  ('apariencia', 1),
#  ('engañar', 1),
#  ('historia-cuento', 1),
#  ('sábado', 1),
#  ('hablar', 1),
#  ('círculo', 1),
#  ('aristocrático', 1),
#  ('invierno', 1),
#  ('hada', 1),
#  ('azul', 1),
#  ('lunes', 1),
#  ('corriente', 1),
#  ('inaugurar', 1),
#  ('ir', 1),
#  ('contar', 1),
#  ('historia', 1),
#  ('ocurrir', 1),
#  ('Pascua', 1),
#  ('generalísimo', 1),
#  ('otomano', 1),
#  ('navío', 1),
#  ('ayes', 1),
#  ('corazón', 1),
#  ('pedir', 1),
#  ('trata', 1),
#  ('decadencia', 1),
#  ('recibir', 1),
#  ('gobierno', 1),
#  ('consignar', 1),
#  ('acarta', 1),
#  ('original', 1),
#  ('enos', 1),
#  ('dirigir', 1),
#  ('raza', 1),
#  ('latino', 1),
#  ('república', 1),
#  ('pintura', 1),
#  ('perro', 1),
#  ('serenatas', 1),
#  ('venir', 1),
#  ('periodista', 1),
#  ('suceder', 1),
#  ('alrededor', 1),
#  ('máxima', 1),
#  ('recordar', 1),
#  ('hotel', 1),
#  ('abertura', 1),
#  ('río', 1),
#  ('sra', 1),
#  ('marzo', 1),
#  ('leyenda', 1),
#  ('pastoral', 1),
#  ('dalia', 1),
#  ('semana', 1),
#  ('diario', 1),
#  ('aquí', 1),
#  ('anécdota', 1),
#  ('curioso', 1),
#  ('decir', 1),
#  ('vilain', 1),
#  ('marinero', 1),
#  ('príncipe', 1),
#  ('miércoles', 1),
#  ('ceniza', 1),
#  ('adelanto', 1),
#  ('acabar', 1),
#  ('llegar', 1),
#  ('mayo', 1),
#  ('rededpr', 1),
#  ('conclusiones', 1),
#  ('ver', 1),
#  ('principal', 1),
#  ('interés', 1),
#  ('amortización', 1),
#  ('público', 1),
#  ('oso', 1),
#  ('perfil', 1),
#  ('ostra', 1),
#  ('cementerio', 1),
#  ('consideraciones', 1),
#  ('Gran', 1),
#  ('batalla', 1),
#  ('emperatriz', 1),
#  ('proclamar', 1),
#  ('entrevista', 1),
#  ('detalle', 1),
#  ('mayor', 1),
#  ('candil', 1),
#  ('festín', 1),
#  ('estudio', 1),
#  ('bíblico', 1),
#  ('quincena', 1),
#  ('agosto', 1),
#  ('débil', 1),
#  ('muestra', 1),
#  ('aprecio', 1),
#  ('cifra', 1),
#  ('ciprés', 1),
#  ('composición', 1),
#  ('ópera', 1),
#  ('robo', 1),
#  ('niño', 1),
#  ('granadino', 1),
#  ('Marcha', 1),
#  ('guerrera', 1),
#  ('genio', 1),
#  ('coro', 1),
#  ('kaleidescopio', 1),
#  ('origen', 1),
#  ('instrumento', 1),
#  ('guitarra', 1),
#  ('l', 1),
#  ('vuelta', 1),
#  ('golondrina', 1),
#  ('sauce', 1),
#  ('cuaresma', 1),
#  ('mejor', 1),
#  ('museo', 1),
#  ('viviente', 1),
#  ('colección', 1),
#  ('social', 1),
#  ('oliva', 1),
#  ('paz', 1),
#  ('inclusa', 1),
#  ('espejo', 1),
#  ('mágico', 1),
#  ('cuento', 1),
#  ('fantástico', 1),
#  ('pasado', 1),
#  ('hallar', 1),
#  ('bosque', 1),
#  ('resistir', 1),
#  ('deseo', 1),
#  ('copiar', 1),
#  ('cama', 1),
#  ('manga', 1),
#  ('largo', 1),
#  ('heredad', 1),
#  ('bendecido', 1),
#  ('ascensión', 1),
#  ('fe', 1),
#  ('rosa', 1),
#  ('sobrina', 1),
#  ('mensage', 1),
#  ('caricia', 1),
#  ('curar', 1),
#  ('defecto', 1),
#  ('arte', 1),
#  ('dama', 1),
#  ('galanteado', 1),
#  ('toque', 1),
#  ('oración', 1),
#  ('bail', 1),
#  ('campestre', 1),
#  ('tradición', 1),
#  ('tocador', 1),
#  ('ilusión', 1),
#  ('violeta', 1),
#  ('verdad', 1),
#  ('sentimiento', 1),
#  ('aventura', 1),
#  ('numeroso', 1),
#  ('notable', 1),
#  ('dominación', 1),
#  ('pájaro', 1),
#  ('matrimonios', 1),
#  ('baño', 1),
#  ('más', 1),
#  ('paseo', 1),
#  ('lago', 1),
#  ('negro', 1),
#  ('suelto', 1),
#  ('duquesa', 1),
#  ('octogenario', 1),
#  ('aldeana', 1),
#  ('enriquecer', 1),
#  ('escalera', 1),
#  ('duda', 1),
#  ('istmo', 1),
#  ('peregrinación', 1),
#  ('destino', 1),
#  ('haber', 1),
#  ('proverbio', 1),
#  ('sombrero', 1),
#  ('lentigo', 1),
#  ('tratamiento', 1),
#  ('página', 1),
#  ('última', 1),
#  ('hora', 1),
#  ('constituido', 1),
#  ('ya', 1),
#  ('oficialmente', 1),
#  ('parte', 1),
#  ('oficial', 1),
#  ('publicado', 1),
#  ('atalla', 1),
#  ('censo', 1),
#  ('aproximativo', 1),
#  ('leer', 1),
#  ('fauno', 1),
#  ('collar', 1),
#  ('rubio', 1),
#  ('esposa', 1),
#  ('sol', 1),
#  ('inauguración', 1),
#  ('conclusión', 1),
#  ('abnegación', 1),
#  ('perfumería', 1),
#  ('recomendar', 1),
#  ('piano', 1),
#  ('enfermedad', 1),
#  ('pecho', 1),
#  ('prevenir', 1),
#  ('alquilar', 1),
#  ('lindísimo', 1),
#  ('habitación', 1),
#  ('voga', 1),
#  ('Corsets', 1),
#  ('plastiques', 1),
#  ('Guantes', 1),
#  ('et', 1),
#  ('antephelique', 1),
#  ('tintura', 1),
#  ('instantáneo', 1),
#  ('segundo', 1),
#  ('novia', 1),
#  ('visita', 1)]

# %%
with open("LEMA_FREQ.txt", "w") as f:
  for el in lema_freq.most_common():
    f.write(str(el)+"\n")

# %%
ner_freq = Counter()

for element in pro_lem_cleaned:
  for titulo_ in element:
    for cat in titulo_:
      if isinstance(cat, str):
        if "[(" in cat:
          for match in re.finditer(r"\[\('([^']+)',\s*'[^']+'\)\]", cat):
          #for match in re.findinter(r"\[\('([^']+)',\s*'([^']+)'\)\]", cat): #group(2) the type of NER
            #print(match.group(0))
            #print(match.group(1))
            ##lema_freq.update([match.group(0)])
            ner_freq.update([match.group(1)])
            #lema_freq.update([cat[0]])

ner_freq.most_common()
# Out:
# [('Revista de Madrid', 18),
#  ('Revista de París', 13),
#  ('Platería Cristofle', 11),
#  ('Revista Parisiense', 11),
#  ('Camisas Claudio', 9),
#  ('Hermanos', 9),
#  ('Huéspedes', 9),
#  ('Casa Delacroix', 9),
#  ('Jules Bloch', 9),
#  ('Nueva Geografía Sangansan', 8),
#  ('Soneto', 7),
#  ('Faguer Labollée', 7),
#  ('Lemnnier', 7),
#  ('Sorré Dehsle', 6),
#  ('Corsets plastiques de Bonvallet', 6),
#  ('Guantes', 6),
#  ('Poesía', 5),
#  ('doña Emilia Serrano de Wilson', 5),
#  ('Revista Parisense', 5),
#  ('Luna', 4),
#  ('Cuba', 4),
#  ('Tarifs des insertions', 4),
#  ('Balada', 3),
#  ('Margarita', 3),
#  ('Paraguay', 3),
#  ('Napoleón III', 3),
#  ('Velázquez', 3),
#  ('Fragmentos', 2),
#  ('Margarita Aurora de Wilson', 2),
#  ('Serrano', 2),
#  ('Oda', 2),
#  ('M. de Lamartine', 2),
#  ('Brasil', 2),
#  ('Leopoldo Robert', 2),
#  ('Estados-Unidos', 2),
#  ('Conclusión', 2),
#  ('Memorándum especial por la guerra de Italia', 2),
#  ('Solferino', 2),
#  ('María Leczinska', 2),
#  ('Griseldina', 2),
#  ('Periquito el Veleidoso', 2),
#  ('Santo Domingo', 2),
#  ('Sevilla', 2),
#  ('Ucles', 2),
#  ('Rusia', 2),
#  ('Sombreros De Alexandrine', 2),
#  ('Bonvallet', 2),
#  ('Eco Hispano-Americano', 2),
#  ('Sr. D. R. P.', 1),
#  ('Desvarío', 1),
#  ('inmortal Quintana...', 1),
#  ('Mocquet', 1),
#  ('señora M…', 1),
#  ('Don B. M.', 1),
#  ('Manzanares', 1),
#  ('de la Rosa de Alejandra', 1),
#  ('Sr. D. Agustín Esteban Collantes', 1),
#  ('Señora doña M. Del Pilar Sinués de Marco', 1),
#  ('María', 1),
#  ('Alteza Real', 1),
#  ('Príncipe de Asturias', 1),
#  ('SS. MM. II', 1),
#  ('El matrimonio de la Princesa real de Inglaterra [...]', 1),
#  ('Alejandro Dumas', 1),
#  ('SS.', 1),
#  ('AA. [...', 1),
#  ('El príncipe Mirza-Ally-Kan-Bahadoor [...]', 1),
#  ('Ismail', 1),
#  ('Leviatán', 1),
#  ('Isabel II', 1),
#  ('Hamlet', 1),
#  ('Malibran', 1),
#  ('Londres', 1),
#  ('Porvenir', 1),
#  ('Francia', 1),
#  ('Nuevo-Mundo', 1),
#  ('Confederación Argentina', 1),
#  ('Uruguay-Le Paraguay', 1),
#  ('S. M. La emperatriz de los franceses', 1),
#  ('Zurbarán', 1),
#  ('Filadelfia', 1),
#  ('Ville', 1),
#  ('Escma', 1),
#  ('Dª Gertrudis Gómez de Avellaneda', 1),
#  ('Leemos en el Monitor  [...]', 1),
#  ('Alto', 1),
#  ('Bajo Rin', 1),
#  ('El matrimonio del hijo mayor [...]', 1),
#  ('Savonnette', 1),
#  ('Ramón de la Sagra', 1),
#  ('SS. AA. II', 1),
#  ('princesa Napoleón', 1),
#  ('San Petesburgo', 1),
#  ('El Entreacto publica un acarta fechada en Génova', 1),
#  ('Pbro', 1),
#  ('D. Félix Varela', 1),
#  ('catedral de Bron', 1),
#  ('Artículo II', 1),
#  ('Deuda', 1),
#  ('M. Alejandro Dumas', 1),
#  ('Carta del Sr.', 1),
#  ('Guillemot', 1),
#  ('Víctor Manuel II', 1),
#  ('Mariano G. Manrique', 1),
#  ('Montmartre', 1),
#  ('Fragmento', 1),
#  ('Batalla de Solferino', 1),
#  ('Ejército de Italia', 1),
#  ('Villafranca', 1),
#  ('mariscal Vaillant', 1),
#  ('Italia', 1),
#  ('S. M.', 1),
#  ('Baltasar', 1),
#  ('Garibaldi', 1),
#  ('Señora Doña Emilia Serrano de Wilson', 1),
#  ('Offland', 1),
#  ('doña María Verdejo', 1),
#  ('Durán', 1),
#  ('Otello', 1),
#  ('Rossini', 1),
#  ('señora Hua', 1),
#  ('doña Carolina Coronado', 1),
#  ('niña Adelaida', 1),
#  ('Esther', 1),
#  ('Tetuán', 1),
#  ('doña Eulogia', 1),
#  ('España', 1),
#  ('Marruecos', 1),
#  ('D. José Piquer', 1),
#  ('Cojimar', 1),
#  ('La ópera de Verdi [...]', 1),
#  ('El marqués de Casa-Riera [...]', 1),
#  ('Dolora', 1),
#  ('Colón', 1),
#  ('Macahé', 1),
#  ('Emilia', 1),
#  ('Señor', 1),
#  ('Araceli Abril de Armendi', 1),
#  ('Soledad', 1),
#  ('Santander', 1),
#  ('Conclusion', 1),
#  ('Allende los mares mora [...]', 1),
#  ('doña Emila Serrano de Wilson', 1),
#  ('J. R.', 1),
#  ('Rolandseck', 1),
#  ('marquesa', 1),
#  ('SS. MM', 1),
#  ('Mariquita', 1),
#  ('Bonaparte', 1),
#  ('sargento Pérez', 1),
#  ('Biarritz', 1),
#  ('Carta I. Monserrat', 1),
#  ('Fábula', 1),
#  ('Carta II', 1),
#  ('Valencia', 1),
#  ('La señora de J [...]', 1),
#  ('El señor X [...]', 1),
#  ('Carta III', 1),
#  ('Barcelona', 1),
#  ('Panamá', 1),
#  ('Saint-Point', 1),
#  ('Austria', 1),
#  ('Feria', 1),
#  ('Francisco José', 1),
#  ('Emperador del Austria', 1),
#  ('Ministerio Inglés', 1),
#  ('Monitor de París', 1),
#  ('Invento-Histórico', 1),
#  ('N.', 1),
#  ('señora **', 1),
#  ('Goysevox', 1),
#  ('D. José Piquer-Oda', 1),
#  ('Alzad vuestras tumbas [...]', 1),
#  ('Safo', 1),
#  ('Sombreros de Alexandrine', 1),
#  ('Planchais [...]', 1),
#  ('Casa de comisión para París [...]', 1),
#  ('Corsets Plastiques Mme', 1),
#  ('Porcelaines', 1),
#  ('Lait', 1),
#  ('Gaceta de Bellas Artes', 1),
#  ('Porta-monedas Despierres', 1),
#  ('Modes de Paris', 1),
#  ('Petit Courrier des Dames', 1),
#  ('Moda de Caballeros', 1),
#  ('Segundo', 1),
#  ('Teatros', 1)]

# %%
with open("NER_FREQ.txt", "w") as f:
  for el in ner_freq.most_common():
    f.write(str(el)+"\n")

# %%
lem_dic = dict(lema_freq.most_common())
lem_dic
# Out:
# {'revista': 65,
#  'moda': 39,
#  'mes': 19,
#  'casa': 18,
#  'histórico': 18,
#  'figurín': 16,
#  'explicación': 14,
#  'teatro': 12,
#  'continuación': 11,
#  'crónica': 10,
#  'parisiense': 10,
#  'cabello': 9,
#  'recomendado': 9,
#  'particular': 9,
#  'dentista': 9,
#  'viaje': 8,
#  'álbum': 8,
#  'día': 8,
#  'mujer': 7,
#  'primero': 7,
#  'señora': 7,
#  'madre': 7,
#  'abanico': 7,
#  'paráume': 7,
#  'joyas': 7,
#  'novela': 6,
#  'duelo': 6,
#  'cintas': 6,
#  'pasamanería': 6,
#  'fábrica': 6,
#  'amor': 5,
#  'obras': 5,
#  'salón': 5,
#  'niña': 4,
#  'costumbres': 4,
#  'hacer': 4,
#  'carta': 4,
#  'introducción': 4,
#  'costumbre': 4,
#  'baile': 4,
#  'secreto': 4,
#  'descripción': 4,
#  'cartas': 4,
#  'princpio': 4,
#  'fin': 4,
#  'moneda': 4,
#  'oro': 4,
#  'bretono': 3,
#  'Conclusión': 3,
#  'amigo': 3,
#  'lector': 3,
#  'curso': 3,
#  'familiar': 3,
#  'literatura': 3,
#  'inglés': 3,
#  'siguiente': 3,
#  'vestido': 3,
#  'emperador': 3,
#  'general': 3,
#  'hermosura': 3,
#  'hermana': 3,
#  'cuadro': 3,
#  'conuco': 3,
#  'indio': 3,
#  'contemporáneo': 3,
#  'marquesa': 3,
#  'Continuación': 3,
#  'histórico-política': 3,
#  'prólogo': 2,
#  'señor': 2,
#  'fragmentos': 2,
#  'alma': 2,
#  'año': 2,
#  'mucho': 2,
#  'periódico': 2,
#  'francés': 2,
#  'matrimonio': 2,
#  'ejército': 2,
#  'Fragmentos': 2,
#  'artículo': 2,
#  'andaluza': 2,
#  'boda': 2,
#  'fotografía': 2,
#  'flor': 2,
#  'tumba': 2,
#  'nuevo': 2,
#  'señorita': 2,
#  'ángel': 2,
#  'no': 2,
#  'felicidad': 2,
#  'duelos': 2,
#  'lugar': 2,
#  'poesía': 2,
#  'oportunidad': 2,
#  'objeto': 2,
#  'episodio': 2,
#  'anuncio': 2,
#  'feria': 2,
#  'mundo': 2,
#  'estudios': 2,
#  'tiempo': 2,
#  'pecas': 2,
#  'mancha': 2,
#  'cara': 2,
#  'lámina': 2,
#  'tapicería': 2,
#  'traje': 2,
#  'enviar': 1,
#  'obra': 1,
#  'piadoso': 1,
#  'gloria': 1,
#  'pobreza': 1,
#  'despedida': 1,
#  'hija': 1,
#  'pesadilla': 1,
#  'primavera': 1,
#  'perejilera': 1,
#  'orilla': 1,
#  'súplica': 1,
#  'gente': 1,
#  'moreno': 1,
#  'excmo': 1,
#  'santo': 1,
#  'cumpleaños': 1,
#  'esconder': 1,
#  'tapada': 1,
#  'apreciable': 1,
#  'amiga': 1,
#  'otoño': 1,
#  'aún': 1,
#  'eco': 1,
#  'tener': 1,
#  'atentado': 1,
#  'banquero': 1,
#  'rico': 1,
#  'extranjero': 1,
#  'buen': 1,
#  'distinguir': 1,
#  'escritor': 1,
#  'don': 1,
#  'prueba': 1,
#  'sincero': 1,
#  'amistad': 1,
#  'luna': 1,
#  'apariencia': 1,
#  'engañar': 1,
#  'historia-cuento': 1,
#  'sábado': 1,
#  'hablar': 1,
#  'círculo': 1,
#  'aristocrático': 1,
#  'invierno': 1,
#  'hada': 1,
#  'azul': 1,
#  'lunes': 1,
#  'corriente': 1,
#  'inaugurar': 1,
#  'ir': 1,
#  'contar': 1,
#  'historia': 1,
#  'ocurrir': 1,
#  'Pascua': 1,
#  'generalísimo': 1,
#  'otomano': 1,
#  'navío': 1,
#  'ayes': 1,
#  'corazón': 1,
#  'pedir': 1,
#  'trata': 1,
#  'decadencia': 1,
#  'recibir': 1,
#  'gobierno': 1,
#  'consignar': 1,
#  'acarta': 1,
#  'original': 1,
#  'enos': 1,
#  'dirigir': 1,
#  'raza': 1,
#  'latino': 1,
#  'república': 1,
#  'pintura': 1,
#  'perro': 1,
#  'serenatas': 1,
#  'venir': 1,
#  'periodista': 1,
#  'suceder': 1,
#  'alrededor': 1,
#  'máxima': 1,
#  'recordar': 1,
#  'hotel': 1,
#  'abertura': 1,
#  'río': 1,
#  'sra': 1,
#  'marzo': 1,
#  'leyenda': 1,
#  'pastoral': 1,
#  'dalia': 1,
#  'semana': 1,
#  'diario': 1,
#  'aquí': 1,
#  'anécdota': 1,
#  'curioso': 1,
#  'decir': 1,
#  'vilain': 1,
#  'marinero': 1,
#  'príncipe': 1,
#  'miércoles': 1,
#  'ceniza': 1,
#  'adelanto': 1,
#  'acabar': 1,
#  'llegar': 1,
#  'mayo': 1,
#  'rededpr': 1,
#  'conclusiones': 1,
#  'ver': 1,
#  'principal': 1,
#  'interés': 1,
#  'amortización': 1,
#  'público': 1,
#  'oso': 1,
#  'perfil': 1,
#  'ostra': 1,
#  'cementerio': 1,
#  'consideraciones': 1,
#  'Gran': 1,
#  'batalla': 1,
#  'emperatriz': 1,
#  'proclamar': 1,
#  'entrevista': 1,
#  'detalle': 1,
#  'mayor': 1,
#  'candil': 1,
#  'festín': 1,
#  'estudio': 1,
#  'bíblico': 1,
#  'quincena': 1,
#  'agosto': 1,
#  'débil': 1,
#  'muestra': 1,
#  'aprecio': 1,
#  'cifra': 1,
#  'ciprés': 1,
#  'composición': 1,
#  'ópera': 1,
#  'robo': 1,
#  'niño': 1,
#  'granadino': 1,
#  'Marcha': 1,
#  'guerrera': 1,
#  'genio': 1,
#  'coro': 1,
#  'kaleidescopio': 1,
#  'origen': 1,
#  'instrumento': 1,
#  'guitarra': 1,
#  'l': 1,
#  'vuelta': 1,
#  'golondrina': 1,
#  'sauce': 1,
#  'cuaresma': 1,
#  'mejor': 1,
#  'museo': 1,
#  'viviente': 1,
#  'colección': 1,
#  'social': 1,
#  'oliva': 1,
#  'paz': 1,
#  'inclusa': 1,
#  'espejo': 1,
#  'mágico': 1,
#  'cuento': 1,
#  'fantástico': 1,
#  'pasado': 1,
#  'hallar': 1,
#  'bosque': 1,
#  'resistir': 1,
#  'deseo': 1,
#  'copiar': 1,
#  'cama': 1,
#  'manga': 1,
#  'largo': 1,
#  'heredad': 1,
#  'bendecido': 1,
#  'ascensión': 1,
#  'fe': 1,
#  'rosa': 1,
#  'sobrina': 1,
#  'mensage': 1,
#  'caricia': 1,
#  'curar': 1,
#  'defecto': 1,
#  'arte': 1,
#  'dama': 1,
#  'galanteado': 1,
#  'toque': 1,
#  'oración': 1,
#  'bail': 1,
#  'campestre': 1,
#  'tradición': 1,
#  'tocador': 1,
#  'ilusión': 1,
#  'violeta': 1,
#  'verdad': 1,
#  'sentimiento': 1,
#  'aventura': 1,
#  'numeroso': 1,
#  'notable': 1,
#  'dominación': 1,
#  'pájaro': 1,
#  'matrimonios': 1,
#  'baño': 1,
#  'más': 1,
#  'paseo': 1,
#  'lago': 1,
#  'negro': 1,
#  'suelto': 1,
#  'duquesa': 1,
#  'octogenario': 1,
#  'aldeana': 1,
#  'enriquecer': 1,
#  'escalera': 1,
#  'duda': 1,
#  'istmo': 1,
#  'peregrinación': 1,
#  'destino': 1,
#  'haber': 1,
#  'proverbio': 1,
#  'sombrero': 1,
#  'lentigo': 1,
#  'tratamiento': 1,
#  'página': 1,
#  'última': 1,
#  'hora': 1,
#  'constituido': 1,
#  'ya': 1,
#  'oficialmente': 1,
#  'parte': 1,
#  'oficial': 1,
#  'publicado': 1,
#  'atalla': 1,
#  'censo': 1,
#  'aproximativo': 1,
#  'leer': 1,
#  'fauno': 1,
#  'collar': 1,
#  'rubio': 1,
#  'esposa': 1,
#  'sol': 1,
#  'inauguración': 1,
#  'conclusión': 1,
#  'abnegación': 1,
#  'perfumería': 1,
#  'recomendar': 1,
#  'piano': 1,
#  'enfermedad': 1,
#  'pecho': 1,
#  'prevenir': 1,
#  'alquilar': 1,
#  'lindísimo': 1,
#  'habitación': 1,
#  'voga': 1,
#  'Corsets': 1,
#  'plastiques': 1,
#  'Guantes': 1,
#  'et': 1,
#  'antephelique': 1,
#  'tintura': 1,
#  'instantáneo': 1,
#  'segundo': 1,
#  'novia': 1,
#  'visita': 1}

# %%
ner_dic = dict(ner_freq.most_common())
ner_dic
# Out:
# {'Revista de Madrid': 18,
#  'Revista de París': 13,
#  'Platería Cristofle': 11,
#  'Revista Parisiense': 11,
#  'Camisas Claudio': 9,
#  'Hermanos': 9,
#  'Huéspedes': 9,
#  'Casa Delacroix': 9,
#  'Jules Bloch': 9,
#  'Nueva Geografía Sangansan': 8,
#  'Soneto': 7,
#  'Faguer Labollée': 7,
#  'Lemnnier': 7,
#  'Sorré Dehsle': 6,
#  'Corsets plastiques de Bonvallet': 6,
#  'Guantes': 6,
#  'Poesía': 5,
#  'doña Emilia Serrano de Wilson': 5,
#  'Revista Parisense': 5,
#  'Luna': 4,
#  'Cuba': 4,
#  'Tarifs des insertions': 4,
#  'Balada': 3,
#  'Margarita': 3,
#  'Paraguay': 3,
#  'Napoleón III': 3,
#  'Velázquez': 3,
#  'Fragmentos': 2,
#  'Margarita Aurora de Wilson': 2,
#  'Serrano': 2,
#  'Oda': 2,
#  'M. de Lamartine': 2,
#  'Brasil': 2,
#  'Leopoldo Robert': 2,
#  'Estados-Unidos': 2,
#  'Conclusión': 2,
#  'Memorándum especial por la guerra de Italia': 2,
#  'Solferino': 2,
#  'María Leczinska': 2,
#  'Griseldina': 2,
#  'Periquito el Veleidoso': 2,
#  'Santo Domingo': 2,
#  'Sevilla': 2,
#  'Ucles': 2,
#  'Rusia': 2,
#  'Sombreros De Alexandrine': 2,
#  'Bonvallet': 2,
#  'Eco Hispano-Americano': 2,
#  'Sr. D. R. P.': 1,
#  'Desvarío': 1,
#  'inmortal Quintana...': 1,
#  'Mocquet': 1,
#  'señora M…': 1,
#  'Don B. M.': 1,
#  'Manzanares': 1,
#  'de la Rosa de Alejandra': 1,
#  'Sr. D. Agustín Esteban Collantes': 1,
#  'Señora doña M. Del Pilar Sinués de Marco': 1,
#  'María': 1,
#  'Alteza Real': 1,
#  'Príncipe de Asturias': 1,
#  'SS. MM. II': 1,
#  'El matrimonio de la Princesa real de Inglaterra [...]': 1,
#  'Alejandro Dumas': 1,
#  'SS.': 1,
#  'AA. [...': 1,
#  'El príncipe Mirza-Ally-Kan-Bahadoor [...]': 1,
#  'Ismail': 1,
#  'Leviatán': 1,
#  'Isabel II': 1,
#  'Hamlet': 1,
#  'Malibran': 1,
#  'Londres': 1,
#  'Porvenir': 1,
#  'Francia': 1,
#  'Nuevo-Mundo': 1,
#  'Confederación Argentina': 1,
#  'Uruguay-Le Paraguay': 1,
#  'S. M. La emperatriz de los franceses': 1,
#  'Zurbarán': 1,
#  'Filadelfia': 1,
#  'Ville': 1,
#  'Escma': 1,
#  'Dª Gertrudis Gómez de Avellaneda': 1,
#  'Leemos en el Monitor  [...]': 1,
#  'Alto': 1,
#  'Bajo Rin': 1,
#  'El matrimonio del hijo mayor [...]': 1,
#  'Savonnette': 1,
#  'Ramón de la Sagra': 1,
#  'SS. AA. II': 1,
#  'princesa Napoleón': 1,
#  'San Petesburgo': 1,
#  'El Entreacto publica un acarta fechada en Génova': 1,
#  'Pbro': 1,
#  'D. Félix Varela': 1,
#  'catedral de Bron': 1,
#  'Artículo II': 1,
#  'Deuda': 1,
#  'M. Alejandro Dumas': 1,
#  'Carta del Sr.': 1,
#  'Guillemot': 1,
#  'Víctor Manuel II': 1,
#  'Mariano G. Manrique': 1,
#  'Montmartre': 1,
#  'Fragmento': 1,
#  'Batalla de Solferino': 1,
#  'Ejército de Italia': 1,
#  'Villafranca': 1,
#  'mariscal Vaillant': 1,
#  'Italia': 1,
#  'S. M.': 1,
#  'Baltasar': 1,
#  'Garibaldi': 1,
#  'Señora Doña Emilia Serrano de Wilson': 1,
#  'Offland': 1,
#  'doña María Verdejo': 1,
#  'Durán': 1,
#  'Otello': 1,
#  'Rossini': 1,
#  'señora Hua': 1,
#  'doña Carolina Coronado': 1,
#  'niña Adelaida': 1,
#  'Esther': 1,
#  'Tetuán': 1,
#  'doña Eulogia': 1,
#  'España': 1,
#  'Marruecos': 1,
#  'D. José Piquer': 1,
#  'Cojimar': 1,
#  'La ópera de Verdi [...]': 1,
#  'El marqués de Casa-Riera [...]': 1,
#  'Dolora': 1,
#  'Colón': 1,
#  'Macahé': 1,
#  'Emilia': 1,
#  'Señor': 1,
#  'Araceli Abril de Armendi': 1,
#  'Soledad': 1,
#  'Santander': 1,
#  'Conclusion': 1,
#  'Allende los mares mora [...]': 1,
#  'doña Emila Serrano de Wilson': 1,
#  'J. R.': 1,
#  'Rolandseck': 1,
#  'marquesa': 1,
#  'SS. MM': 1,
#  'Mariquita': 1,
#  'Bonaparte': 1,
#  'sargento Pérez': 1,
#  'Biarritz': 1,
#  'Carta I. Monserrat': 1,
#  'Fábula': 1,
#  'Carta II': 1,
#  'Valencia': 1,
#  'La señora de J [...]': 1,
#  'El señor X [...]': 1,
#  'Carta III': 1,
#  'Barcelona': 1,
#  'Panamá': 1,
#  'Saint-Point': 1,
#  'Austria': 1,
#  'Feria': 1,
#  'Francisco José': 1,
#  'Emperador del Austria': 1,
#  'Ministerio Inglés': 1,
#  'Monitor de París': 1,
#  'Invento-Histórico': 1,
#  'N.': 1,
#  'señora **': 1,
#  'Goysevox': 1,
#  'D. José Piquer-Oda': 1,
#  'Alzad vuestras tumbas [...]': 1,
#  'Safo': 1,
#  'Sombreros de Alexandrine': 1,
#  'Planchais [...]': 1,
#  'Casa de comisión para París [...]': 1,
#  'Corsets Plastiques Mme': 1,
#  'Porcelaines': 1,
#  'Lait': 1,
#  'Gaceta de Bellas Artes': 1,
#  'Porta-monedas Despierres': 1,
#  'Modes de Paris': 1,
#  'Petit Courrier des Dames': 1,
#  'Moda de Caballeros': 1,
#  'Segundo': 1,
#  'Teatros': 1}

# %%
import re
from collections import Counter

all_results = []  # Final list: (document_id, category, form, origin, frequency)

for idx, element in enumerate(pro_lem_cleaned):
    document_id = f"OB{idx+1}"

    # === Lemmas ===
    lemma_pairs = []
    for titulo_ in element:
        for cat in titulo_:
            if isinstance(cat, tuple):
                lemma_pairs.append(cat)  # ('lemma', 'form')

    lemma_counter = Counter(lemma_pairs)
    for lemma, freq in lemma_counter.items():
        all_results.append((document_id, lemma, 'LEMMA', freq))

    # === NERs ===
    ner_matches = []
    for titulo_ in element:
        for cat in titulo_:
            if isinstance(cat, str) and "[(" in cat:
                for match in re.finditer(r"\[\('([^']+)',\s*'[^']+'\)\]", cat):
                    entity = match.group(1)
                    ner_matches.append((entity, entity))  # we assume form = entity for now

    ner_counter = Counter(ner_matches)
    for (entity, form), freq in ner_counter.items():
        all_results.append((document_id, entity, form, 'NER', freq))

# === Preview ===
for row in all_results:
    print(row)
# Out:
# ('OB1', ('Enviando', 'enviar', 'VERB'), 'LEMMA', 1)
# ('OB1', ('obras', 'obra', 'NOUN'), 'LEMMA', 1)
# ('OB1', 'Sr. D. R. P.', 'Sr. D. R. P.', 'NER', 1)
# ('OB2', ('mujer', 'mujer', 'NOUN'), 'LEMMA', 1)
# ('OB2', ('piadosa', 'piadoso', 'ADJ'), 'LEMMA', 1)
# ('OB2', 'Fragmentos', 'Fragmentos', 'NER', 1)
# ('OB3', 'Desvarío', 'Desvarío', 'NER', 1)
# ('OB4', ('Gloria', 'gloria', 'PROPN'), 'LEMMA', 1)
# ('OB4', ('pobreza', 'pobreza', 'NOUN'), 'LEMMA', 1)
# ('OB4', 'Soneto', 'Soneto', 'NER', 1)
# ('OB4', 'inmortal Quintana...', 'inmortal Quintana...', 'NER', 1)
# ('OB5', ('despedida', 'despedida', 'NOUN'), 'LEMMA', 1)
# ('OB5', ('hija', 'hija', 'NOUN'), 'LEMMA', 1)
# ('OB5', 'Balada', 'Balada', 'NER', 1)
# ('OB6', ('viaje', 'viaje', 'NOUN'), 'LEMMA', 1)
# ('OB6', ('Prólogo', 'prólogo', 'NOUN'), 'LEMMA', 1)
# ('OB6', ('pesadilla', 'pesadilla', 'PROPN'), 'LEMMA', 1)
# ('OB6', 'Luna', 'Luna', 'NER', 1)
# ('OB6', 'Mocquet', 'Mocquet', 'NER', 1)
# ('OB7', ('álbum', 'álbum', 'NOUN'), 'LEMMA', 1)
# ('OB7', 'señora M…', 'señora M…', 'NER', 1)
# ('OB8', ('primavera', 'primavera', 'NOUN'), 'LEMMA', 1)
# ('OB9', ('perejilera', 'perejilera', 'NOUN'), 'LEMMA', 1)
# ('OB10', ('viaje', 'viaje', 'NOUN'), 'LEMMA', 1)
# ('OB10', ('Continuación', 'continuación', 'NOUN'), 'LEMMA', 1)
# ('OB10', 'Luna', 'Luna', 'NER', 1)
# ('OB11', ('señor', 'señor', 'NOUN'), 'LEMMA', 1)
# ('OB11', 'Don B. M.', 'Don B. M.', 'NER', 1)
# ('OB12', ('orillas', 'orilla', 'NOUN'), 'LEMMA', 1)
# ('OB12', ('súplica', 'súplica', 'NOUN'), 'LEMMA', 1)
# ('OB12', 'Manzanares', 'Manzanares', 'NER', 1)
# ('OB13', ('viaje', 'viaje', 'NOUN'), 'LEMMA', 1)
# ('OB13', ('Continuación', 'continuación', 'NOUN'), 'LEMMA', 1)
# ('OB13', 'Luna', 'Luna', 'NER', 1)
# ('OB14', ('Fragmentos', 'fragmentos', 'NOUN'), 'LEMMA', 1)
# ('OB14', 'de la Rosa de Alejandra', 'de la Rosa de Alejandra', 'NER', 1)
# ('OB15', ('Gente', 'gente', 'NOUN'), 'LEMMA', 1)
# ('OB15', ('morena', 'moreno', 'ADJ'), 'LEMMA', 1)
# ('OB16', ('viaje', 'viaje', 'NOUN'), 'LEMMA', 1)
# ('OB16', ('Continuación', 'continuación', 'NOUN'), 'LEMMA', 1)
# ('OB16', 'Luna', 'Luna', 'NER', 1)
# ('OB17', ('excmo', 'excmo', 'NOUN'), 'LEMMA', 1)
# ('OB17', ('día', 'día', 'NOUN'), 'LEMMA', 1)
# ('OB17', ('santo', 'santo', 'NOUN'), 'LEMMA', 1)
# ('OB17', 'Sr. D. Agustín Esteban Collantes', 'Sr. D. Agustín Esteban Collantes', 'NER', 1)
# ('OB18', ('niña', 'niña', 'NOUN'), 'LEMMA', 1)
# ('OB18', ('día', 'día', 'NOUN'), 'LEMMA', 1)
# ('OB18', ('cumpleaños', 'cumpleaños', 'NOUN'), 'LEMMA', 1)
# ('OB18', 'Margarita Aurora de Wilson', 'Margarita Aurora de Wilson', 'NER', 1)
# ('OB18', 'Serrano', 'Serrano', 'NER', 1)
# ('OB19', ('Costumbres', 'costumbres', 'NOUN'), 'LEMMA', 1)
# ('OB20', ('Novela', 'novela', 'NOUN'), 'LEMMA', 1)
# ('OB20', ('bretona', 'bretono', 'ADJ'), 'LEMMA', 1)
# ('OB20', 'Margarita', 'Margarita', 'NER', 1)
# ('OB21', ('escondidos', 'esconder', 'ADJ'), 'LEMMA', 1)
# ('OB21', ('tapada', 'tapada', 'NOUN'), 'LEMMA', 1)
# ('OB21', ('Fragmentos', 'fragmentos', 'NOUN'), 'LEMMA', 1)
# ('OB22', ('apreciable', 'apreciable', 'ADJ'), 'LEMMA', 1)
# ('OB22', ('amiga', 'amiga', 'NOUN'), 'LEMMA', 1)
# ('OB22', ('álbum', 'álbum', 'NOUN'), 'LEMMA', 1)
# ('OB22', 'Señora doña M. Del Pilar Sinués de Marco', 'Señora doña M. Del Pilar Sinués de Marco', 'NER', 1)
# ('OB23', ('Costumbres', 'costumbres', 'NOUN'), 'LEMMA', 1)
# ('OB24', ('Novela', 'novela', 'NOUN'), 'LEMMA', 1)
# ('OB24', ('bretona', 'bretono', 'ADJ'), 'LEMMA', 1)
# ('OB24', ('Continuación', 'continuación', 'NOUN'), 'LEMMA', 1)
# ('OB24', 'Margarita', 'Margarita', 'NER', 1)
# ('OB25', ('niña', 'niña', 'NOUN'), 'LEMMA', 1)
# ('OB25', 'Margarita Aurora de Wilson', 'Margarita Aurora de Wilson', 'NER', 1)
# ('OB25', 'Serrano', 'Serrano', 'NER', 1)
# ('OB26', 'María', 'María', 'NER', 1)
# ('OB27', 'Alteza Real', 'Alteza Real', 'NER', 1)
# ('OB27', 'Príncipe de Asturias', 'Príncipe de Asturias', 'NER', 1)
# ('OB28', ('Novela', 'novela', 'NOUN'), 'LEMMA', 1)
# ('OB28', ('bretona', 'bretono', 'ADJ'), 'LEMMA', 1)
# ('OB28', ('Conclusión', 'Conclusión', 'PROPN'), 'LEMMA', 1)
# ('OB28', 'Margarita', 'Margarita', 'NER', 1)
# ('OB29', ('otoño', 'otoño', 'NOUN'), 'LEMMA', 1)
# ('OB30', ('Aún', 'aún', 'ADV'), 'LEMMA', 1)
# ('OB30', ('eco', 'eco', 'NOUN'), 'LEMMA', 1)
# ('OB30', ('tienen', 'tener', 'VERB'), 'LEMMA', 1)
# ('OB30', ('alma', 'alma', 'NOUN'), 'LEMMA', 1)
# ('OB30', 'Soneto', 'Soneto', 'NER', 1)
# ('OB31', ('Atentado', 'atentado', 'NOUN'), 'LEMMA', 1)
# ('OB31', 'SS. MM. II', 'SS. MM. II', 'NER', 1)
# ('OB32', ('Hace', 'hacer', 'VERB'), 'LEMMA', 1)
# ('OB32', ('años', 'año', 'NOUN'), 'LEMMA', 1)
# ('OB32', ('banquero', 'banquero', 'NOUN'), 'LEMMA', 1)
# ('OB32', ('muy', 'mucho', 'ADV'), 'LEMMA', 1)
# ('OB32', ('rico', 'rico', 'ADJ'), 'LEMMA', 1)
# ('OB32', ('periódicos', 'periódico', 'NOUN'), 'LEMMA', 1)
# ('OB32', ('franceses', 'francés', 'ADJ'), 'LEMMA', 1)
# ('OB32', ('extranjero', 'extranjero', 'NOUN'), 'LEMMA', 1)
# ('OB32', 'El matrimonio de la Princesa real de Inglaterra [...]', 'El matrimonio de la Princesa real de Inglaterra [...]', 'NER', 1)
# ('OB33', 'Poesía', 'Poesía', 'NER', 1)
# ('OB33', 'Oda', 'Oda', 'NER', 1)
# ('OB34', ('buen', 'buen', 'ADJ'), 'LEMMA', 1)
# ('OB34', ('amigo', 'amigo', 'NOUN'), 'LEMMA', 1)
# ('OB34', ('distinguido', 'distinguir', 'ADJ'), 'LEMMA', 1)
# ('OB34', ('escritor', 'escritor', 'NOUN'), 'LEMMA', 1)
# ('OB34', ('don', 'don', 'ADJ'), 'LEMMA', 1)
# ('OB34', ('prueba', 'prueba', 'NOUN'), 'LEMMA', 1)
# ('OB34', ('sincera', 'sincero', 'ADJ'), 'LEMMA', 1)
# ('OB34', ('amistad', 'amistad', 'NOUN'), 'LEMMA', 1)
# ('OB34', 'Alejandro Dumas', 'Alejandro Dumas', 'NER', 1)
# ('OB35', ('luna', 'luna', 'NOUN'), 'LEMMA', 1)
# ('OB35', 'Soneto', 'Soneto', 'NER', 1)
# ('OB36', ('apariencias', 'apariencia', 'NOUN'), 'LEMMA', 1)
# ('OB36', ('engañan', 'engañar', 'VERB'), 'LEMMA', 1)
# ('OB36', ('Historia-cuento', 'historia-cuento', 'NOUN'), 'LEMMA', 1)
# ('OB37', ('viaje', 'viaje', 'NOUN'), 'LEMMA', 1)
# ('OB37', ('sábado', 'sábado', 'NOUN'), 'LEMMA', 1)
# ('OB37', ('Habláse', 'hablar', 'VERB'), 'LEMMA', 1)
# ('OB37', ('círculos', 'círculo', 'NOUN'), 'LEMMA', 1)
# ('OB37', ('aristocrático', 'aristocrático', 'ADJ'), 'LEMMA', 1)
# ('OB37', ('matrimonio', 'matrimonio', 'NOUN'), 'LEMMA', 1)
# ('OB37', 'SS.', 'SS.', 'NER', 1)
# ('OB37', 'AA. [...', 'AA. [...', 'NER', 1)
# ('OB37', 'El príncipe Mirza-Ally-Kan-Bahadoor [...]', 'El príncipe Mirza-Ally-Kan-Bahadoor [...]', 'NER', 1)
# ('OB38', ('invierno', 'invierno', 'NOUN'), 'LEMMA', 1)
# ('OB39', ('hada', 'hada', 'NOUN'), 'LEMMA', 1)
# ('OB39', ('azul', 'azul', 'ADJ'), 'LEMMA', 1)
# ('OB40', ('lunes', 'lunes', 'NOUN'), 'LEMMA', 1)
# ('OB40', ('corriente', 'corriente', 'NOUN'), 'LEMMA', 1)
# ('OB40', ('inaugurado', 'inaugurar', 'VERB'), 'LEMMA', 1)
# ('OB40', ('Vamos', 'ir', 'VERB'), 'LEMMA', 1)
# ('OB40', ('contar', 'contar', 'VERB'), 'LEMMA', 1)
# ('OB40', ('historia', 'historia', 'NOUN'), 'LEMMA', 1)
# ('OB40', ('ocurrida', 'ocurrir', 'ADJ'), 'LEMMA', 1)
# ('OB40', ('días', 'día', 'NOUN'), 'LEMMA', 1)
# ('OB40', ('Pascua', 'Pascua', 'PROPN'), 'LEMMA', 1)
# ('OB40', ('generalísimo', 'generalísimo', 'ADJ'), 'LEMMA', 1)
# ('OB40', ('ejército', 'ejército', 'NOUN'), 'LEMMA', 1)
# ('OB40', ('otomano', 'otomano', 'ADJ'), 'LEMMA', 1)
# ('OB40', 'Ismail', 'Ismail', 'NER', 1)
# ('OB41', ('navío', 'navío', 'NOUN'), 'LEMMA', 1)
# ('OB41', 'Leviatán', 'Leviatán', 'NER', 1)
# ('OB42', ('Ayes', 'ayes', 'PROPN'), 'LEMMA', 1)
# ('OB42', ('corazón', 'corazón', 'NOUN'), 'LEMMA', 1)
# ('OB43', ('Carta', 'carta', 'NOUN'), 'LEMMA', 1)
# ('OB43', 'M. de Lamartine', 'M. de Lamartine', 'NER', 1)
# ('OB44', ('Introducción', 'introducción', 'NOUN'), 'LEMMA', 1)
# ('OB45', 'Isabel II', 'Isabel II', 'NER', 1)
# ('OB46', 'Hamlet', 'Hamlet', 'NER', 1)
# ('OB47', ('lector', 'lector', 'NOUN'), 'LEMMA', 1)
# ('OB47', ('pide', 'pedir', 'VERB'), 'LEMMA', 1)
# ('OB47', ('trata', 'trata', 'NOUN'), 'LEMMA', 1)
# ('OB47', ('decadencia', 'decadencia', 'NOUN'), 'LEMMA', 1)
# ('OB47', ('costumbres', 'costumbre', 'NOUN'), 'LEMMA', 1)
# ('OB47', ('recibía', 'recibir', 'VERB'), 'LEMMA', 1)
# ('OB47', ('gobierno', 'gobierno', 'NOUN'), 'LEMMA', 1)
# ('OB47', 'Malibran', 'Malibran', 'NER', 1)
# ('OB47', 'Londres', 'Londres', 'NER', 1)
# ('OB47', 'Brasil', 'Brasil', 'NER', 1)
# ('OB48', ('Consignamos', 'consignar', 'VERB'), 'LEMMA', 1)
# ('OB48', ('acarta', 'acarta', 'NOUN'), 'LEMMA', 1)
# ('OB48', ('original', 'original', 'ADJ'), 'LEMMA', 1)
# ('OB48', ('enos', 'enos', 'NOUN'), 'LEMMA', 1)
# ('OB48', ('dirigido', 'dirigir', 'VERB'), 'LEMMA', 1)
# ('OB48', 'M. de Lamartine', 'M. de Lamartine', 'NER', 1)
# ('OB49', ('raza', 'raza', 'NOUN'), 'LEMMA', 1)
# ('OB49', ('latina', 'latino', 'ADJ'), 'LEMMA', 1)
# ('OB49', ('Introducción', 'introducción', 'NOUN'), 'LEMMA', 1)
# ('OB49', 'Porvenir', 'Porvenir', 'NER', 1)
# ('OB49', 'Francia', 'Francia', 'NER', 1)
# ('OB49', 'Nuevo-Mundo', 'Nuevo-Mundo', 'NER', 1)
# ('OB50', ('república', 'república', 'NOUN'), 'LEMMA', 1)
# ('OB50', 'Confederación Argentina', 'Confederación Argentina', 'NER', 1)
# ('OB50', 'Uruguay-Le Paraguay', 'Uruguay-Le Paraguay', 'NER', 1)
# ('OB51', 'S. M. La emperatriz de los franceses', 'S. M. La emperatriz de los franceses', 'NER', 1)
# ('OB52', ('Cursos', 'curso', 'NOUN'), 'LEMMA', 1)
# ('OB52', ('familiares', 'familiar', 'ADJ'), 'LEMMA', 1)
# ('OB52', ('literatura', 'literatura', 'NOUN'), 'LEMMA', 1)
# ('OB52', ('pintura', 'pintura', 'NOUN'), 'LEMMA', 1)
# ('OB53', ('perro', 'perro', 'NOUN'), 'LEMMA', 1)
# ('OB53', 'Zurbarán', 'Zurbarán', 'NER', 1)
# ('OB54', ('Serenatas', 'serenatas', 'PROPN'), 'LEMMA', 1)
# ('OB54', ('Introducción', 'introducción', 'NOUN'), 'LEMMA', 1)
# ('OB54', ('Fragmentos', 'Fragmentos', 'PROPN'), 'LEMMA', 1)
# ('OB55', ('viene', 'venir', 'VERB'), 'LEMMA', 1)
# ('OB55', ('periodista', 'periodista', 'NOUN'), 'LEMMA', 1)
# ('OB55', ('inglés', 'inglés', 'ADJ'), 'LEMMA', 1)
# ('OB55', ('sucedido', 'suceder', 'VERB'), 'LEMMA', 1)
# ('OB55', ('alrededores', 'alrededor', 'NOUN'), 'LEMMA', 1)
# ('OB55', ('Máximas', 'máxima', 'ADJ'), 'LEMMA', 1)
# ('OB55', 'Filadelfia', 'Filadelfia', 'NER', 1)
# ('OB56', ('Recuerdo', 'recordar', 'VERB'), 'LEMMA', 1)
# ('OB56', ('baile', 'baile', 'NOUN'), 'LEMMA', 1)
# ('OB56', ('hotel', 'hotel', 'NOUN'), 'LEMMA', 1)
# ('OB56', 'Ville', 'Ville', 'NER', 1)
# ('OB57', ('Abertura', 'abertura', 'NOUN'), 'LEMMA', 1)
# ('OB57', ('ríos', 'río', 'NOUN'), 'LEMMA', 1)
# ('OB57', 'Paraguay', 'Paraguay', 'NER', 1)
# ('OB58', ('Sra', 'sra', 'PROPN'), 'LEMMA', 1)
# ('OB58', 'Escma', 'Escma', 'NER', 1)
# ('OB58', 'Dª Gertrudis Gómez de Avellaneda', 'Dª Gertrudis Gómez de Avellaneda', 'NER', 1)
# ('OB59', ('marzo', 'marzo', 'PROPN'), 'LEMMA', 1)
# ('OB60', ('Cursos', 'curso', 'NOUN'), 'LEMMA', 1)
# ('OB60', ('familiares', 'familiar', 'ADJ'), 'LEMMA', 1)
# ('OB60', ('literatura', 'literatura', 'NOUN'), 'LEMMA', 1)
# ('OB60', 'Leopoldo Robert', 'Leopoldo Robert', 'NER', 1)
# ('OB61', ('Leyenda', 'leyenda', 'NOUN'), 'LEMMA', 1)
# ('OB61', ('pastoral', 'pastoral', 'ADJ'), 'LEMMA', 1)
# ('OB62', ('dalia', 'dalia', 'NOUN'), 'LEMMA', 1)
# ('OB63', ('Hace', 'hacer', 'VERB'), 'LEMMA', 1)
# ('OB63', ('semanas', 'semana', 'NOUN'), 'LEMMA', 1)
# ('OB63', ('diarios', 'diario', 'NOUN'), 'LEMMA', 1)
# ('OB63', ('aquí', 'aquí', 'ADV'), 'LEMMA', 1)
# ('OB63', ('siguiente', 'siguiente', 'ADJ'), 'LEMMA', 1)
# ('OB63', ('anécdota', 'anécdota', 'NOUN'), 'LEMMA', 1)
# ('OB63', ('curioso', 'curioso', 'ADJ'), 'LEMMA', 1)
# ('OB63', ('dicho', 'decir', 'VERB'), 'LEMMA', 1)
# ('OB63', ('vilain', 'vilain', 'NOUN'), 'LEMMA', 1)
# ('OB63', 'Leemos en el Monitor  [...]', 'Leemos en el Monitor  [...]', 'NER', 1)
# ('OB63', 'Alto', 'Alto', 'NER', 1)
# ('OB63', 'Bajo Rin', 'Bajo Rin', 'NER', 1)
# ('OB63', 'El matrimonio del hijo mayor [...]', 'El matrimonio del hijo mayor [...]', 'NER', 1)
# ('OB63', 'Savonnette', 'Savonnette', 'NER', 1)
# ('OB64', ('Carta', 'carta', 'NOUN'), 'LEMMA', 1)
# ('OB64', 'Ramón de la Sagra', 'Ramón de la Sagra', 'NER', 1)
# ('OB65', ('Artículo', 'artículo', 'NOUN'), 'LEMMA', 1)
# ('OB65', 'Estados-Unidos', 'Estados-Unidos', 'NER', 1)
# ('OB65', 'Paraguay', 'Paraguay', 'NER', 1)
# ('OB66', ('Costumbres', 'costumbres', 'NOUN'), 'LEMMA', 1)
# ('OB66', ('andaluzas', 'andaluza', 'ADJ'), 'LEMMA', 1)
# ('OB66', ('marineros', 'marinero', 'NOUN'), 'LEMMA', 1)
# ('OB67', ('Viaje', 'viaje', 'NOUN'), 'LEMMA', 1)
# ('OB67', ('vestido', 'vestido', 'NOUN'), 'LEMMA', 1)
# ('OB67', ('boda', 'boda', 'NOUN'), 'LEMMA', 1)
# ('OB68', ('príncipe', 'príncipe', 'NOUN'), 'LEMMA', 1)
# ('OB68', 'SS. AA. II', 'SS. AA. II', 'NER', 1)
# ('OB68', 'princesa Napoleón', 'princesa Napoleón', 'NER', 1)
# ('OB69', ('miércoles', 'miércoles', 'NOUN'), 'LEMMA', 1)
# ('OB69', ('ceniza', 'ceniza', 'NOUN'), 'LEMMA', 1)
# ('OB70', ('Cursos', 'curso', 'NOUN'), 'LEMMA', 1)
# ('OB70', ('familiares', 'familiar', 'ADJ'), 'LEMMA', 1)
# ('OB70', ('literatura', 'literatura', 'NOUN'), 'LEMMA', 1)
# ('OB70', 'Leopoldo Robert', 'Leopoldo Robert', 'NER', 1)
# ('OB70', 'Conclusión', 'Conclusión', 'NER', 1)
# ('OB71', ('días', 'día', 'NOUN'), 'LEMMA', 1)
# ('OB71', ('hacen', 'hacer', 'VERB'), 'LEMMA', 1)
# ('OB71', ('adelantos', 'adelanto', 'NOUN'), 'LEMMA', 1)
# ('OB71', ('fotografía', 'fotografía', 'NOUN'), 'LEMMA', 1)
# ('OB71', ('Acaba', 'acabar', 'VERB'), 'LEMMA', 1)
# ('OB71', ('llegar', 'llegar', 'VERB'), 'LEMMA', 1)
# ('OB71', 'San Petesburgo', 'San Petesburgo', 'NER', 1)
# ('OB71', 'El Entreacto publica un acarta fechada en Génova', 'El Entreacto publica un acarta fechada en Génova', 'NER', 1)
# ('OB72', 'Memorándum especial por la guerra de Italia', 'Memorándum especial por la guerra de Italia', 'NER', 1)
# ('OB73', ('Introducción', 'introducción', 'NOUN'), 'LEMMA', 1)
# ('OB74', 'Pbro', 'Pbro', 'NER', 1)
# ('OB74', 'D. Félix Varela', 'D. Félix Varela', 'NER', 1)
# ('OB75', ('flores', 'flor', 'NOUN'), 'LEMMA', 1)
# ('OB75', ('mayo', 'mayo', 'NOUN'), 'LEMMA', 1)
# ('OB76', 'catedral de Bron', 'catedral de Bron', 'NER', 1)
# ('OB78', ('Viaje', 'viaje', 'NOUN'), 'LEMMA', 1)
# ('OB78', ('rededpr', 'rededpr', 'NOUN'), 'LEMMA', 1)
# ('OB78', ('vestido', 'vestido', 'NOUN'), 'LEMMA', 1)
# ('OB78', ('boda', 'boda', 'NOUN'), 'LEMMA', 1)
# ('OB78', ('Conclusiones', 'conclusiones', 'NOUN'), 'LEMMA', 1)
# ('OB79', 'Artículo II', 'Artículo II', 'NER', 1)
# ('OB79', 'Estados-Unidos', 'Estados-Unidos', 'NER', 1)
# ('OB79', 'Paraguay', 'Paraguay', 'NER', 1)
# ('OB81', ('vea', 'ver', 'VERB'), 'LEMMA', 1)
# ('OB81', ('principales', 'principal', 'ADJ'), 'LEMMA', 1)
# ('OB81', ('intereses', 'interés', 'NOUN'), 'LEMMA', 1)
# ('OB81', ('amortización', 'amortización', 'NOUN'), 'LEMMA', 1)
# ('OB81', ('pública', 'público', 'ADJ'), 'LEMMA', 1)
# ('OB81', 'Deuda', 'Deuda', 'NER', 1)
# ('OB82', ('Carta', 'carta', 'NOUN'), 'LEMMA', 1)
# ('OB82', 'M. Alejandro Dumas', 'M. Alejandro Dumas', 'NER', 1)
# ('OB83', 'Carta del Sr.', 'Carta del Sr.', 'NER', 1)
# ('OB83', 'Guillemot', 'Guillemot', 'NER', 1)
# ('OB84', 'Napoleón III', 'Napoleón III', 'NER', 1)
# ('OB85', 'Víctor Manuel II', 'Víctor Manuel II', 'NER', 1)
# ('OB86', ('oso', 'oso', 'NOUN'), 'LEMMA', 1)
# ('OB87', ('amigo', 'amigo', 'NOUN'), 'LEMMA', 1)
# ('OB87', 'Poesía', 'Poesía', 'NER', 1)
# ('OB87', 'Mariano G. Manrique', 'Mariano G. Manrique', 'NER', 1)
# ('OB88', ('Perfil', 'perfil', 'NOUN'), 'LEMMA', 1)
# ('OB88', ('inglés', 'inglés', 'ADJ'), 'LEMMA', 1)
# ('OB89', ('ostra', 'ostra', 'NOUN'), 'LEMMA', 1)
# ('OB90', 'Poesía', 'Poesía', 'NER', 1)
# ('OB90', 'Napoleón III', 'Napoleón III', 'NER', 1)
# ('OB91', ('tumba', 'tumba', 'NOUN'), 'LEMMA', 1)
# ('OB91', ('cementerio', 'cementerio', 'NOUN'), 'LEMMA', 1)
# ('OB91', 'Montmartre', 'Montmartre', 'NER', 1)
# ('OB91', 'Fragmento', 'Fragmento', 'NER', 1)
# ('OB92', ('Consideraciones', 'consideraciones', 'NOUN'), 'LEMMA', 1)
# ('OB92', ('vestidos', 'vestido', 'NOUN'), 'LEMMA', 1)
# ('OB93', ('Gran', 'Gran', 'ADJ'), 'LEMMA', 1)
# ('OB93', ('batalla', 'batalla', 'NOUN'), 'LEMMA', 1)
# ('OB93', 'Solferino', 'Solferino', 'NER', 1)
# ('OB94', 'Memorándum especial por la guerra de Italia', 'Memorándum especial por la guerra de Italia', 'NER', 1)
# ('OB95', ('emperador', 'emperador', 'NOUN'), 'LEMMA', 1)
# ('OB95', ('emperatriz', 'emperatriz', 'NOUN'), 'LEMMA', 1)
# ('OB95', 'Batalla de Solferino', 'Batalla de Solferino', 'NER', 1)
# ('OB96', ('Proclama', 'proclamar', 'VERB'), 'LEMMA', 1)
# ('OB96', 'Ejército de Italia', 'Ejército de Italia', 'NER', 1)
# ('OB97', ('entrevista', 'entrevista', 'NOUN'), 'LEMMA', 1)
# ('OB97', ('Nuevos', 'nuevo', 'ADJ'), 'LEMMA', 1)
# ('OB97', ('detalles', 'detalle', 'NOUN'), 'LEMMA', 1)
# ('OB97', 'Villafranca', 'Villafranca', 'NER', 1)
# ('OB98', ('mayor', 'mayor', 'ADJ'), 'LEMMA', 1)
# ('OB98', ('general', 'general', 'NOUN'), 'LEMMA', 1)
# ('OB98', ('ejército', 'ejército', 'NOUN'), 'LEMMA', 1)
# ('OB98', 'mariscal Vaillant', 'mariscal Vaillant', 'NER', 1)
# ('OB98', 'Italia', 'Italia', 'NER', 1)
# ('OB99', ('Costumbres', 'costumbres', 'NOUN'), 'LEMMA', 1)
# ('OB99', ('andaluzas', 'andaluza', 'ADJ'), 'LEMMA', 1)
# ('OB99', ('baile', 'baile', 'NOUN'), 'LEMMA', 1)
# ('OB99', ('candil', 'candil', 'NOUN'), 'LEMMA', 1)
# ('OB99', 'Poesía', 'Poesía', 'NER', 1)
# ('OB100', ('emperador', 'emperador', 'NOUN'), 'LEMMA', 1)
# ('OB100', 'S. M.', 'S. M.', 'NER', 1)
# ('OB100', 'Napoleón III', 'Napoleón III', 'NER', 1)
# ('OB100', 'Fragmentos', 'Fragmentos', 'NER', 1)
# ('OB101', ('fotografía', 'fotografía', 'NOUN'), 'LEMMA', 1)
# ('OB102', ('festín', 'festín', 'NOUN'), 'LEMMA', 1)
# ('OB102', ('Estudio', 'estudio', 'NOUN'), 'LEMMA', 1)
# ('OB102', ('bíblico', 'bíblico', 'ADJ'), 'LEMMA', 1)
# ('OB102', 'Baltasar', 'Baltasar', 'NER', 1)
# ('OB104', ('primera', 'primero', 'ADJ'), 'LEMMA', 1)
# ('OB104', ('quincena', 'quincena', 'NOUN'), 'LEMMA', 1)
# ('OB104', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB104', ('agosto', 'agosto', 'PROPN'), 'LEMMA', 1)
# ('OB105', ('general', 'general', 'NOUN'), 'LEMMA', 1)
# ('OB105', 'Garibaldi', 'Garibaldi', 'NER', 1)
# ('OB106', ('días', 'día', 'NOUN'), 'LEMMA', 1)
# ('OB107', ('débil', 'débil', 'ADJ'), 'LEMMA', 1)
# ('OB107', ('muestra', 'muestra', 'NOUN'), 'LEMMA', 1)
# ('OB107', ('aprecio', 'aprecio', 'NOUN'), 'LEMMA', 1)
# ('OB107', 'Señora Doña Emilia Serrano de Wilson', 'Señora Doña Emilia Serrano de Wilson', 'NER', 1)
# ('OB108', 'Offland', 'Offland', 'NER', 1)
# ('OB109', ('señorita', 'señorita', 'NOUN'), 'LEMMA', 1)
# ('OB109', 'doña María Verdejo', 'doña María Verdejo', 'NER', 1)
# ('OB109', 'Durán', 'Durán', 'NER', 1)
# ('OB110', ('cifra', 'cifra', 'NOUN'), 'LEMMA', 1)
# ('OB110', ('ciprés', 'ciprés', 'NOUN'), 'LEMMA', 1)
# ('OB111', 'María Leczinska', 'María Leczinska', 'NER', 1)
# ('OB112', ('Composición', 'composición', 'NOUN'), 'LEMMA', 1)
# ('OB112', ('ópera', 'ópera', 'NOUN'), 'LEMMA', 1)
# ('OB112', 'Otello', 'Otello', 'NER', 1)
# ('OB112', 'Rossini', 'Rossini', 'NER', 1)
# ('OB113', ('robo', 'robo', 'NOUN'), 'LEMMA', 1)
# ('OB113', ('niño', 'niño', 'NOUN'), 'LEMMA', 1)
# ('OB113', 'señora Hua', 'señora Hua', 'NER', 1)
# ('OB114', ('señora', 'señora', 'NOUN'), 'LEMMA', 1)
# ('OB114', 'doña Carolina Coronado', 'doña Carolina Coronado', 'NER', 1)
# ('OB115', ('granadina', 'granadino', 'NOUN'), 'LEMMA', 1)
# ('OB115', ('Marcha', 'Marcha', 'NOUN'), 'LEMMA', 1)
# ('OB115', ('guerrera', 'guerrera', 'ADJ'), 'LEMMA', 1)
# ('OB116', ('genio', 'genio', 'NOUN'), 'LEMMA', 1)
# ('OB117', 'María Leczinska', 'María Leczinska', 'NER', 1)
# ('OB118', ('coro', 'coro', 'NOUN'), 'LEMMA', 1)
# ('OB118', ('ángeles', 'ángel', 'NOUN'), 'LEMMA', 1)
# ('OB119', ('kaleidescopio', 'kaleidescopio', 'NOUN'), 'LEMMA', 1)
# ('OB120', ('duelo', 'duelo', 'NOUN'), 'LEMMA', 1)
# ('OB120', ('mujeres', 'mujer', 'NOUN'), 'LEMMA', 1)
# ('OB121', ('secretos', 'secreto', 'NOUN'), 'LEMMA', 1)
# ('OB121', ('hermosura', 'hermosura', 'NOUN'), 'LEMMA', 1)
# ('OB122', ('día', 'día', 'NOUN'), 'LEMMA', 1)
# ('OB122', 'niña Adelaida', 'niña Adelaida', 'NER', 1)
# ('OB123', 'Esther', 'Esther', 'NER', 1)
# ('OB124', ('Origen', 'origen', 'NOUN'), 'LEMMA', 1)
# ('OB124', ('instrumentos', 'instrumento', 'NOUN'), 'LEMMA', 1)
# ('OB124', ('guitarra', 'guitarra', 'NOUN'), 'LEMMA', 1)
# ('OB125', 'Tetuán', 'Tetuán', 'NER', 1)
# ('OB126', ('duelo', 'duelo', 'NOUN'), 'LEMMA', 1)
# ('OB126', ('mujeres', 'mujer', 'NOUN'), 'LEMMA', 1)
# ('OB126', ('Continuación', 'continuación', 'NOUN'), 'LEMMA', 1)
# ('OB127', ('Secretos', 'secreto', 'NOUN'), 'LEMMA', 1)
# ('OB127', ('hermosura', 'hermosura', 'NOUN'), 'LEMMA', 1)
# ('OB127', ('Continuación', 'continuación', 'NOUN'), 'LEMMA', 1)
# ('OB128', ('L', 'l', 'PROPN'), 'LEMMA', 1)
# ('OB128', ('vuelta', 'vuelta', 'NOUN'), 'LEMMA', 1)
# ('OB128', ('golondrina', 'golondrina', 'NOUN'), 'LEMMA', 1)
# ('OB128', ('Fragmentos', 'Fragmentos', 'PROPN'), 'LEMMA', 1)
# ('OB129', ('duelo', 'duelo', 'NOUN'), 'LEMMA', 1)
# ('OB129', ('mujeres', 'mujer', 'NOUN'), 'LEMMA', 1)
# ('OB129', ('Continuación', 'continuación', 'NOUN'), 'LEMMA', 1)
# ('OB130', ('Secretos', 'secreto', 'NOUN'), 'LEMMA', 1)
# ('OB130', ('hermosura', 'hermosura', 'NOUN'), 'LEMMA', 1)
# ('OB130', ('Continuación', 'continuación', 'NOUN'), 'LEMMA', 1)
# ('OB131', ('sauce', 'sauce', 'NOUN'), 'LEMMA', 1)
# ('OB132', 'Balada', 'Balada', 'NER', 1)
# ('OB133', ('duelo', 'duelo', 'NOUN'), 'LEMMA', 1)
# ('OB133', ('mujeres', 'mujer', 'NOUN'), 'LEMMA', 1)
# ('OB133', ('Continuación', 'continuación', 'NOUN'), 'LEMMA', 1)
# ('OB134', ('hermana', 'hermana', 'NOUN'), 'LEMMA', 1)
# ('OB134', 'Velázquez', 'Velázquez', 'NER', 1)
# ('OB135', ('cuaresma', 'cuaresma', 'NOUN'), 'LEMMA', 1)
# ('OB135', ('amor', 'amor', 'NOUN'), 'LEMMA', 1)
# ('OB136', ('mejor', 'mejor', 'ADJ'), 'LEMMA', 1)
# ('OB136', ('niña', 'niña', 'NOUN'), 'LEMMA', 1)
# ('OB137', ('duelo', 'duelo', 'NOUN'), 'LEMMA', 1)
# ('OB137', ('mujeres', 'mujer', 'NOUN'), 'LEMMA', 1)
# ('OB137', ('Continuación', 'continuación', 'NOUN'), 'LEMMA', 1)
# ('OB138', ('museo', 'museo', 'NOUN'), 'LEMMA', 1)
# ('OB138', ('viviente', 'viviente', 'ADJ'), 'LEMMA', 1)
# ('OB138', ('colección', 'colección', 'NOUN'), 'LEMMA', 1)
# ('OB138', ('cuadros', 'cuadro', 'NOUN'), 'LEMMA', 1)
# ('OB138', ('sociales', 'social', 'ADJ'), 'LEMMA', 1)
# ('OB138', ('Cuadro', 'cuadro', 'NOUN'), 'LEMMA', 1)
# ('OB138', ('primero', 'primero', 'ADJ'), 'LEMMA', 1)
# ('OB138', 'doña Eulogia', 'doña Eulogia', 'NER', 1)
# ('OB139', ('hermana', 'hermana', 'NOUN'), 'LEMMA', 1)
# ('OB139', 'Velázquez', 'Velázquez', 'NER', 1)
# ('OB140', ('oliva', 'oliva', 'NOUN'), 'LEMMA', 1)
# ('OB140', ('paz', 'paz', 'NOUN'), 'LEMMA', 1)
# ('OB140', 'España', 'España', 'NER', 1)
# ('OB140', 'Marruecos', 'Marruecos', 'NER', 1)
# ('OB141', ('Descripción', 'descripción', 'NOUN'), 'LEMMA', 1)
# ('OB141', ('teatro', 'teatro', 'NOUN'), 'LEMMA', 1)
# ('OB141', 'D. José Piquer', 'D. José Piquer', 'NER', 1)
# ('OB142', ('duelo', 'duelo', 'NOUN'), 'LEMMA', 1)
# ('OB142', ('mujeres', 'mujer', 'NOUN'), 'LEMMA', 1)
# ('OB142', ('Continuación', 'continuación', 'NOUN'), 'LEMMA', 1)
# ('OB143', ('hermana', 'hermana', 'NOUN'), 'LEMMA', 1)
# ('OB143', 'Velázquez', 'Velázquez', 'NER', 1)
# ('OB144', ('ángel', 'ángel', 'NOUN'), 'LEMMA', 1)
# ('OB144', ('inclusa', 'inclusa', 'NOUN'), 'LEMMA', 1)
# ('OB145', ('espejos', 'espejo', 'NOUN'), 'LEMMA', 1)
# ('OB145', ('mágicos', 'mágico', 'ADJ'), 'LEMMA', 1)
# ('OB145', ('Cuento', 'cuento', 'NOUN'), 'LEMMA', 1)
# ('OB145', ('fantástico', 'fantástico', 'ADJ'), 'LEMMA', 1)
# ('OB146', ('Cartas', 'cartas', 'NOUN'), 'LEMMA', 1)
# ('OB146', 'Cuba', 'Cuba', 'NER', 1)
# ('OB146', 'Cojimar', 'Cojimar', 'NER', 1)
# ('OB147', ('Días', 'día', 'NOUN'), 'LEMMA', 1)
# ('OB147', ('pasados', 'pasado', 'ADJ'), 'LEMMA', 1)
# ('OB147', ('hallaba', 'hallar', 'VERB'), 'LEMMA', 1)
# ('OB147', ('bosque', 'bosque', 'NOUN'), 'LEMMA', 1)
# ('OB147', ('No', 'no', 'ADV'), 'LEMMA', 1)
# ('OB147', ('resistir', 'resistir', 'VERB'), 'LEMMA', 1)
# ('OB147', ('deseo', 'deseo', 'NOUN'), 'LEMMA', 1)
# ('OB147', ('copiar', 'copiar', 'VERB'), 'LEMMA', 1)
# ('OB147', 'La ópera de Verdi [...]', 'La ópera de Verdi [...]', 'NER', 1)
# ('OB147', 'El marqués de Casa-Riera [...]', 'El marqués de Casa-Riera [...]', 'NER', 1)
# ('OB148', ('cama', 'cama', 'NOUN'), 'LEMMA', 1)
# ('OB148', ('matrimonio', 'matrimonio', 'NOUN'), 'LEMMA', 1)
# ('OB148', 'Balada', 'Balada', 'NER', 1)
# ('OB149', ('tumbas', 'tumba', 'NOUN'), 'LEMMA', 1)
# ('OB149', 'Dolora', 'Dolora', 'NER', 1)
# ('OB150', 'Colón', 'Colón', 'NER', 1)
# ('OB151', ('madre', 'madre', 'NOUN'), 'LEMMA', 1)
# ('OB152', ('baile', 'baile', 'NOUN'), 'LEMMA', 1)
# ('OB152', ('manga', 'manga', 'NOUN'), 'LEMMA', 1)
# ('OB152', ('larga', 'largo', 'ADJ'), 'LEMMA', 1)
# ('OB153', ('heredad', 'heredad', 'NOUN'), 'LEMMA', 1)
# ('OB153', ('bendecida', 'bendecido', 'ADJ'), 'LEMMA', 1)
# ('OB155', 'Macahé', 'Macahé', 'NER', 1)
# ('OB156', ('álbum', 'álbum', 'NOUN'), 'LEMMA', 1)
# ('OB156', 'Emilia', 'Emilia', 'NER', 1)
# ('OB157', ('ascensión', 'ascensión', 'NOUN'), 'LEMMA', 1)
# ('OB157', 'Señor', 'Señor', 'NER', 1)
# ('OB158', ('madre', 'madre', 'NOUN'), 'LEMMA', 1)
# ('OB159', ('Cartas', 'cartas', 'NOUN'), 'LEMMA', 1)
# ('OB159', ('conuco', 'conuco', 'NOUN'), 'LEMMA', 1)
# ('OB159', ('indio', 'indio', 'NOUN'), 'LEMMA', 1)
# ('OB159', 'Cuba', 'Cuba', 'NER', 1)
# ('OB160', ('Amor', 'amor', 'NOUN'), 'LEMMA', 1)
# ('OB160', ('fe', 'fe', 'NOUN'), 'LEMMA', 1)
# ('OB161', ('rosas', 'rosa', 'NOUN'), 'LEMMA', 1)
# ('OB162', 'Griseldina', 'Griseldina', 'NER', 1)
# ('OB163', ('sobrina', 'sobrina', 'NOUN'), 'LEMMA', 1)
# ('OB163', 'Araceli Abril de Armendi', 'Araceli Abril de Armendi', 'NER', 1)
# ('OB164', ('mensage', 'mensage', 'NOUN'), 'LEMMA', 1)
# ('OB165', 'Griseldina', 'Griseldina', 'NER', 1)
# ('OB166', ('Cartas', 'cartas', 'NOUN'), 'LEMMA', 1)
# ('OB166', ('conuco', 'conuco', 'NOUN'), 'LEMMA', 1)
# ('OB166', ('indio', 'indio', 'NOUN'), 'LEMMA', 1)
# ('OB166', 'Cuba', 'Cuba', 'NER', 1)
# ('OB167', ('caricia', 'caricia', 'NOUN'), 'LEMMA', 1)
# ('OB167', ('curar', 'curar', 'VERB'), 'LEMMA', 1)
# ('OB167', ('defecto', 'defecto', 'NOUN'), 'LEMMA', 1)
# ('OB168', ('princpio', 'princpio', 'NOUN'), 'LEMMA', 1)
# ('OB168', ('fin', 'fin', 'NOUN'), 'LEMMA', 1)
# ('OB169', ('felicidad', 'felicidad', 'NOUN'), 'LEMMA', 1)
# ('OB170', ('álbum', 'álbum', 'NOUN'), 'LEMMA', 1)
# ('OB170', ('niña', 'niña', 'NOUN'), 'LEMMA', 1)
# ('OB171', ('arte', 'arte', 'NOUN'), 'LEMMA', 1)
# ('OB171', 'Oda', 'Oda', 'NER', 1)
# ('OB172', ('dama', 'dama', 'NOUN'), 'LEMMA', 1)
# ('OB172', ('muy', 'mucho', 'ADV'), 'LEMMA', 1)
# ('OB172', ('galanteada', 'galanteado', 'ADJ'), 'LEMMA', 1)
# ('OB172', ('álbum', 'álbum', 'NOUN'), 'LEMMA', 1)
# ('OB173', ('princpio', 'princpio', 'NOUN'), 'LEMMA', 1)
# ('OB173', ('fin', 'fin', 'NOUN'), 'LEMMA', 1)
# ('OB173', ('Novela', 'novela', 'NOUN'), 'LEMMA', 1)
# ('OB173', ('costumbres', 'costumbre', 'NOUN'), 'LEMMA', 1)
# ('OB173', ('contemporáneas', 'contemporáneo', 'ADJ'), 'LEMMA', 1)
# ('OB174', ('felicidad', 'felicidad', 'NOUN'), 'LEMMA', 1)
# ('OB175', 'Periquito el Veleidoso', 'Periquito el Veleidoso', 'NER', 1)
# ('OB176', ('Cartas', 'cartas', 'NOUN'), 'LEMMA', 1)
# ('OB176', ('conuco', 'conuco', 'NOUN'), 'LEMMA', 1)
# ('OB176', ('indio', 'indio', 'NOUN'), 'LEMMA', 1)
# ('OB176', 'Cuba', 'Cuba', 'NER', 1)
# ('OB177', 'Santo Domingo', 'Santo Domingo', 'NER', 1)
# ('OB178', ('toque', 'toque', 'NOUN'), 'LEMMA', 1)
# ('OB178', ('oración', 'oración', 'NOUN'), 'LEMMA', 1)
# ('OB179', 'Soledad', 'Soledad', 'NER', 1)
# ('OB180', ('princpio', 'princpio', 'NOUN'), 'LEMMA', 1)
# ('OB180', ('fin', 'fin', 'NOUN'), 'LEMMA', 1)
# ('OB180', ('Novela', 'novela', 'NOUN'), 'LEMMA', 1)
# ('OB180', ('costumbres', 'costumbre', 'NOUN'), 'LEMMA', 1)
# ('OB180', ('contemporáneas', 'contemporáneo', 'ADJ'), 'LEMMA', 1)
# ('OB181', ('bailes', 'bail', 'NOUN'), 'LEMMA', 1)
# ('OB181', ('campestres', 'campestre', 'ADJ'), 'LEMMA', 1)
# ('OB181', 'Santander', 'Santander', 'NER', 1)
# ('OB182', 'Periquito el Veleidoso', 'Periquito el Veleidoso', 'NER', 1)
# ('OB182', 'Conclusion', 'Conclusion', 'NER', 1)
# ('OB183', ('Duelos', 'duelos', 'NOUN'), 'LEMMA', 1)
# ('OB183', ('amor', 'amor', 'NOUN'), 'LEMMA', 1)
# ('OB184', 'Allende los mares mora [...]', 'Allende los mares mora [...]', 'NER', 1)
# ('OB185', ('señora', 'señora', 'NOUN'), 'LEMMA', 1)
# ('OB185', ('álbum', 'álbum', 'NOUN'), 'LEMMA', 1)
# ('OB185', 'doña Emila Serrano de Wilson', 'doña Emila Serrano de Wilson', 'NER', 1)
# ('OB186', ('álbum', 'álbum', 'NOUN'), 'LEMMA', 1)
# ('OB186', ('señorita', 'señorita', 'NOUN'), 'LEMMA', 1)
# ('OB186', 'J. R.', 'J. R.', 'NER', 1)
# ('OB187', ('Carta', 'carta', 'NOUN'), 'LEMMA', 1)
# ('OB188', ('lugar', 'lugar', 'NOUN'), 'LEMMA', 1)
# ('OB189', ('Duelos', 'duelos', 'NOUN'), 'LEMMA', 1)
# ('OB189', ('amor', 'amor', 'NOUN'), 'LEMMA', 1)
# ('OB189', ('Conclusión', 'Conclusión', 'PROPN'), 'LEMMA', 1)
# ('OB190', ('Tradición', 'tradición', 'NOUN'), 'LEMMA', 1)
# ('OB190', 'Rolandseck', 'Rolandseck', 'NER', 1)
# ('OB191', ('Secretos', 'secreto', 'NOUN'), 'LEMMA', 1)
# ('OB191', ('tocador', 'tocador', 'NOUN'), 'LEMMA', 1)
# ('OB192', ('madre', 'madre', 'NOUN'), 'LEMMA', 1)
# ('OB192', 'marquesa', 'marquesa', 'NER', 1)
# ('OB193', 'Poesía', 'Poesía', 'NER', 1)
# ('OB194', ('Ilusión', 'ilusión', 'NOUN'), 'LEMMA', 1)
# ('OB195', ('violeta', 'violeta', 'NOUN'), 'LEMMA', 1)
# ('OB195', 'Soneto', 'Soneto', 'NER', 1)
# ('OB196', ('verdad', 'verdad', 'NOUN'), 'LEMMA', 1)
# ('OB196', ('sentimiento', 'sentimiento', 'NOUN'), 'LEMMA', 1)
# ('OB197', ('poesía', 'poesía', 'NOUN'), 'LEMMA', 1)
# ('OB197', ('oportunidad', 'oportunidad', 'NOUN'), 'LEMMA', 1)
# ('OB197', ('objeto', 'objeto', 'NOUN'), 'LEMMA', 1)
# ('OB198', ('lugar', 'lugar', 'NOUN'), 'LEMMA', 1)
# ('OB198', ('Conclusión', 'Conclusión', 'PROPN'), 'LEMMA', 1)
# ('OB199', ('Viaje', 'viaje', 'NOUN'), 'LEMMA', 1)
# ('OB199', 'SS. MM', 'SS. MM', 'NER', 1)
# ('OB200', 'Mariquita', 'Mariquita', 'NER', 1)
# ('OB201', ('aventuras', 'aventura', 'NOUN'), 'LEMMA', 1)
# ('OB201', ('numerosas', 'numeroso', 'ADJ'), 'LEMMA', 1)
# ('OB201', ('general', 'general', 'NOUN'), 'LEMMA', 1)
# ('OB201', ('notable', 'notable', 'ADJ'), 'LEMMA', 1)
# ('OB201', ('siguiente', 'siguiente', 'ADJ'), 'LEMMA', 1)
# ('OB201', 'Bonaparte', 'Bonaparte', 'NER', 1)
# ('OB202', ('madre', 'madre', 'NOUN'), 'LEMMA', 1)
# ('OB202', ('marquesa', 'marquesa', 'NOUN'), 'LEMMA', 1)
# ('OB202', ('Continuación', 'Continuación', 'PROPN'), 'LEMMA', 1)
# ('OB203', ('Episodio', 'episodio', 'NOUN'), 'LEMMA', 1)
# ('OB203', ('dominación', 'dominación', 'NOUN'), 'LEMMA', 1)
# ('OB203', ('francesa', 'francés', 'ADJ'), 'LEMMA', 1)
# ('OB203', 'sargento Pérez', 'sargento Pérez', 'NER', 1)
# ('OB203', 'Santo Domingo', 'Santo Domingo', 'NER', 1)
# ('OB204', ('princpio', 'princpio', 'NOUN'), 'LEMMA', 1)
# ('OB204', ('fin', 'fin', 'NOUN'), 'LEMMA', 1)
# ('OB204', ('Novela', 'novela', 'NOUN'), 'LEMMA', 1)
# ('OB204', ('costumbres', 'costumbre', 'NOUN'), 'LEMMA', 1)
# ('OB204', ('contemporáneas', 'contemporáneo', 'ADJ'), 'LEMMA', 1)
# ('OB205', ('pájaros', 'pájaro', 'NOUN'), 'LEMMA', 1)
# ('OB206', ('flor', 'flor', 'NOUN'), 'LEMMA', 1)
# ('OB207', ('moneda', 'moneda', 'NOUN'), 'LEMMA', 1)
# ('OB207', ('oro', 'oro', 'NOUN'), 'LEMMA', 1)
# ('OB208', ('Matrimonios', 'matrimonios', 'NOUN'), 'LEMMA', 1)
# ('OB208', ('anuncios', 'anuncio', 'NOUN'), 'LEMMA', 1)
# ('OB208', ('baños', 'baño', 'NOUN'), 'LEMMA', 1)
# ('OB208', ('Hace', 'hacer', 'VERB'), 'LEMMA', 1)
# ('OB208', ('días', 'día', 'NOUN'), 'LEMMA', 1)
# ('OB208', 'Biarritz', 'Biarritz', 'NER', 1)
# ('OB209', ('madre', 'madre', 'NOUN'), 'LEMMA', 1)
# ('OB209', ('marquesa', 'marquesa', 'NOUN'), 'LEMMA', 1)
# ('OB209', ('Continuación', 'Continuación', 'PROPN'), 'LEMMA', 1)
# ('OB210', 'Sevilla', 'Sevilla', 'NER', 1)
# ('OB211', ('año', 'año', 'NOUN'), 'LEMMA', 1)
# ('OB211', ('más', 'más', 'ADV'), 'LEMMA', 1)
# ('OB211', 'Soneto', 'Soneto', 'NER', 1)
# ('OB212', 'Carta I. Monserrat', 'Carta I. Monserrat', 'NER', 1)
# ('OB213', ('moneda', 'moneda', 'NOUN'), 'LEMMA', 1)
# ('OB213', ('oro', 'oro', 'NOUN'), 'LEMMA', 1)
# ('OB214', ('paseo', 'paseo', 'NOUN'), 'LEMMA', 1)
# ('OB214', ('lago', 'lago', 'NOUN'), 'LEMMA', 1)
# ('OB214', ('negro', 'negro', 'ADJ'), 'LEMMA', 1)
# ('OB215', ('feria', 'feria', 'NOUN'), 'LEMMA', 1)
# ('OB215', 'Ucles', 'Ucles', 'NER', 1)
# ('OB216', ('madre', 'madre', 'NOUN'), 'LEMMA', 1)
# ('OB216', ('marquesa', 'marquesa', 'NOUN'), 'LEMMA', 1)
# ('OB216', ('Continuación', 'Continuación', 'PROPN'), 'LEMMA', 1)
# ('OB217', ('cabello', 'cabello', 'NOUN'), 'LEMMA', 1)
# ('OB217', ('suelto', 'suelto', 'ADJ'), 'LEMMA', 1)
# ('OB217', 'Fábula', 'Fábula', 'NER', 1)
# ('OB218', 'Carta II', 'Carta II', 'NER', 1)
# ('OB218', 'Valencia', 'Valencia', 'NER', 1)
# ('OB219', ('feria', 'feria', 'NOUN'), 'LEMMA', 1)
# ('OB219', 'Ucles', 'Ucles', 'NER', 1)
# ('OB220', ('poesía', 'poesía', 'NOUN'), 'LEMMA', 1)
# ('OB220', ('oportunidad', 'oportunidad', 'NOUN'), 'LEMMA', 1)
# ('OB220', ('objeto', 'objeto', 'NOUN'), 'LEMMA', 1)
# ('OB221', ('moneda', 'moneda', 'NOUN'), 'LEMMA', 1)
# ('OB221', ('oro', 'oro', 'NOUN'), 'LEMMA', 1)
# ('OB222', ('duquesa', 'duquesa', 'NOUN'), 'LEMMA', 1)
# ('OB222', ('octogenaria', 'octogenario', 'ADJ'), 'LEMMA', 1)
# ('OB222', ('aldeana', 'aldeana', 'NOUN'), 'LEMMA', 1)
# ('OB222', ('enriquecida', 'enriquecer', 'ADJ'), 'LEMMA', 1)
# ('OB222', 'La señora de J [...]', 'La señora de J [...]', 'NER', 1)
# ('OB222', 'El señor X [...]', 'El señor X [...]', 'NER', 1)
# ('OB223', ('escalera', 'escalera', 'NOUN'), 'LEMMA', 1)
# ('OB224', 'Carta III', 'Carta III', 'NER', 1)
# ('OB224', 'Barcelona', 'Barcelona', 'NER', 1)
# ('OB225', ('moneda', 'moneda', 'NOUN'), 'LEMMA', 1)
# ('OB225', ('oro', 'oro', 'NOUN'), 'LEMMA', 1)
# ('OB225', 'Conclusión', 'Conclusión', 'NER', 1)
# ('OB226', 'Brasil', 'Brasil', 'NER', 1)
# ('OB227', ('alma', 'alma', 'NOUN'), 'LEMMA', 1)
# ('OB227', ('dudas', 'duda', 'NOUN'), 'LEMMA', 1)
# ('OB228', ('istmo', 'istmo', 'NOUN'), 'LEMMA', 1)
# ('OB228', 'Panamá', 'Panamá', 'NER', 1)
# ('OB229', ('peregrinación', 'peregrinación', 'NOUN'), 'LEMMA', 1)
# ('OB229', 'Saint-Point', 'Saint-Point', 'NER', 1)
# ('OB230', ('destinos', 'destino', 'NOUN'), 'LEMMA', 1)
# ('OB230', ('no', 'no', 'ADV'), 'LEMMA', 1)
# ('OB230', ('hay', 'haber', 'VERB'), 'LEMMA', 1)
# ('OB230', ('amigos', 'amigo', 'NOUN'), 'LEMMA', 1)
# ('OB230', ('Proverbio', 'proverbio', 'NOUN'), 'LEMMA', 1)
# ('OB230', ('cuadros', 'cuadro', 'NOUN'), 'LEMMA', 1)
# ('OB231', ('sombrero', 'sombrero', 'NOUN'), 'LEMMA', 1)
# ('OB231', ('emperador', 'emperador', 'NOUN'), 'LEMMA', 1)
# ('OB231', 'Austria', 'Austria', 'NER', 1)
# ('OB232', ('amor', 'amor', 'NOUN'), 'LEMMA', 1)
# ('OB233', 'Feria', 'Feria', 'NER', 1)
# ('OB233', 'Sevilla', 'Sevilla', 'NER', 1)
# ('OB235', ('lentigo', 'lentigo', 'NOUN'), 'LEMMA', 1)
# ('OB235', ('tratamiento', 'tratamiento', 'NOUN'), 'LEMMA', 1)
# ('OB236', ('primera', 'primero', 'ADJ'), 'LEMMA', 1)
# ('OB236', ('página', 'página', 'NOUN'), 'LEMMA', 1)
# ('OB236', ('álbum', 'álbum', 'NOUN'), 'LEMMA', 1)
# ('OB237', ('mundo', 'mundo', 'NOUN'), 'LEMMA', 1)
# ('OB237', 'Soneto', 'Soneto', 'NER', 1)
# ('OB238', ('mundo', 'mundo', 'NOUN'), 'LEMMA', 1)
# ('OB238', 'Soneto', 'Soneto', 'NER', 1)
# ('OB239', ('Última', 'última', 'ADJ'), 'LEMMA', 1)
# ('OB239', ('hora', 'hora', 'NOUN'), 'LEMMA', 1)
# ('OB240', 'Francisco José', 'Francisco José', 'NER', 1)
# ('OB240', 'Emperador del Austria', 'Emperador del Austria', 'NER', 1)
# ('OB241', ('Constituido', 'constituido', 'ADJ'), 'LEMMA', 1)
# ('OB241', ('ya', 'ya', 'ADV'), 'LEMMA', 1)
# ('OB241', ('oficialmente', 'oficialmente', 'ADV'), 'LEMMA', 1)
# ('OB241', ('nuevo', 'nuevo', 'ADJ'), 'LEMMA', 1)
# ('OB241', 'Ministerio Inglés', 'Ministerio Inglés', 'NER', 1)
# ('OB242', ('Parte', 'parte', 'NOUN'), 'LEMMA', 1)
# ('OB242', ('oficial', 'oficial', 'ADJ'), 'LEMMA', 1)
# ('OB242', ('publicado', 'publicado', 'ADJ'), 'LEMMA', 1)
# ('OB242', ('atalla', 'atalla', 'NOUN'), 'LEMMA', 1)
# ('OB242', 'Monitor de París', 'Monitor de París', 'NER', 1)
# ('OB242', 'Solferino', 'Solferino', 'NER', 1)
# ('OB243', ('Censo', 'censo', 'NOUN'), 'LEMMA', 1)
# ('OB243', ('aproximativo', 'aproximativo', 'ADJ'), 'LEMMA', 1)
# ('OB243', ('periódico', 'periódico', 'NOUN'), 'LEMMA', 1)
# ('OB243', ('lee', 'leer', 'VERB'), 'LEMMA', 1)
# ('OB243', ('siguiente', 'siguiente', 'ADJ'), 'LEMMA', 1)
# ('OB243', 'Invento-Histórico', 'Invento-Histórico', 'NER', 1)
# ('OB244', ('señor', 'señor', 'NOUN'), 'LEMMA', 1)
# ('OB244', 'N.', 'N.', 'NER', 1)
# ('OB244', 'señora **', 'señora **', 'NER', 1)
# ('OB245', ('fauno', 'fauno', 'NOUN'), 'LEMMA', 1)
# ('OB245', 'Goysevox', 'Goysevox', 'NER', 1)
# ('OB246', ('prólogo', 'prólogo', 'NOUN'), 'LEMMA', 1)
# ('OB246', ('Episodio', 'episodio', 'NOUN'), 'LEMMA', 1)
# ('OB247', ('collar', 'collar', 'NOUN'), 'LEMMA', 1)
# ('OB248', ('cabello', 'cabello', 'NOUN'), 'LEMMA', 1)
# ('OB248', ('rubio', 'rubio', 'ADJ'), 'LEMMA', 1)
# ('OB249', ('esposa', 'esposa', 'NOUN'), 'LEMMA', 1)
# ('OB249', ('sol', 'sol', 'NOUN'), 'LEMMA', 1)
# ('OB250', ('Inauguración', 'inauguración', 'NOUN'), 'LEMMA', 1)
# ('OB250', ('teatro', 'teatro', 'NOUN'), 'LEMMA', 1)
# ('OB250', 'D. José Piquer-Oda', 'D. José Piquer-Oda', 'NER', 1)
# ('OB250', 'Alzad vuestras tumbas [...]', 'Alzad vuestras tumbas [...]', 'NER', 1)
# ('OB251', ('Estudios', 'estudios', 'NOUN'), 'LEMMA', 1)
# ('OB251', ('primeros', 'primero', 'ADJ'), 'LEMMA', 1)
# ('OB251', ('tiempos', 'tiempo', 'NOUN'), 'LEMMA', 1)
# ('OB251', 'Rusia', 'Rusia', 'NER', 1)
# ('OB252', ('Estudios', 'estudios', 'NOUN'), 'LEMMA', 1)
# ('OB252', ('primeros', 'primero', 'ADJ'), 'LEMMA', 1)
# ('OB252', ('tiempos', 'tiempo', 'NOUN'), 'LEMMA', 1)
# ('OB252', ('Conclusión', 'conclusión', 'NOUN'), 'LEMMA', 1)
# ('OB252', 'Rusia', 'Rusia', 'NER', 1)
# ('OB253', 'Safo', 'Safo', 'NER', 1)
# ('OB254', ('Abnegación', 'abnegación', 'NOUN'), 'LEMMA', 1)
# ('OB255', 'Sombreros de Alexandrine', 'Sombreros de Alexandrine', 'NER', 1)
# ('OB257', 'Sombreros De Alexandrine', 'Sombreros De Alexandrine', 'NER', 1)
# ('OB258', 'Sombreros De Alexandrine', 'Sombreros De Alexandrine', 'NER', 1)
# ('OB262', ('perfumería', 'perfumería', 'NOUN'), 'LEMMA', 1)
# ('OB262', 'Planchais [...]', 'Planchais [...]', 'NER', 1)
# ('OB263', ('Recomendamos', 'recomendar', 'VERB'), 'LEMMA', 1)
# ('OB263', ('lectores', 'lector', 'NOUN'), 'LEMMA', 1)
# ('OB263', ('pianos', 'piano', 'NOUN'), 'LEMMA', 1)
# ('OB264', 'Casa de comisión para París [...]', 'Casa de comisión para París [...]', 'NER', 1)
# ('OB265', ('enfermedades', 'enfermedad', 'NOUN'), 'LEMMA', 1)
# ('OB265', ('pecho', 'pecho', 'NOUN'), 'LEMMA', 1)
# ('OB266', ('Prevenimos', 'prevenir', 'VERB'), 'LEMMA', 1)
# ('OB266', ('lectores', 'lector', 'NOUN'), 'LEMMA', 1)
# ('OB267', 'Corsets Plastiques Mme', 'Corsets Plastiques Mme', 'NER', 1)
# ('OB267', 'Bonvallet', 'Bonvallet', 'NER', 1)
# ('OB268', ('alquila', 'alquilar', 'VERB'), 'LEMMA', 1)
# ('OB268', ('lindísima', 'lindísimo', 'ADJ'), 'LEMMA', 1)
# ('OB268', ('habitación', 'habitación', 'NOUN'), 'LEMMA', 1)
# ('OB269', ('Casas', 'casa', 'NOUN'), 'LEMMA', 1)
# ('OB269', ('recomendadas', 'recomendado', 'ADJ'), 'LEMMA', 1)
# ('OB269', ('artículos', 'artículo', 'NOUN'), 'LEMMA', 1)
# ('OB269', ('voga', 'voga', 'NOUN'), 'LEMMA', 1)
# ('OB270', ('Corsets', 'Corsets', 'PROPN'), 'LEMMA', 1)
# ('OB270', ('plastiques', 'plastiques', 'PROPN'), 'LEMMA', 1)
# ('OB270', ('Guantes', 'Guantes', 'PROPN'), 'LEMMA', 1)
# ('OB270', ('abanicos', 'abanico', 'NOUN'), 'LEMMA', 1)
# ('OB270', ('parfumes', 'paráume', 'NOUN'), 'LEMMA', 1)
# ('OB270', ('Joyas', 'joyas', 'PROPN'), 'LEMMA', 1)
# ('OB270', ('cabellos', 'cabello', 'NOUN'), 'LEMMA', 1)
# ('OB270', ('et', 'et', 'PROPN'), 'LEMMA', 1)
# ('OB270', 'Bonvallet', 'Bonvallet', 'NER', 1)
# ('OB270', 'Faguer Labollée', 'Faguer Labollée', 'NER', 1)
# ('OB270', 'Lemnnier', 'Lemnnier', 'NER', 1)
# ('OB270', 'Porcelaines', 'Porcelaines', 'NER', 1)
# ('OB271', ('Casas', 'casa', 'NOUN'), 'LEMMA', 1)
# ('OB271', ('recomendadas', 'recomendado', 'ADJ'), 'LEMMA', 1)
# ('OB272', ('Cintas', 'cintas', 'NOUN'), 'LEMMA', 1)
# ('OB272', ('pasamanerías', 'pasamanería', 'NOUN'), 'LEMMA', 1)
# ('OB272', ('fábrica', 'fábrica', 'NOUN'), 'LEMMA', 1)
# ('OB272', ('abanicos', 'abanico', 'NOUN'), 'LEMMA', 1)
# ('OB272', ('parfumes', 'paráume', 'NOUN'), 'LEMMA', 1)
# ('OB272', ('Joyas', 'joyas', 'PROPN'), 'LEMMA', 1)
# ('OB272', ('cabellos', 'cabello', 'NOUN'), 'LEMMA', 1)
# ('OB272', 'Sorré Dehsle', 'Sorré Dehsle', 'NER', 1)
# ('OB272', 'Corsets plastiques de Bonvallet', 'Corsets plastiques de Bonvallet', 'NER', 1)
# ('OB272', 'Guantes', 'Guantes', 'NER', 1)
# ('OB272', 'Faguer Labollée', 'Faguer Labollée', 'NER', 1)
# ('OB272', 'Lemnnier', 'Lemnnier', 'NER', 1)
# ('OB273', ('antephelique', 'antephelique', 'PROPN'), 'LEMMA', 1)
# ('OB273', ('Pecas', 'pecas', 'NOUN'), 'LEMMA', 1)
# ('OB273', ('manchas', 'mancha', 'NOUN'), 'LEMMA', 1)
# ('OB273', ('cara', 'cara', 'NOUN'), 'LEMMA', 1)
# ('OB273', 'Lait', 'Lait', 'NER', 1)
# ('OB274', 'Camisas Claudio', 'Camisas Claudio', 'NER', 1)
# ('OB274', 'Hermanos', 'Hermanos', 'NER', 1)
# ('OB275', ('Tintura', 'tintura', 'NOUN'), 'LEMMA', 1)
# ('OB275', ('inglesa', 'inglés', 'ADJ'), 'LEMMA', 1)
# ('OB275', ('instantánea', 'instantáneo', 'ADJ'), 'LEMMA', 1)
# ('OB276', ('Casa', 'casa', 'NOUN'), 'LEMMA', 1)
# ('OB276', ('particular', 'particular', 'ADJ'), 'LEMMA', 1)
# ('OB276', 'Huéspedes', 'Huéspedes', 'NER', 1)
# ('OB277', 'Casa Delacroix', 'Casa Delacroix', 'NER', 1)
# ('OB278', ('dentista', 'dentista', 'NOUN'), 'LEMMA', 1)
# ('OB278', 'Jules Bloch', 'Jules Bloch', 'NER', 1)
# ('OB279', 'Gaceta de Bellas Artes', 'Gaceta de Bellas Artes', 'NER', 1)
# ('OB280', ('Pecas', 'pecas', 'NOUN'), 'LEMMA', 1)
# ('OB280', ('manchas', 'mancha', 'NOUN'), 'LEMMA', 1)
# ('OB280', ('cara', 'cara', 'NOUN'), 'LEMMA', 1)
# ('OB281', ('Casas', 'casa', 'NOUN'), 'LEMMA', 1)
# ('OB281', ('recomendadas', 'recomendado', 'ADJ'), 'LEMMA', 1)
# ('OB282', 'Porta-monedas Despierres', 'Porta-monedas Despierres', 'NER', 1)
# ('OB283', 'Tarifs des insertions', 'Tarifs des insertions', 'NER', 1)
# ('OB284', ('Cintas', 'cintas', 'NOUN'), 'LEMMA', 1)
# ('OB284', ('pasamanerías', 'pasamanería', 'NOUN'), 'LEMMA', 1)
# ('OB284', ('fábrica', 'fábrica', 'NOUN'), 'LEMMA', 1)
# ('OB284', ('abanicos', 'abanico', 'NOUN'), 'LEMMA', 1)
# ('OB284', ('parfumes', 'paráume', 'NOUN'), 'LEMMA', 1)
# ('OB284', ('Joyas', 'joyas', 'PROPN'), 'LEMMA', 1)
# ('OB284', ('cabellos', 'cabello', 'NOUN'), 'LEMMA', 1)
# ('OB284', 'Sorré Dehsle', 'Sorré Dehsle', 'NER', 1)
# ('OB284', 'Corsets plastiques de Bonvallet', 'Corsets plastiques de Bonvallet', 'NER', 1)
# ('OB284', 'Guantes', 'Guantes', 'NER', 1)
# ('OB284', 'Faguer Labollée', 'Faguer Labollée', 'NER', 1)
# ('OB284', 'Lemnnier', 'Lemnnier', 'NER', 1)
# ('OB285', 'Camisas Claudio', 'Camisas Claudio', 'NER', 1)
# ('OB285', 'Hermanos', 'Hermanos', 'NER', 1)
# ('OB286', 'Nueva Geografía Sangansan', 'Nueva Geografía Sangansan', 'NER', 1)
# ('OB287', ('Casa', 'casa', 'NOUN'), 'LEMMA', 1)
# ('OB287', ('particular', 'particular', 'ADJ'), 'LEMMA', 1)
# ('OB287', 'Huéspedes', 'Huéspedes', 'NER', 1)
# ('OB288', 'Casa Delacroix', 'Casa Delacroix', 'NER', 1)
# ('OB289', ('dentista', 'dentista', 'NOUN'), 'LEMMA', 1)
# ('OB289', 'Jules Bloch', 'Jules Bloch', 'NER', 1)
# ('OB290', 'Platería Cristofle', 'Platería Cristofle', 'NER', 1)
# ('OB291', ('Casas', 'casa', 'NOUN'), 'LEMMA', 1)
# ('OB291', ('recomendadas', 'recomendado', 'ADJ'), 'LEMMA', 1)
# ('OB292', 'Tarifs des insertions', 'Tarifs des insertions', 'NER', 1)
# ('OB293', ('Cintas', 'cintas', 'NOUN'), 'LEMMA', 1)
# ('OB293', ('pasamanerías', 'pasamanería', 'NOUN'), 'LEMMA', 1)
# ('OB293', ('fábrica', 'fábrica', 'NOUN'), 'LEMMA', 1)
# ('OB293', ('abanicos', 'abanico', 'NOUN'), 'LEMMA', 1)
# ('OB293', ('parfumes', 'paráume', 'NOUN'), 'LEMMA', 1)
# ('OB293', ('Joyas', 'joyas', 'PROPN'), 'LEMMA', 1)
# ('OB293', ('cabellos', 'cabello', 'NOUN'), 'LEMMA', 1)
# ('OB293', 'Sorré Dehsle', 'Sorré Dehsle', 'NER', 1)
# ('OB293', 'Corsets plastiques de Bonvallet', 'Corsets plastiques de Bonvallet', 'NER', 1)
# ('OB293', 'Guantes', 'Guantes', 'NER', 1)
# ('OB293', 'Faguer Labollée', 'Faguer Labollée', 'NER', 1)
# ('OB293', 'Lemnnier', 'Lemnnier', 'NER', 1)
# ('OB294', 'Camisas Claudio', 'Camisas Claudio', 'NER', 1)
# ('OB294', 'Hermanos', 'Hermanos', 'NER', 1)
# ('OB295', 'Nueva Geografía Sangansan', 'Nueva Geografía Sangansan', 'NER', 1)
# ('OB296', ('Casa', 'casa', 'NOUN'), 'LEMMA', 1)
# ('OB296', ('particular', 'particular', 'ADJ'), 'LEMMA', 1)
# ('OB296', 'Huéspedes', 'Huéspedes', 'NER', 1)
# ('OB297', 'Casa Delacroix', 'Casa Delacroix', 'NER', 1)
# ('OB298', ('dentista', 'dentista', 'NOUN'), 'LEMMA', 1)
# ('OB298', 'Jules Bloch', 'Jules Bloch', 'NER', 1)
# ('OB299', 'Platería Cristofle', 'Platería Cristofle', 'NER', 1)
# ('OB300', ('Casas', 'casa', 'NOUN'), 'LEMMA', 1)
# ('OB300', ('recomendadas', 'recomendado', 'ADJ'), 'LEMMA', 1)
# ('OB301', 'Tarifs des insertions', 'Tarifs des insertions', 'NER', 1)
# ('OB302', 'Camisas Claudio', 'Camisas Claudio', 'NER', 1)
# ('OB302', 'Hermanos', 'Hermanos', 'NER', 1)
# ('OB303', 'Nueva Geografía Sangansan', 'Nueva Geografía Sangansan', 'NER', 1)
# ('OB304', ('Casa', 'casa', 'NOUN'), 'LEMMA', 1)
# ('OB304', ('particular', 'particular', 'ADJ'), 'LEMMA', 1)
# ('OB304', 'Huéspedes', 'Huéspedes', 'NER', 1)
# ('OB305', 'Casa Delacroix', 'Casa Delacroix', 'NER', 1)
# ('OB306', ('dentista', 'dentista', 'NOUN'), 'LEMMA', 1)
# ('OB306', 'Jules Bloch', 'Jules Bloch', 'NER', 1)
# ('OB307', 'Platería Cristofle', 'Platería Cristofle', 'NER', 1)
# ('OB308', ('Casas', 'casa', 'NOUN'), 'LEMMA', 1)
# ('OB308', ('recomendadas', 'recomendado', 'ADJ'), 'LEMMA', 1)
# ('OB309', 'Tarifs des insertions', 'Tarifs des insertions', 'NER', 1)
# ('OB310', 'Camisas Claudio', 'Camisas Claudio', 'NER', 1)
# ('OB310', 'Hermanos', 'Hermanos', 'NER', 1)
# ('OB311', 'Nueva Geografía Sangansan', 'Nueva Geografía Sangansan', 'NER', 1)
# ('OB312', ('Casa', 'casa', 'NOUN'), 'LEMMA', 1)
# ('OB312', ('particular', 'particular', 'ADJ'), 'LEMMA', 1)
# ('OB312', 'Huéspedes', 'Huéspedes', 'NER', 1)
# ('OB313', 'Casa Delacroix', 'Casa Delacroix', 'NER', 1)
# ('OB314', ('dentista', 'dentista', 'NOUN'), 'LEMMA', 1)
# ('OB314', 'Jules Bloch', 'Jules Bloch', 'NER', 1)
# ('OB315', 'Platería Cristofle', 'Platería Cristofle', 'NER', 1)
# ('OB316', ('Casas', 'casa', 'NOUN'), 'LEMMA', 1)
# ('OB316', ('recomendadas', 'recomendado', 'ADJ'), 'LEMMA', 1)
# ('OB317', 'Platería Cristofle', 'Platería Cristofle', 'NER', 1)
# ('OB318', 'Camisas Claudio', 'Camisas Claudio', 'NER', 1)
# ('OB318', 'Hermanos', 'Hermanos', 'NER', 1)
# ('OB319', 'Nueva Geografía Sangansan', 'Nueva Geografía Sangansan', 'NER', 1)
# ('OB320', ('Casa', 'casa', 'NOUN'), 'LEMMA', 1)
# ('OB320', ('particular', 'particular', 'ADJ'), 'LEMMA', 1)
# ('OB320', 'Huéspedes', 'Huéspedes', 'NER', 1)
# ('OB321', 'Casa Delacroix', 'Casa Delacroix', 'NER', 1)
# ('OB322', ('dentista', 'dentista', 'NOUN'), 'LEMMA', 1)
# ('OB322', 'Jules Bloch', 'Jules Bloch', 'NER', 1)
# ('OB323', ('Casas', 'casa', 'NOUN'), 'LEMMA', 1)
# ('OB323', ('recomendadas', 'recomendado', 'ADJ'), 'LEMMA', 1)
# ('OB324', ('Cintas', 'cintas', 'NOUN'), 'LEMMA', 1)
# ('OB324', ('pasamanerías', 'pasamanería', 'NOUN'), 'LEMMA', 1)
# ('OB324', ('fábrica', 'fábrica', 'NOUN'), 'LEMMA', 1)
# ('OB324', ('abanicos', 'abanico', 'NOUN'), 'LEMMA', 1)
# ('OB324', ('parfumes', 'paráume', 'NOUN'), 'LEMMA', 1)
# ('OB324', ('Joyas', 'joyas', 'PROPN'), 'LEMMA', 1)
# ('OB324', ('cabellos', 'cabello', 'NOUN'), 'LEMMA', 1)
# ('OB324', 'Sorré Dehsle', 'Sorré Dehsle', 'NER', 1)
# ('OB324', 'Corsets plastiques de Bonvallet', 'Corsets plastiques de Bonvallet', 'NER', 1)
# ('OB324', 'Guantes', 'Guantes', 'NER', 1)
# ('OB324', 'Faguer Labollée', 'Faguer Labollée', 'NER', 1)
# ('OB324', 'Lemnnier', 'Lemnnier', 'NER', 1)
# ('OB325', 'Camisas Claudio', 'Camisas Claudio', 'NER', 1)
# ('OB325', 'Hermanos', 'Hermanos', 'NER', 1)
# ('OB326', 'Nueva Geografía Sangansan', 'Nueva Geografía Sangansan', 'NER', 1)
# ('OB327', ('Casa', 'casa', 'NOUN'), 'LEMMA', 1)
# ('OB327', ('particular', 'particular', 'ADJ'), 'LEMMA', 1)
# ('OB327', 'Huéspedes', 'Huéspedes', 'NER', 1)
# ('OB328', 'Casa Delacroix', 'Casa Delacroix', 'NER', 1)
# ('OB329', ('dentista', 'dentista', 'NOUN'), 'LEMMA', 1)
# ('OB329', 'Jules Bloch', 'Jules Bloch', 'NER', 1)
# ('OB330', 'Platería Cristofle', 'Platería Cristofle', 'NER', 1)
# ('OB331', 'Camisas Claudio', 'Camisas Claudio', 'NER', 1)
# ('OB331', 'Hermanos', 'Hermanos', 'NER', 1)
# ('OB332', 'Nueva Geografía Sangansan', 'Nueva Geografía Sangansan', 'NER', 1)
# ('OB333', ('Casa', 'casa', 'NOUN'), 'LEMMA', 1)
# ('OB333', ('particular', 'particular', 'ADJ'), 'LEMMA', 1)
# ('OB333', 'Huéspedes', 'Huéspedes', 'NER', 1)
# ('OB334', 'Casa Delacroix', 'Casa Delacroix', 'NER', 1)
# ('OB335', ('dentista', 'dentista', 'NOUN'), 'LEMMA', 1)
# ('OB335', 'Jules Bloch', 'Jules Bloch', 'NER', 1)
# ('OB336', 'Platería Cristofle', 'Platería Cristofle', 'NER', 1)
# ('OB337', ('Casas', 'casa', 'NOUN'), 'LEMMA', 1)
# ('OB337', ('recomendadas', 'recomendado', 'ADJ'), 'LEMMA', 1)
# ('OB338', ('Cintas', 'cintas', 'NOUN'), 'LEMMA', 1)
# ('OB338', ('pasamanerías', 'pasamanería', 'NOUN'), 'LEMMA', 1)
# ('OB338', ('fábrica', 'fábrica', 'NOUN'), 'LEMMA', 1)
# ('OB338', ('abanicos', 'abanico', 'NOUN'), 'LEMMA', 1)
# ('OB338', ('parfumes', 'paráume', 'NOUN'), 'LEMMA', 1)
# ('OB338', ('Joyas', 'joyas', 'PROPN'), 'LEMMA', 1)
# ('OB338', ('cabellos', 'cabello', 'NOUN'), 'LEMMA', 1)
# ('OB338', 'Sorré Dehsle', 'Sorré Dehsle', 'NER', 1)
# ('OB338', 'Corsets plastiques de Bonvallet', 'Corsets plastiques de Bonvallet', 'NER', 1)
# ('OB338', 'Guantes', 'Guantes', 'NER', 1)
# ('OB338', 'Faguer Labollée', 'Faguer Labollée', 'NER', 1)
# ('OB338', 'Lemnnier', 'Lemnnier', 'NER', 1)
# ...
# ('OB351', ('Obras', 'obras', 'NOUN'), 'LEMMA', 1)
# ('OB351', ('señora', 'señora', 'NOUN'), 'LEMMA', 1)
# ('OB351', 'doña Emilia Serrano de Wilson', 'doña Emilia Serrano de Wilson', 'NER', 1)
# ('OB352', 'Modes de Paris', 'Modes de Paris', 'NER', 1)
# ('OB352', 'Petit Courrier des Dames', 'Petit Courrier des Dames', 'NER', 1)
# ('OB353', 'Eco Hispano-Americano', 'Eco Hispano-Americano', 'NER', 1)
# ('OB354', ('Obras', 'obras', 'NOUN'), 'LEMMA', 1)
# ('OB354', ('señora', 'señora', 'NOUN'), 'LEMMA', 1)
# ('OB354', 'doña Emilia Serrano de Wilson', 'doña Emilia Serrano de Wilson', 'NER', 1)
# ('OB355', 'Eco Hispano-Americano', 'Eco Hispano-Americano', 'NER', 1)
# ('OB356', ('Anuncio', 'anuncio', 'NOUN'), 'LEMMA', 1)
# ('OB357', ('Obras', 'obras', 'NOUN'), 'LEMMA', 1)
# ('OB357', ('señora', 'señora', 'NOUN'), 'LEMMA', 1)
# ('OB357', 'doña Emilia Serrano de Wilson', 'doña Emilia Serrano de Wilson', 'NER', 1)
# ('OB360', ('Explicación', 'explicación', 'NOUN'), 'LEMMA', 1)
# ('OB360', ('lámina', 'lámina', 'NOUN'), 'LEMMA', 1)
# ('OB360', ('tapicería', 'tapicería', 'NOUN'), 'LEMMA', 1)
# ('OB361', ('Explicación', 'explicación', 'NOUN'), 'LEMMA', 1)
# ('OB361', ('lámina', 'lámina', 'NOUN'), 'LEMMA', 1)
# ('OB361', ('tapicería', 'tapicería', 'NOUN'), 'LEMMA', 1)
# ('OB362', ('Explicación', 'explicación', 'NOUN'), 'LEMMA', 1)
# ('OB362', ('figurín', 'figurín', 'NOUN'), 'LEMMA', 1)
# ('OB363', 'Moda de Caballeros', 'Moda de Caballeros', 'NER', 1)
# ('OB366', ('Explicación', 'explicación', 'NOUN'), 'LEMMA', 1)
# ('OB366', ('figurín', 'figurín', 'NOUN'), 'LEMMA', 1)
# ('OB367', ('Explicación', 'explicación', 'NOUN'), 'LEMMA', 1)
# ('OB367', ('figurín', 'figurín', 'NOUN'), 'LEMMA', 1)
# ('OB369', ('Descripción', 'descripción', 'NOUN'), 'LEMMA', 1)
# ('OB369', ('figurín', 'figurín', 'NOUN'), 'LEMMA', 1)
# ('OB369', ('primer', 'primero', 'ADJ'), 'LEMMA', 1)
# ('OB369', ('segundo', 'segundo', 'ADJ'), 'LEMMA', 1)
# ('OB369', ('traje', 'traje', 'NOUN'), 'LEMMA', 1)
# ('OB370', ('Descripción', 'descripción', 'NOUN'), 'LEMMA', 1)
# ('OB370', ('figurín', 'figurín', 'NOUN'), 'LEMMA', 1)
# ('OB370', ('traje', 'traje', 'NOUN'), 'LEMMA', 1)
# ('OB370', ('novia', 'novia', 'NOUN'), 'LEMMA', 1)
# ('OB370', ('madre', 'madre', 'NOUN'), 'LEMMA', 1)
# ('OB372', ('Explicación', 'explicación', 'NOUN'), 'LEMMA', 1)
# ('OB372', ('figurín', 'figurín', 'NOUN'), 'LEMMA', 1)
# ('OB376', ('Descripción', 'descripción', 'NOUN'), 'LEMMA', 1)
# ('OB376', ('figurín', 'figurín', 'NOUN'), 'LEMMA', 1)
# ('OB376', ('baile', 'baile', 'NOUN'), 'LEMMA', 1)
# ('OB377', ('Figurín', 'figurín', 'NOUN'), 'LEMMA', 1)
# ('OB377', ('visita', 'visita', 'NOUN'), 'LEMMA', 1)
# ('OB378', ('Explicación', 'explicación', 'NOUN'), 'LEMMA', 1)
# ('OB378', ('figurín', 'figurín', 'NOUN'), 'LEMMA', 1)
# ('OB380', ('Explicación', 'explicación', 'NOUN'), 'LEMMA', 1)
# ('OB380', ('figurín', 'figurín', 'NOUN'), 'LEMMA', 1)
# ('OB381', ('Explicación', 'explicación', 'NOUN'), 'LEMMA', 1)
# ('OB381', ('figurín', 'figurín', 'NOUN'), 'LEMMA', 1)
# ('OB382', ('Explicación', 'explicación', 'NOUN'), 'LEMMA', 1)
# ('OB382', ('figurín', 'figurín', 'NOUN'), 'LEMMA', 1)
# ('OB383', ('Explicación', 'explicación', 'NOUN'), 'LEMMA', 1)
# ('OB383', ('figurín', 'figurín', 'NOUN'), 'LEMMA', 1)
# ('OB386', ('Explicación', 'explicación', 'NOUN'), 'LEMMA', 1)
# ('OB386', ('figurín', 'figurín', 'NOUN'), 'LEMMA', 1)
# ('OB387', ('Explicación', 'explicación', 'NOUN'), 'LEMMA', 1)
# ('OB387', ('figurines', 'figurín', 'NOUN'), 'LEMMA', 1)
# ('OB387', ('Primero', 'primero', 'ADV'), 'LEMMA', 1)
# ('OB388', ('Explicación', 'explicación', 'NOUN'), 'LEMMA', 1)
# ('OB388', ('figurines', 'figurín', 'NOUN'), 'LEMMA', 1)
# ('OB388', 'Segundo', 'Segundo', 'NER', 1)
# ('OB389', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB389', ('moda', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB390', 'Revista de París', 'Revista de París', 'NER', 1)
# ('OB391', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB391', ('moda', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB392', 'Revista de París', 'Revista de París', 'NER', 1)
# ('OB393', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB393', ('moda', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB394', 'Revista de París', 'Revista de París', 'NER', 1)
# ('OB395', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB395', ('moda', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB396', 'Revista de París', 'Revista de París', 'NER', 1)
# ('OB397', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB397', ('moda', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB398', 'Revista de París', 'Revista de París', 'NER', 1)
# ('OB399', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB399', ('moda', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB400', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB400', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB400', ('salones', 'salón', 'NOUN'), 'LEMMA', 1)
# ('OB400', ('teatros', 'teatro', 'NOUN'), 'LEMMA', 1)
# ('OB401', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB401', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB401', ('salones', 'salón', 'NOUN'), 'LEMMA', 1)
# ('OB401', ('teatros', 'teatro', 'NOUN'), 'LEMMA', 1)
# ('OB402', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB402', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB402', ('salones', 'salón', 'NOUN'), 'LEMMA', 1)
# ('OB402', ('teatros', 'teatro', 'NOUN'), 'LEMMA', 1)
# ('OB403', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB403', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB403', ('salones', 'salón', 'NOUN'), 'LEMMA', 1)
# ('OB403', ('teatros', 'teatro', 'NOUN'), 'LEMMA', 1)
# ('OB404', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB404', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB404', ('salones', 'salón', 'NOUN'), 'LEMMA', 1)
# ('OB404', ('teatros', 'teatro', 'NOUN'), 'LEMMA', 1)
# ('OB405', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB405', ('histórica', 'histórico', 'ADJ'), 'LEMMA', 1)
# ('OB405', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB406', 'Revista Parisense', 'Revista Parisense', 'NER', 1)
# ('OB407', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB407', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB408', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB408', ('histórica', 'histórico', 'ADJ'), 'LEMMA', 1)
# ('OB408', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB409', 'Revista Parisense', 'Revista Parisense', 'NER', 1)
# ('OB410', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB410', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB411', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB411', ('histórica', 'histórico', 'ADJ'), 'LEMMA', 1)
# ('OB411', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB412', 'Revista Parisense', 'Revista Parisense', 'NER', 1)
# ('OB413', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB413', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB414', 'Revista Parisense', 'Revista Parisense', 'NER', 1)
# ('OB415', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB415', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB416', 'Revista Parisense', 'Revista Parisense', 'NER', 1)
# ('OB417', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB417', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB418', 'Revista Parisiense', 'Revista Parisiense', 'NER', 1)
# ('OB419', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB419', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB420', 'Revista Parisiense', 'Revista Parisiense', 'NER', 1)
# ('OB421', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB421', ('histórico-política', 'histórico-política', 'ADJ'), 'LEMMA', 1)
# ('OB422', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB422', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB423', 'Revista Parisiense', 'Revista Parisiense', 'NER', 1)
# ('OB424', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB424', ('histórico-política', 'histórico-política', 'ADJ'), 'LEMMA', 1)
# ('OB425', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB425', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB426', 'Revista Parisiense', 'Revista Parisiense', 'NER', 1)
# ('OB427', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB427', ('histórico-política', 'histórico-política', 'ADJ'), 'LEMMA', 1)
# ('OB428', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB428', ('teatros', 'teatro', 'NOUN'), 'LEMMA', 1)
# ('OB429', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB429', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB430', 'Revista de Madrid', 'Revista de Madrid', 'NER', 1)
# ('OB431', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB431', ('teatros', 'teatro', 'NOUN'), 'LEMMA', 1)
# ('OB432', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB432', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB433', 'Revista Parisiense', 'Revista Parisiense', 'NER', 1)
# ('OB434', 'Revista de Madrid', 'Revista de Madrid', 'NER', 1)
# ('OB435', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB435', ('teatros', 'teatro', 'NOUN'), 'LEMMA', 1)
# ('OB436', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB436', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB437', 'Revista Parisiense', 'Revista Parisiense', 'NER', 1)
# ('OB438', 'Revista de Madrid', 'Revista de Madrid', 'NER', 1)
# ('OB439', ('Crónica', 'crónica', 'NOUN'), 'LEMMA', 1)
# ('OB439', ('parisiense', 'parisiense', 'ADJ'), 'LEMMA', 1)
# ('OB440', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB440', ('teatros', 'teatro', 'NOUN'), 'LEMMA', 1)
# ('OB441', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB441', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB442', 'Revista Parisiense', 'Revista Parisiense', 'NER', 1)
# ('OB443', 'Revista de Madrid', 'Revista de Madrid', 'NER', 1)
# ('OB444', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB444', ('teatros', 'teatro', 'NOUN'), 'LEMMA', 1)
# ('OB445', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB445', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB446', 'Revista Parisiense', 'Revista Parisiense', 'NER', 1)
# ('OB447', 'Revista de Madrid', 'Revista de Madrid', 'NER', 1)
# ('OB448', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB448', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB449', 'Revista Parisiense', 'Revista Parisiense', 'NER', 1)
# ('OB450', 'Revista de Madrid', 'Revista de Madrid', 'NER', 1)
# ('OB451', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB451', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB452', 'Revista Parisiense', 'Revista Parisiense', 'NER', 1)
# ('OB453', 'Revista de Madrid', 'Revista de Madrid', 'NER', 1)
# ('OB454', 'Revista Parisiense', 'Revista Parisiense', 'NER', 1)
# ('OB455', 'Revista de Madrid', 'Revista de Madrid', 'NER', 1)
# ('OB456', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB456', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB457', 'Revista de Madrid', 'Revista de Madrid', 'NER', 1)
# ('OB458', 'Revista de París', 'Revista de París', 'NER', 1)
# ('OB459', 'Teatros', 'Teatros', 'NER', 1)
# ('OB460', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB460', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB461', 'Revista de Madrid', 'Revista de Madrid', 'NER', 1)
# ('OB462', 'Revista de París', 'Revista de París', 'NER', 1)
# ('OB463', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB463', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB464', 'Revista de Madrid', 'Revista de Madrid', 'NER', 1)
# ('OB465', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB465', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB466', 'Revista de Madrid', 'Revista de Madrid', 'NER', 1)
# ('OB467', 'Revista de París', 'Revista de París', 'NER', 1)
# ('OB468', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB468', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB469', 'Revista de Madrid', 'Revista de Madrid', 'NER', 1)
# ('OB470', 'Revista de París', 'Revista de París', 'NER', 1)
# ('OB471', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB471', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB472', 'Revista de Madrid', 'Revista de Madrid', 'NER', 1)
# ('OB473', 'Revista de París', 'Revista de París', 'NER', 1)
# ('OB474', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB474', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB475', 'Revista de Madrid', 'Revista de Madrid', 'NER', 1)
# ('OB476', 'Revista de París', 'Revista de París', 'NER', 1)
# ('OB477', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB477', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB478', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB478', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB479', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB479', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB480', 'Revista de Madrid', 'Revista de Madrid', 'NER', 1)
# ('OB481', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB481', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB482', 'Revista de Madrid', 'Revista de Madrid', 'NER', 1)
# ('OB483', 'Revista de París', 'Revista de París', 'NER', 1)
# ('OB484', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB484', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB485', 'Revista de Madrid', 'Revista de Madrid', 'NER', 1)
# ('OB486', 'Revista de París', 'Revista de París', 'NER', 1)
# ('OB487', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB487', ('modas', 'moda', 'NOUN'), 'LEMMA', 1)
# ('OB488', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB488', ('histórica', 'histórico', 'ADJ'), 'LEMMA', 1)
# ('OB488', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB489', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB489', ('histórica', 'histórico', 'ADJ'), 'LEMMA', 1)
# ('OB489', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB490', ('Crónica', 'crónica', 'NOUN'), 'LEMMA', 1)
# ('OB490', ('parisiense', 'parisiense', 'ADJ'), 'LEMMA', 1)
# ('OB491', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB491', ('histórica', 'histórico', 'ADJ'), 'LEMMA', 1)
# ('OB491', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB492', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB492', ('histórica', 'histórico', 'ADJ'), 'LEMMA', 1)
# ('OB492', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB493', ('Crónica', 'crónica', 'NOUN'), 'LEMMA', 1)
# ('OB493', ('parisiense', 'parisiense', 'ADJ'), 'LEMMA', 1)
# ('OB494', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB494', ('histórica', 'histórico', 'ADJ'), 'LEMMA', 1)
# ('OB494', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB495', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB495', ('histórica', 'histórico', 'ADJ'), 'LEMMA', 1)
# ('OB495', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB496', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB496', ('histórica', 'histórico', 'ADJ'), 'LEMMA', 1)
# ('OB496', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB497', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB497', ('histórica', 'histórico', 'ADJ'), 'LEMMA', 1)
# ('OB497', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB498', ('Crónica', 'crónica', 'NOUN'), 'LEMMA', 1)
# ('OB498', ('parisiense', 'parisiense', 'ADJ'), 'LEMMA', 1)
# ('OB499', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB499', ('histórica', 'histórico', 'ADJ'), 'LEMMA', 1)
# ('OB499', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB500', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB500', ('histórica', 'histórico', 'ADJ'), 'LEMMA', 1)
# ('OB500', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB501', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB501', ('histórica', 'histórico', 'ADJ'), 'LEMMA', 1)
# ('OB501', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB502', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB502', ('histórica', 'histórico', 'ADJ'), 'LEMMA', 1)
# ('OB502', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB503', ('Crónica', 'crónica', 'NOUN'), 'LEMMA', 1)
# ('OB503', ('parisiense', 'parisiense', 'ADJ'), 'LEMMA', 1)
# ('OB504', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB504', ('histórica', 'histórico', 'ADJ'), 'LEMMA', 1)
# ('OB504', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB505', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB505', ('histórica', 'histórico', 'ADJ'), 'LEMMA', 1)
# ('OB505', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB506', ('Crónica', 'crónica', 'NOUN'), 'LEMMA', 1)
# ('OB506', ('parisiense', 'parisiense', 'ADJ'), 'LEMMA', 1)
# ('OB507', ('Revista', 'revista', 'NOUN'), 'LEMMA', 1)
# ('OB507', ('histórica', 'histórico', 'ADJ'), 'LEMMA', 1)
# ('OB507', ('mes', 'mes', 'NOUN'), 'LEMMA', 1)
# ('OB508', ('Crónica', 'crónica', 'NOUN'), 'LEMMA', 1)
# ('OB508', ('parisiense', 'parisiense', 'ADJ'), 'LEMMA', 1)
# ('OB509', ('Crónica', 'crónica', 'NOUN'), 'LEMMA', 1)
# ('OB509', ('parisiense', 'parisiense', 'ADJ'), 'LEMMA', 1)
# ('OB510', ('Crónica', 'crónica', 'NOUN'), 'LEMMA', 1)
# ('OB510', ('parisiense', 'parisiense', 'ADJ'), 'LEMMA', 1)
# ('OB511', ('Crónica', 'crónica', 'NOUN'), 'LEMMA', 1)
# ('OB511', ('parisiense', 'parisiense', 'ADJ'), 'LEMMA', 1)

# %%
import pandas as pd
import re
from collections import Counter
import ast

# Step 1: Read the CSV file into a pandas DataFrame
df = pd.read_csv('Categorías_List_2_Javier.csv')

all_results = []  # Final list: (document_id, category, form, origin, frequency)

# Step 2: Iterate over the rows of the CSV DataFrame
for idx, row in df.iterrows():
    document_id = row['ID_título']
    categorias = row['Categorías']

    # Safely evaluate the 'Categorías' string as a list of tuples using ast.literal_eval
    categorias = ast.literal_eval(categorias)

    # === Lemmas ===
    lemma_pairs = []
    for titulo_ in categorias:
        for cat in titulo_:
            if isinstance(cat, tuple):  # Check if the element is a tuple
                lemma_pairs.append((cat[0], cat[1]))  # ('lemma', 'form')

    lemma_counter = Counter(lemma_pairs)
    for lemma, freq in lemma_counter.items():
        all_results.append((document_id, lemma, 'LEMMA', freq))

    # === NERs ===
    ner_matches = []
    for titulo_ in categorias:
        for cat in titulo_:
            if isinstance(cat, str) and "[(" in cat:  # Check if the element is a string with NER
                # Use regular expression to find NERs in the string
                for match in re.finditer(r"\[\('([^']+)',\s*'[^']+'\)\]", cat):
                    entity = match.group(1)
                    ner_matches.append((entity, entity))  # Assume form = entity for now

    ner_counter = Counter(ner_matches)
    for (entity, form), freq in ner_counter.items():
        all_results.append((document_id, entity, form, 'NER', freq))

# Step 3: Preview the results
for row in all_results:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-48-16d8a20009c9> in <cell line: 0>()
#       5
#       6 # Step 1: Read the CSV file into a pandas DataFrame
# ----> 7 df = pd.read_csv('Categorías_List_2_Javier.csv')
#       8
#       9 all_results = []  # Final list: (document_id, category, form, origin, frequency)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     624
#     625     with parser:
# --> 626         return parser.read(nrows)
#     627
#     628
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1921                     columns,
#    1922                     col_dict,
# -> 1923                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1924                     nrows
#    1925                 )
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 8 fields in line 5, saw 10
