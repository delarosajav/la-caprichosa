# %%
# !pip install stanza
import stanza
# Out:
# Requirement already satisfied: stanza in /home/ludivina/anaconda3/lib/python3.12/site-packages (1.10.1)
# Requirement already satisfied: emoji in /home/ludivina/anaconda3/lib/python3.12/site-packages (from stanza) (2.14.1)
# Requirement already satisfied: numpy in /home/ludivina/anaconda3/lib/python3.12/site-packages (from stanza) (1.26.4)
# Requirement already satisfied: protobuf>=3.15.0 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in /home/ludivina/anaconda3/lib/python3.12/site-packages (from stanza) (2.32.2)
# Requirement already satisfied: networkx in /home/ludivina/anaconda3/lib/python3.12/site-packages (from stanza) (3.2.1)
# Requirement already satisfied: torch>=1.3.0 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from stanza) (2.6.0)
# Requirement already satisfied: tqdm in /home/ludivina/anaconda3/lib/python3.12/site-packages (from stanza) (4.66.4)
# Requirement already satisfied: filelock in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (4.11.0)
# Requirement already satisfied: jinja2 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (3.1.4)
# Requirement already satisfied: fsspec in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (3.2.0)
# Requirement already satisfied: setuptools in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (69.5.1)
# Requirement already satisfied: sympy==1.13.1 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.3.0->stanza) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from requests->stanza) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from requests->stanza) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from requests->stanza) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from requests->stanza) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ludivina/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.3.0->stanza) (2.1.3)

# %%
## N: añadidos para respetar la arquitectura actual del repositorio (no existía la carpeta content/ inicialmente):
import os
if not os.path.isdir('content'):
    os.path.makedirs('content')
##

#//NLP TOK, MWT, POS, LEMMA, NER, DEPPARSE:

def processing_1(text, nlp_model):
  doc = nlp_model(text)
  return [(word.text, word.lemma, word.upos, word.head, word.deprel) for sent in doc.sentences for word in sent.words]

#//ES-------------------
nlp_es = stanza.Pipeline(lang="es", processors="tokenize,mwt,pos,lemma,ner,depparse") #IMPORTANTE: EL ORDEN, esto es, lo que antecede afecta a lo siguiente, mientras que lo que precede no)

##N: he tenido que hacer una copia dentro de content/ del archivo ALL_TITLES.txt que tenías en el mismo nivel que el programa (dentro de la arquitectura del repositorio)
## Por otro lado, aquí vendría bien incorporar la(s) query/ies SQL a la DB en vez de contar con el resultado de las mismas en un archivo ALL_TITLE.txt obtenido anteriormente.
## No olvides que la finalidad de este trabajo es implementar un módulo de análisis de cada título, dentro de un proceso que incluye tb la recopilación de todos los metadatos
## (de cada título) que vas a necesitar a la hora de poner toda la información resultante de forma arquitecturada en la DB (que luego ya no se tocará sino que la app node.js le hará requests)
path = "content/ALL_TITLES.txt" 

with open(path, "r", encoding="utf-8") as f:
  rows = f.readlines()

## N: es una cuestión de estilo/economía de programación pero las líneas siguientes pueden comprimirse en una sola línea de lista de comprehensión:
## processed_titles_es = [processing_1(row, nlp_es) for row in rows]

processed_titles_es = []

for row in rows:
    titles_row = processing_1(row, nlp_es)
    processed_titles_es.append(titles_row)
##

print(processed_titles_es)

#//FR-------------------
#nlp_fr = stanza.Pipeline(lang="fr", processors="tokenize,mwt,pos,lemma,ner,depparse") #IMPORTANTE: EL ORDEN, esto es, lo que antecede afecta a lo siguiente, mientras que lo que precede no)

#with open(path, "r", encoding="utf-8") as f:
 # rows = f.readlines()

#processed_titles_fr = []

#for row in rows:
 #   titles_row = processing_1(row, nlp_fr)
  #  processed_titles_fr.append(titles_row)

#print(processed_titles_fr)
# Out:
# 2025-03-13 16:12:39 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-03-13 16:12:39 INFO: Downloaded file to /home/ludivina/stanza_resources/resources.json
# 2025-03-13 16:12:39 INFO: Loading these models for language: es (Spanish):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# | ner       | conll02           |
# =================================
#
# 2025-03-13 16:12:39 INFO: Using device: cuda
# 2025-03-13 16:12:39 INFO: Loading: tokenize
# 2025-03-13 16:12:39 INFO: Loading: mwt
# 2025-03-13 16:12:39 INFO: Loading: pos
# 2025-03-13 16:12:40 INFO: Loading: lemma
# 2025-03-13 16:12:41 INFO: Loading: depparse
# 2025-03-13 16:12:41 INFO: Loading: ner
# 2025-03-13 16:12:42 INFO: Done loading processors!
# [[('A', 'a', 'ADP', 3, 'case'), ('el', 'el', 'DET', 3, 'det'), ('Sr.', 'sr.', 'PROPN', 7, 'obl'), ('D.', 'd.', 'PROPN', 3, 'flat'), ('R.', 'R.', 'PROPN', 3, 'flat'), ('P.', 'p.', 'PROPN', 3, 'flat'), ('Enviando', 'enviar', 'VERB', 0, 'root'), ('le', 'él', 'PRON', 7, 'obl:arg'), ('mis', 'mi', 'DET', 10, 'det'), ('obras', 'obra', 'NOUN', 7, 'obj')], [('La', 'el', 'DET', 2, 'det'), ('mujer', 'mujer', 'NOUN', 0, 'root'), ('piadosa', 'piadoso', 'ADJ', 2, 'amod'), ('(', '(', 'PUNCT', 5, 'punct'), ('Fragmentos', 'Fragmentos', 'PROPN', 2, 'appos'), (')', ')', 'PUNCT', 5, 'punct')], [('Desvarío', 'desvarío', 'NOUN', 0, 'root')], [('Soneto', 'soneto', 'PROPN', 0, 'root'), ('.', '.', 'PUNCT', 1, 'punct'), ('"', '"', 'PUNCT', 3, 'punct'), ('¡', '¡', 'PUNCT', 3, 'punct'), ('Gloria', 'gloria', 'PROPN', 0, 'root'), ('y', 'y', 'CCONJ', 5, 'cc'), ('pobreza', 'pobreza', 'NOUN', 3, 'conj'), ('!', '!', 'PUNCT', 3, 'punct'), ('El', 'el', 'DET', 3, 'det'), ('inmortal', 'inmortal', 'ADJ', 3, 'amod'), ('Quintana', 'Quintana', 'PROPN', 0, 'root'), ('...', '...', 'PUNCT', 3, 'punct'), ('"', '"', 'PUNCT', 3, 'punct')], [('Balada', 'Balada', 'PROPN', 0, 'root'), ('.', '.', 'PUNCT', 1, 'punct'), ('La', 'el', 'DET', 2, 'det'), ('despedida', 'despedida', 'NOUN', 0, 'root'), ('de', 'de', 'ADP', 5, 'case'), ('una', 'uno', 'DET', 5, 'det'), ('hija', 'hija', 'NOUN', 2, 'nmod')], [('Un', 'uno', 'DET', 2, 'det'), ('viaje', 'viaje', 'NOUN', 0, 'root'), ('a', 'a', 'ADP', 5, 'case'), ('la', 'el', 'DET', 5, 'det'), ('Luna', 'luna', 'PROPN', 2, 'nmod'), ('.', '.', 'PUNCT', 2, 'punct'), ('Prólogo', 'prólogo', 'NOUN', 0, 'root'), (':', ':', 'PUNCT', 4, 'punct'), ('La', 'el', 'DET', 4, 'det'), ('pesadilla', 'pesadilla', 'PROPN', 1, 'appos'), ('de', 'de', 'ADP', 6, 'case'), ('Mocquet', 'Mocquet', 'PROPN', 4, 'nmod')], [('En', 'en', 'ADP', 3, 'case'), ('el', 'el', 'DET', 3, 'det'), ('álbum', 'álbum', 'NOUN', 0, 'root'), ('de', 'de', 'ADP', 6, 'case'), ('la', 'el', 'DET', 6, 'det'), ('señora', 'señora', 'NOUN', 3, 'nmod'), ('M…', 'm…', 'PROPN', 6, 'appos')], [('La', 'el', 'DET', 2, 'det'), ('primavera', 'primavera', 'NOUN', 0, 'root')], [('La', 'el', 'DET', 2, 'det'), ('perejilera', 'perejilera', 'NOUN', 0, 'root')], [('Un', 'uno', 'DET', 2, 'det'), ('viaje', 'viaje', 'NOUN', 0, 'root'), ('a', 'a', 'ADP', 5, 'case'), ('la', 'el', 'DET', 5, 'det'), ('Luna', 'luna', 'PROPN', 2, 'nmod'), ('.', '.', 'PUNCT', 2, 'punct'), ('(', '(', 'PUNCT', 2, 'punct'), ('Continuación', 'continuación', 'NOUN', 0, 'root'), (')', ')', 'PUNCT', 2, 'punct')], [('A', 'a', 'ADP', 3, 'case'), ('el', 'el', 'DET', 3, 'det'), ('señor', 'señor', 'NOUN', 0, 'root'), ('Don', 'Don', 'PROPN', 3, 'appos'), ('B.', 'B.', 'PROPN', 4, 'flat'), ('M.', 'M.', 'PROPN', 4, 'flat')], [('A', 'a', 'ADP', 2, 'case'), ('orillas', 'orilla', 'NOUN', 0, 'root'), ('de', 'de', 'ADP', 5, 'case'), ('el', 'el', 'DET', 5, 'det'), ('Manzanares', 'manzanares', 'PROPN', 2, 'nmod'), ('.', '.', 'PUNCT', 2, 'punct'), ('La', 'el', 'DET', 2, 'det'), ('súplica', 'súplica', 'NOUN', 0, 'root')], [('Un', 'uno', 'DET', 2, 'det'), ('viaje', 'viaje', 'NOUN', 0, 'root'), ('a', 'a', 'ADP', 5, 'case'), ('la', 'el', 'DET', 5, 'det'), ('Luna', 'luna', 'PROPN', 2, 'nmod'), ('.', '.', 'PUNCT', 2, 'punct'), ('(', '(', 'PUNCT', 2, 'punct'), ('Continuación', 'continuación', 'NOUN', 0, 'root'), (')', ')', 'PUNCT', 2, 'punct')], [('Fragmentos', 'fragmentos', 'NOUN', 0, 'root'), ('de', 'de', 'ADP', 4, 'case'), ('la', 'el', 'DET', 4, 'det'), ('Rosa', 'Rosa', 'PROPN', 1, 'nmod'), ('de', 'de', 'ADP', 6, 'case'), ('Alejandra', 'Alejandra', 'PROPN', 4, 'nmod')], [('Gente', 'gente', 'NOUN', 0, 'root'), ('morena', 'moreno', 'ADJ', 1, 'amod')], [('Un', 'uno', 'DET', 2, 'det'), ('viaje', 'viaje', 'NOUN', 0, 'root'), ('a', 'a', 'ADP', 5, 'case'), ('la', 'el', 'DET', 5, 'det'), ('Luna', 'luna', 'PROPN', 2, 'nmod'), ('.', '.', 'PUNCT', 2, 'punct'), ('(', '(', 'PUNCT', 2, 'punct'), ('Continuación', 'continuación', 'NOUN', 0, 'root'), (')', ')', 'PUNCT', 2, 'punct')], [('A' ...

# %%
with open("content/_ES_PROCESSING_PERTITLE.txt", "w", encoding="utf-8") as f:
  for element in processed_titles_es:
    f.write(str(element) + "\n")

with open("content/_FR_PROCESSING_PERTITLE.txt", "w", encoding="utf-8") as f:
  for element in processed_titles_es:
    f.write(str(element) + "\n")

# %%
#NLP NER:
def ner1(text, nlp_model):
  doc = nlp_model(text)
  return [(ent.text, ent.type) for ent in doc.entities]

#//ES-----
nlp_es = stanza.Pipeline(lang="es", processors="tokenize,mwt,pos,lemma,ner") #IMPORTANTE: EL ORDEN, esto es, lo que antecede afecta a lo siguiente, mientras que lo que precede no)
path = "content/ALL_TITLES.txt"

with open(path, "r", encoding="utf-8") as f:
  rows = f.readlines()

## N: puedes reescribir el código siguiente en forma de lista de comprehensión si lo deseas (sobre el mismo modelo que mi comentario anterior)
entities_ES = []

for row in rows:
  entities_row = ner1(row, nlp_es)
  entities_ES.append(entities_row)
##
print(entities_ES)

#//FR---------
#nlp_fr = stanza.Pipeline(lang="fr", processors="tokenize,mwt,pos,lemma,ner") #IMPORTANTE: EL ORDEN, esto es, lo que antecede afecta a lo siguiente, mientras que lo que precede no)

#with open(path, "r", encoding="utf-8") as f:
  #rows = f.readlines()

#entities_FR = []

#for row in rows:
  #entities_row = ner1(row, nlp_fr)
  #entities_FR.append(entities_row)

#print(entities_FR)
# Out:
# 2025-03-13 16:35:17 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-03-13 16:35:17 INFO: Downloaded file to /home/ludivina/stanza_resources/resources.json
# 2025-03-13 16:35:17 INFO: Loading these models for language: es (Spanish):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | ner       | conll02           |
# =================================
#
# 2025-03-13 16:35:17 INFO: Using device: cuda
# 2025-03-13 16:35:17 INFO: Loading: tokenize
# 2025-03-13 16:35:17 INFO: Loading: mwt
# 2025-03-13 16:35:17 INFO: Loading: pos
# 2025-03-13 16:35:18 INFO: Loading: lemma
# 2025-03-13 16:35:19 INFO: Loading: ner
# 2025-03-13 16:35:20 INFO: Done loading processors!
# [[('Sr. D. R. P.', 'MISC')], [('Fragmentos', 'MISC')], [('Desvarío', 'MISC')], [('Soneto', 'PER'), ('inmortal Quintana...', 'MISC')], [('Balada', 'PER')], [('Luna', 'MISC'), ('Mocquet', 'PER')], [('señora M…', 'PER')], [], [], [('Luna', 'MISC')], [('Don B. M.', 'PER')], [('Manzanares', 'LOC')], [('Luna', 'MISC')], [('de la Rosa de Alejandra', 'PER')], [], [('Luna', 'MISC')], [('Sr. D. Agustín Esteban Collantes', 'MISC')], [('Margarita Aurora de Wilson', 'PER'), ('Serrano', 'PER')], [('I', 'PER')], [('Margarita', 'PER')], [], [('Señora doña M. Del Pilar Sinués de Marco', 'PER')], [('II', 'MISC')], [('Margarita', 'PER')], [('Margarita Aurora de Wilson', 'PER'), ('Serrano', 'PER')], [('María', 'PER')], [('Alteza Real', 'PER'), ('Príncipe de Asturias', 'PER')], [('Margarita', 'PER')], [], [('Soneto', 'PER')], [('SS. MM. II', 'PER')], [('El matrimonio de la Princesa real de Inglaterra [...]"', 'MISC')], [('Poesía', 'MISC'), ('Oda', 'PER')], [('Alejandro Dumas', 'PER')], [('Soneto', 'PER')], [], [('SS.', 'MISC'), ('príncipe Mirza-Ally-Kan-Bahadoor', 'PER'), ('Habláse mucho en los círculos aristocrático de un matrimonio [...]', 'MISC')], [], [], [('Ismail', 'PER')], [('Leviatán', 'MISC')], [], [('M. de Lamartine', 'PER')], [], [('Isabel II', 'PER')], [('Hamlet', 'PER')], [('La Malibran', 'MISC'), ('Londres', 'LOC'), ('El gobierno del Brasil [...]', 'MISC')], [('M. de Lamartine', 'PER')], [('Porvenir', 'PER'), ('Francia', 'ORG'), ('Nuevo-Mundo', 'LOC')], [('Confederación Argentina', 'ORG'), ('Uruguay-Le Paraguay', 'ORG')], [('S. M. La emperatriz de los franceses', 'MISC')], [], [('Zurbarán', 'LOC')], [], [('Filadelfia', 'LOC')], [('Ville', 'LOC')], [('Paraguay', 'LOC')], [('Escma', 'ORG'), ('Dª Gertrudis Gómez de Avellaneda', 'PER')], [], [('Leopoldo Robert', 'PER')], [], [], [('Leemos en el Monitor  [...]"', 'MISC'), ('Anuario diplomático de 1859\' [...]"', 'MISC'), ('Alto', 'MISC'), ('Bajo Rin', 'LOC'), ('El matrimonio del hijo mayor [...]"-Savonnette', 'MISC')], [('Ramón de la Sagra', 'PER')], [('Estados-Unidos', 'ORG'), ('Paraguay', 'ORG')], [], [], [('SS. AA. II', 'MISC'), ('princesa Napoleón', 'PER')], [], [('Leopoldo Robert', 'PER'), ('Conclusión', 'ORG')], [('San Petesburgo', 'MISC'), ('El Entreacto publica un acarta fechada en Génova', 'MISC')], [('Memorándum especial por la guerra de Italia', 'MISC')], [], [('Pbro', 'PER'), ('D. Félix Varela', 'PER')], [], [('catedral de Bron', 'LOC')], [], [('Artículo II', 'MISC'), ('Estados-Unidos', 'ORG'), ('Paraguay', 'ORG')], [], [('Deuda', 'MISC')], [('M. Alejandro Dumas', 'PER')], [('Carta del Sr.', 'MISC'), ('Guillemot', 'PER')], [('Napoleón III', 'PER')], [('Víctor Manuel II', 'PER')], [], [('Poesía', 'MISC'), ('Mariano G. Manrique', 'PER')], [], [], [('Poesía', 'MISC'), ('Napoleón III', 'PER')], [('Montmartre', 'LOC'), ('Fragmento', 'MISC')], [], [('Solferino', 'PER')], [('Memorándum especial por la guerra de Italia', 'MISC')], [('Batalla de Solferino', 'MISC')], [('Ejército de Italia', 'ORG')], [('Villafranca', 'LOC')], [('mariscal Vaillant', 'PER'), ('Italia', 'LOC')], [('Poesía', 'MISC')], [('S. M.', 'PER'), ('Napoleón III', 'PER'), ('Fragmentos', 'ORG')], [], [('Baltasar', 'PER')], [], [], [('Garibaldi', 'PER')], [], [('Señora Doña Emilia Serrano de Wilson', 'PER')], [('Offland', 'PER')], [('doña María Verdejo', 'PER'), ('Durán', 'PER')], [], [('María Leczinska', 'PER')], [('Otello', 'MISC'), ('Rossini', 'PER')], [('señora Hua', 'PER')], [('doña Carolina Coronado', 'PER')], [], [], [('María Leczinska', 'PER')], [], [], [], [], [('niña Adelaida', 'PER')], [('Esther', 'PER')], [], [('Tetuán', 'LOC')], [], [], [], [], [], [], [('Balada', 'PER')], [], [('Velázquez', 'PER')], [], [], [], [('doña Eulogia', 'PER')], [('Velázquez', 'PER')], [('España', 'ORG'), ('Marruecos', 'ORG')], [('D. José Piquer', 'PER')], [], [('Velázquez', 'PER')], [], [], [('Cuba', 'LOC'), ('Cojimar', 'PER')], [('La ópera de Verdi [...]"-"El marqués de Casa-Riera [...]"-"No podemos resistir el deseo de copiar [ ...

# %%
print(entities_ES)
# Out:
# [[('Sr. D. R. P.', 'MISC')], [('Fragmentos', 'MISC')], [('Desvarío', 'MISC')], [('Soneto', 'PER'), ('inmortal Quintana...', 'MISC')], [('Balada', 'PER')], [('Luna', 'MISC'), ('Mocquet', 'PER')], [('señora M…', 'PER')], [], [], [('Luna', 'MISC')], [('Don B. M.', 'PER')], [('Manzanares', 'LOC')], [('Luna', 'MISC')], [('de la Rosa de Alejandra', 'PER')], [], [('Luna', 'MISC')], [('Sr. D. Agustín Esteban Collantes', 'MISC')], [('Margarita Aurora de Wilson', 'PER'), ('Serrano', 'PER')], [('I', 'PER')], [('Margarita', 'PER')], [], [('Señora doña M. Del Pilar Sinués de Marco', 'PER')], [('II', 'MISC')], [('Margarita', 'PER')], [('Margarita Aurora de Wilson', 'PER'), ('Serrano', 'PER')], [('María', 'PER')], [('Alteza Real', 'PER'), ('Príncipe de Asturias', 'PER')], [('Margarita', 'PER')], [], [('Soneto', 'PER')], [('SS. MM. II', 'PER')], [('El matrimonio de la Princesa real de Inglaterra [...]"', 'MISC')], [('Poesía', 'MISC'), ('Oda', 'PER')], [('Alejandro Dumas', 'PER')], [('Soneto', 'PER')], [], [('SS.', 'MISC'), ('príncipe Mirza-Ally-Kan-Bahadoor', 'PER'), ('Habláse mucho en los círculos aristocrático de un matrimonio [...]', 'MISC')], [], [], [('Ismail', 'PER')], [('Leviatán', 'MISC')], [], [('M. de Lamartine', 'PER')], [], [('Isabel II', 'PER')], [('Hamlet', 'PER')], [('La Malibran', 'MISC'), ('Londres', 'LOC'), ('El gobierno del Brasil [...]', 'MISC')], [('M. de Lamartine', 'PER')], [('Porvenir', 'PER'), ('Francia', 'ORG'), ('Nuevo-Mundo', 'LOC')], [('Confederación Argentina', 'ORG'), ('Uruguay-Le Paraguay', 'ORG')], [('S. M. La emperatriz de los franceses', 'MISC')], [], [('Zurbarán', 'LOC')], [], [('Filadelfia', 'LOC')], [('Ville', 'LOC')], [('Paraguay', 'LOC')], [('Escma', 'ORG'), ('Dª Gertrudis Gómez de Avellaneda', 'PER')], [], [('Leopoldo Robert', 'PER')], [], [], [('Leemos en el Monitor  [...]"', 'MISC'), ('Anuario diplomático de 1859\' [...]"', 'MISC'), ('Alto', 'MISC'), ('Bajo Rin', 'LOC'), ('El matrimonio del hijo mayor [...]"-Savonnette', 'MISC')], [('Ramón de la Sagra', 'PER')], [('Estados-Unidos', 'ORG'), ('Paraguay', 'ORG')], [], [], [('SS. AA. II', 'MISC'), ('princesa Napoleón', 'PER')], [], [('Leopoldo Robert', 'PER'), ('Conclusión', 'ORG')], [('San Petesburgo', 'MISC'), ('El Entreacto publica un acarta fechada en Génova', 'MISC')], [('Memorándum especial por la guerra de Italia', 'MISC')], [], [('Pbro', 'PER'), ('D. Félix Varela', 'PER')], [], [('catedral de Bron', 'LOC')], [], [('Artículo II', 'MISC'), ('Estados-Unidos', 'ORG'), ('Paraguay', 'ORG')], [], [('Deuda', 'MISC')], [('M. Alejandro Dumas', 'PER')], [('Carta del Sr.', 'MISC'), ('Guillemot', 'PER')], [('Napoleón III', 'PER')], [('Víctor Manuel II', 'PER')], [], [('Poesía', 'MISC'), ('Mariano G. Manrique', 'PER')], [], [], [('Poesía', 'MISC'), ('Napoleón III', 'PER')], [('Montmartre', 'LOC'), ('Fragmento', 'MISC')], [], [('Solferino', 'PER')], [('Memorándum especial por la guerra de Italia', 'MISC')], [('Batalla de Solferino', 'MISC')], [('Ejército de Italia', 'ORG')], [('Villafranca', 'LOC')], [('mariscal Vaillant', 'PER'), ('Italia', 'LOC')], [('Poesía', 'MISC')], [('S. M.', 'PER'), ('Napoleón III', 'PER'), ('Fragmentos', 'ORG')], [], [('Baltasar', 'PER')], [], [], [('Garibaldi', 'PER')], [], [('Señora Doña Emilia Serrano de Wilson', 'PER')], [('Offland', 'PER')], [('doña María Verdejo', 'PER'), ('Durán', 'PER')], [], [('María Leczinska', 'PER')], [('Otello', 'MISC'), ('Rossini', 'PER')], [('señora Hua', 'PER')], [('doña Carolina Coronado', 'PER')], [], [], [('María Leczinska', 'PER')], [], [], [], [], [('niña Adelaida', 'PER')], [('Esther', 'PER')], [], [('Tetuán', 'LOC')], [], [], [], [], [], [], [('Balada', 'PER')], [], [('Velázquez', 'PER')], [], [], [], [('doña Eulogia', 'PER')], [('Velázquez', 'PER')], [('España', 'ORG'), ('Marruecos', 'ORG')], [('D. José Piquer', 'PER')], [], [('Velázquez', 'PER')], [], [], [('Cuba', 'LOC'), ('Cojimar', 'PER')], [('La ópera de Verdi [...]"-"El marqués de Casa-Riera [...]"-"No podemos resistir el deseo de copiar [ ...

# %%
#necessary to change also processing function due to depparse won't work with only NER
#(lacking rest of title)
def processing_2(text, nlp_model):
  doc = nlp_model(text)
  return [(word.text, word.lemma, word.upos) for sent in doc.sentences for word in sent.words]

tok = processing_2('Sr. D. R. P.', nlp_es) #it also produces different results for word.lemma and word.upos if we process it without the rest of the title.
tok
# Out:
# [('Sr', 'sr', 'PROPN'),
#  ('.', '.', 'PUNCT'),
#  ('D.', 'd.', 'PROPN'),
#  ('R.', 'R.', 'PROPN'),
#  ('P.', 'p.', 'PROPN')]

# %%
## N: Aquí no he visto diferencia con el código anterior ni entendí lo que querías probar, me lo explicarás por tfo
#proof of that (specially with punctuation):
def processing_2(text, nlp_model):
  doc = nlp_model(text)
  return [(word.text, word.lemma, word.upos) for sent in doc.sentences for word in sent.words]

tok =processing_2('Sr. D. R. P.', nlp_es)
tok
# Out:
# [('Sr', 'sr', 'PROPN'),
#  ('.', '.', 'PUNCT'),
#  ('D.', 'd.', 'PROPN'),
#  ('R.', 'R.', 'PROPN'),
#  ('P.', 'p.', 'PROPN')]

# %%
#//MERGING ENTITIES AND TOKENS FROM EACH LANG
#//(LIST OF SUBLIST WHERE EACH SUBLIST IS A TITLE COMPOSED BY TUPLES WHERE EACH TUPLES IS A TOKEN WITH A LENGTH OF 4):

#necessary to change also processing function due to depparse won't work with only NER
#(lacking rest of title)

def processing_2(text, nlp_model):
  doc = nlp_model(text)
  return [(word.text, word.lemma, word.upos) for sent in doc.sentences for word in sent.words]

processed_entities_ES = []

for lista in entities_ES:
  for tupla in lista:
    tok = processing_2(tupla[0], nlp_es)
    processed_entities_ES.append([tupla, tok])

print(processed_entities_ES)

with open("content/_MERGED_TITLE_NER.txt", "w", encoding="utf-8") as f:
  for element in processed_entities_ES:
    f.write(str(element) + "\n")
#we notice some differences with the way it processes lemmas and POS, without the rest of the title.
#ask Nadège about this
## N: es verdad y lo he pensado cuando te proponía hacerlo. Es normal dado que la "frase" de referencia cambia: el título entero o solo el NER. 
## Es un falso problema dado que mejor vale el análisis sintáctico dentro del título entero que dentro del NER. Será simplemente cuestión de sustituir la sublista
## de tokens (identificado gracias a la serie de tupla[0] que es común entre las tuplas del título y las del modelo aplicado a la str del NER)
# Out:
# [[('Sr. D. R. P.', 'MISC'), [('Sr', 'sr', 'PROPN'), ('.', '.', 'PUNCT'), ('D.', 'd.', 'PROPN'), ('R.', 'R.', 'PROPN'), ('P.', 'p.', 'PROPN')]], [('Fragmentos', 'MISC'), [('Fragmentos', 'fragmentos', 'NOUN')]], [('Desvarío', 'MISC'), [('Desvarío', 'desvarío', 'NOUN')]], [('Soneto', 'PER'), [('Soneto', 'soneto', 'NOUN')]], [('inmortal Quintana...', 'MISC'), [('inmortal', 'inmortal', 'ADJ'), ('Quintana', 'Quintana', 'PROPN'), ('...', '...', 'PUNCT')]], [('Balada', 'PER'), [('Balada', 'Balada', 'PROPN')]], [('Luna', 'MISC'), [('Luna', 'luna', 'PROPN')]], [('Mocquet', 'PER'), [('Mocquet', 'Mocquet', 'PROPN')]], [('señora M…', 'PER'), [('señora', 'señora', 'NOUN'), ('M…', 'm…', 'PROPN')]], [('Luna', 'MISC'), [('Luna', 'luna', 'PROPN')]], [('Don B. M.', 'PER'), [('Don', 'Don', 'PROPN'), ('B.', 'B.', 'PROPN'), ('M.', 'M.', 'PROPN')]], [('Manzanares', 'LOC'), [('Manzanares', 'manzanares', 'PROPN')]], [('Luna', 'MISC'), [('Luna', 'luna', 'PROPN')]], [('de la Rosa de Alejandra', 'PER'), [('de', 'de', 'ADP'), ('la', 'el', 'DET'), ('Rosa', 'Rosa', 'PROPN'), ('de', 'de', 'ADP'), ('Alejandra', 'Alejandra', 'PROPN')]], [('Luna', 'MISC'), [('Luna', 'luna', 'PROPN')]], [('Sr. D. Agustín Esteban Collantes', 'MISC'), [('Sr', 'sr', 'PROPN'), ('.', '.', 'PUNCT'), ('D.', 'd.', 'PROPN'), ('Agustín', 'agustín', 'PROPN'), ('Esteban', 'esteban', 'PROPN'), ('Collantes', 'Collantes', 'PROPN')]], [('Margarita Aurora de Wilson', 'PER'), [('Margarita', 'margarita', 'PROPN'), ('Aurora', 'aurora', 'PROPN'), ('de', 'de', 'ADP'), ('Wilson', 'wilson', 'PROPN')]], [('Serrano', 'PER'), [('Serrano', 'Serrano', 'PROPN')]], [('I', 'PER'), [('I', 'i', 'NUM')]], [('Margarita', 'PER'), [('Margarita', 'margarita', 'PROPN')]], [('Señora doña M. Del Pilar Sinués de Marco', 'PER'), [('Señora', 'señora', 'NOUN'), ('doña', 'doña', 'ADJ'), ('M.', 'M.', 'PROPN'), ('De', 'de', 'ADP'), ('el', 'el', 'DET'), ('Pilar', 'Pilar', 'PROPN'), ('Sinués', 'Sinués', 'PROPN'), ('de', 'de', 'ADP'), ('Marco', 'marco', 'PROPN')]], [('II', 'MISC'), [('II', 'ii', 'NUM')]], [('Margarita', 'PER'), [('Margarita', 'margarita', 'PROPN')]], [('Margarita Aurora de Wilson', 'PER'), [('Margarita', 'margarita', 'PROPN'), ('Aurora', 'aurora', 'PROPN'), ('de', 'de', 'ADP'), ('Wilson', 'wilson', 'PROPN')]], [('Serrano', 'PER'), [('Serrano', 'Serrano', 'PROPN')]], [('María', 'PER'), [('María', 'María', 'PROPN')]], [('Alteza Real', 'PER'), [('Alteza', 'alteza', 'PROPN'), ('Real', 'real', 'PROPN')]], [('Príncipe de Asturias', 'PER'), [('Príncipe', 'Príncipe', 'PROPN'), ('de', 'de', 'ADP'), ('Asturias', 'Asturias', 'PROPN')]], [('Margarita', 'PER'), [('Margarita', 'margarita', 'PROPN')]], [('Soneto', 'PER'), [('Soneto', 'soneto', 'NOUN')]], [('SS. MM. II', 'PER'), [('SS.', 'ss.', 'PROPN'), ('MM.', 'mm.', 'PROPN'), ('II', 'ii', 'NUM')]], [('El matrimonio de la Princesa real de Inglaterra [...]"', 'MISC'), [('El', 'el', 'DET'), ('matrimonio', 'matrimonio', 'NOUN'), ('de', 'de', 'ADP'), ('la', 'el', 'DET'), ('Princesa', 'Princesa', 'PROPN'), ('real', 'real', 'PROPN'), ('de', 'de', 'ADP'), ('Inglaterra', 'inglaterra', 'PROPN'), ('[', '[', 'PUNCT'), ('...', '...', 'PUNCT'), (']', ']', 'PUNCT'), ('"', '"', 'PUNCT')]], [('Poesía', 'MISC'), [('Poesía', 'poesía', 'NOUN')]], [('Oda', 'PER'), [('Oda', 'oda', 'PROPN')]], [('Alejandro Dumas', 'PER'), [('Alejandro', 'alejandro', 'PROPN'), ('Dumas', 'dumas', 'PROPN')]], [('Soneto', 'PER'), [('Soneto', 'soneto', 'NOUN')]], [('SS.', 'MISC'), [('SS', 'ss', 'PROPN'), ('.', '.', 'PUNCT')]], [('príncipe Mirza-Ally-Kan-Bahadoor', 'PER'), [('príncipe', 'príncipe', 'NOUN'), ('Mirza-Ally-Kan-Bahadoor', 'Mirza-Ally-Kan-Bahadoor', 'PROPN')]], [('Habláse mucho en los círculos aristocrático de un matrimonio [...]', 'MISC'), [('Habláse', 'hablar', 'VERB'), ('mucho', 'mucho', 'PRON'), ('en', 'en', 'ADP'), ('los', 'el', 'DET'), ('círculos', 'círculo', 'NOUN'), ('aristocrático', 'aristocrático', 'ADJ'), ('de', 'de', 'ADP'), ('un', 'uno', 'DET'), ('matrimonio', 'matrimonio', 'NOUN'), ('[', '[', 'P ...

# %%
#last code escaping the lines of code that are without NER, as well as jumping line when more than one tuple(entity recognized)
#to solve this:

def processing_2(text, nlp_model):
  doc = nlp_model(text)
  return [(word.text, word.lemma, word.upos) for sent in doc.sentences for word in sent.words]

processed_entities_ES = []

for entity_list in entities_ES:
  row_result = []
  for entity in entity_list:
    text = entity[0]
    tok = processing_2(text, nlp_es)
    row_result.append([entity, tok])

  processed_entities_ES.append(row_result) #IMPORTANT TO NOT INDENT THIS LINE, OTHERWISE IT DOES NOT KEEP EMPTY ROWS(WITHOUT ENTITY)
##
with open("content/_MERGED_TITLE_NER.txt", "w", encoding="utf-8") as f:
    for element in processed_entities_ES:
        f.write(str(element) + "\n")

# %%
processed_entities_ES[:10]
# Out:
# [[[('Sr. D. R. P.', 'MISC'),
#    [('Sr', 'sr', 'PROPN'),
#     ('.', '.', 'PUNCT'),
#     ('D.', 'd.', 'PROPN'),
#     ('R.', 'R.', 'PROPN'),
#     ('P.', 'p.', 'PROPN')]]],
#  [[('Fragmentos', 'MISC'), [('Fragmentos', 'fragmentos', 'NOUN')]]],
#  [[('Desvarío', 'MISC'), [('Desvarío', 'desvarío', 'NOUN')]]],
#  [[('Soneto', 'PER'), [('Soneto', 'soneto', 'NOUN')]],
#   [('inmortal Quintana...', 'MISC'),
#    [('inmortal', 'inmortal', 'ADJ'),
#     ('Quintana', 'Quintana', 'PROPN'),
#     ('...', '...', 'PUNCT')]]],
#  [[('Balada', 'PER'), [('Balada', 'Balada', 'PROPN')]]],
#  [[('Luna', 'MISC'), [('Luna', 'luna', 'PROPN')]],
#   [('Mocquet', 'PER'), [('Mocquet', 'Mocquet', 'PROPN')]]],
#  [[('señora M…', 'PER'),
#    [('señora', 'señora', 'NOUN'), ('M…', 'm…', 'PROPN')]]],
#  [],
#  [],
#  [[('Luna', 'MISC'), [('Luna', 'luna', 'PROPN')]]]]

# %%
# necessary to make some cleaning before NER, specific symbols that are
# problematic %%
## N: creo recordar que había procedido esto sobre todo para los títulos que ocultan subtítulos (aglomeración de varios títulos en uno)
## con la finalidad de tratar cada uno por separado
import re
def clean_text(text):
  cleaned_text = re.sub(r'\s*"\s*|\s*-\s*|\s*\[\.\.\.\]\s*', ' ', text)
  cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()
  return cleaned_text

with open(path, "r", encoding="utf-8") as f:
  rows = f.readlines()
  cleaned_rows = [clean_text(row) for row in rows]

print(cleaned_rows)
#Talk to Nadège: why do we keep other "redundant" things
#such as (Fragmentos), (Continuación) or (Conclusión) %%
#might be nteresting to categorize and create categories with them (maybe as genres?)%%
# Out:
# ['Al Sr. D. R. P. Enviándole mis obras', 'La mujer piadosa (Fragmentos)', 'Desvarío', 'Soneto. ¡Gloria y pobreza! El inmortal Quintana...', 'Balada. La despedida de una hija', 'Un viaje a la Luna. Prólogo: La pesadilla de Mocquet', 'En el álbum de la señora M…', 'La primavera', 'La perejilera', 'Un viaje a la Luna. (Continuación)', 'Al señor Don B. M.', 'A orillas del Manzanares. La súplica', 'Un viaje a la Luna. (Continuación)', 'Fragmentos de la Rosa de Alejandra', 'Gente morena', 'Un viaje a la Luna. (Continuación)', 'Al excmo. Sr. D. Agustín Esteban Collantes, en el día de su santo', 'A la niña Margarita Aurora de Wilson y Serrano, el día de su cumpleaños', 'Costumbres del siglo XIX. I', 'Margarita. Novela bretona', 'Los escondidos y la tapada. Fragmentos', 'A mi apreciable amiga la Señora doña M. Del Pilar Sinués de Marco en su álbum', 'Costumbres del siglo XIX.II', 'Margarita. Novela bretona. (Continuación)', 'A la niña Margarita Aurora de Wilson y Serrano', 'A María', 'A su Alteza Real el Príncipe de Asturias', 'Margarita. Novela bretona. (Conclusión)', 'El otoño', 'Soneto. Aún eco tienen en el alma mía...', 'Atentado contra SS. MM. II.', 'El matrimonio de la Princesa real de Inglaterra Hace algunos años que un banquero muy rico Varios periódicos franceses y del extranjero', 'A la Poesía. Oda', 'A mi buen amigo el distinguido escritor don Alejandro Dumas en prueba de sincera amistad', 'A la luna. Soneto', 'Las apariencias engañan. Historia cuento', 'El viaje de SS. AA. El sábado a la una El príncipe Mirza Ally Kan Bahadoor Habláse mucho en los círculos aristocrático de un matrimonio', 'El invierno', 'La hada azul', 'El lunes 5 del corriente se ha inaugurado Vamos a contar una historia ocurrida en estos días de Pascua Cuando Ismail, generalísimo del ejército otomano', 'El navío Leviatán', 'Ayes del corazón', 'Carta de M. de Lamartine', 'Introducción', 'Isabel II', 'Hamlet', 'Lo que cada lector pide La trata de blancas De la decadencia de las costumbres La Malibran recibía en Londres El gobierno del Brasil', 'Consignamos la acarta original qu enos ha dirigido M. de Lamartine', 'Porvenir de la raza latina y de la Francia en el Nuevo Mundo. Introducción', 'Confederación Argentina y república del Uruguay Le Paraguay', 'S. M. La emperatriz de los franceses', 'Cursos familiares de literatura. La pintura', 'El perro de Zurbarán', 'Serenatas. Introducción. (Fragmentos)', 'Lo que viene a ser un periodista inglés Ha sucedido en los alrededores de Filadelfia Máximas', 'Recuerdo. Un baile en el hotel de Ville, en 1859', 'Abertura del Paraguay y de los ríos', 'La Escma. Sra. Dª Gertrudis Gómez de Avellaneda', 'El 20 de marzo', 'Cursos familiares de literatura. Leopoldo Robert', 'Leyenda pastoral', 'La dalia', "Leemos en el Monitor Según el 'Anuario diplomático de 1859' Hace algunas semanas que los diarios del Alto y del Bajo Rin He aquí la siguiente anécdota Un curioso ha dicho El matrimonio del hijo mayor Savonnette a vilain", 'Carta de Ramón de la Sagra', 'Artículo I. Los Estados Unidos y el Paraguay', 'Costumbres andaluzas. Los dos marineros', 'Viaje por un vestido de boda', 'SS. AA. II el príncipe y la princesa Napoleón', 'El miércoles de ceniza', 'Cursos familiares de literatura. Leopoldo Robert. (Conclusión)', 'Pues que en nuestros días se hacen tantos adelantos en la fotografía Acaba de llegar de San Petesburgo El Entreacto publica un acarta fechada en Génova', 'Memorándum especial por la guerra de Italia', 'Introducción', 'Pbro. D. Félix Varela', 'Las flores de mayo', 'A la catedral de Bron', 'Viaje al rededpr de un vestido de boda. (Conclusiones)', 'Artículo II. Los Estados Unidos y el Paraguay', 'Una de tantas', 'Para que se vea cómo los principales intereses y amortización de la Deuda pública', 'Carta de M. Alejandro Dumas', 'Carta del Sr. Guillemot', 'Napoleón III', 'Víctor Manuel II', 'El oso', 'Poesía. A mi amigo Mariano G. Manrique', 'Perfil inglés', 'La ostra', 'Poesía. A Napoleón III', 'A una tumba en el cementerio d ...

# %%
## No tenemos estos archivos en el repositorio, averigua que no tengas archivos/carpeta en tu local que no aparezcan en el acceso web al repositorio gitlab:
## si es así, necesitas hacer unos git add . /git commit / git push porque significa que solo están en tu copia local del repositorio y que no están indexados 
## (o sea no compartidos ni compartibles)
with open("/content/CLEAN_ALL_TITLES.txt", "w", encoding="utf-8") as f:
    for element in cleaned_rows:
        f.write(str(element) + "\n")

# %%
## aquí me pierdo todo por la misma razón que explicado antes
#let's iterate through same NER function but now on this cleaned corpus %%
def ner1(text, nlp_model):
  doc = nlp_model(text)
  return [(ent.text, ent.type) for ent in doc.entities]

nlp_es = stanza.Pipeline(lang="es", processors="tokenize,mwt,pos,lemma,ner") #IMPORTANTE: EL ORDEN, esto es, lo que antecede afecta a lo siguiente, mientras que lo que precede no)

cleaned_entities_ES = []

for title in cleaned_rows:
  entities_title = ner1(title, nlp_es)
  cleaned_entities_ES.append(entities_title)

print(cleaned_entities_ES)

with open("/content/CLEANED_ENTITIES_ES.txt", "w", encoding="utf-8") as f:
    for element in cleaned_entities_ES:
        f.write(str(element) + "\n")
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: es (Spanish):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | ner       | conll02           |
# =================================
#
# INFO:stanza:Using device: cuda
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!
# [[('Sr. D. R. P.', 'MISC')], [('Fragmentos', 'MISC')], [('Desvarío', 'MISC')], [('Soneto', 'PER'), ('Quintana', 'PER')], [('Balada', 'PER')], [('Luna', 'MISC'), ('Mocquet', 'PER')], [('señora M…', 'PER')], [], [], [('Luna', 'MISC')], [('Don B. M.', 'PER')], [('Manzanares', 'LOC')], [('Luna', 'MISC')], [('de la Rosa de Alejandra', 'PER')], [], [('Luna', 'MISC')], [('Sr. D. Agustín Esteban Collantes', 'MISC')], [('Margarita Aurora de Wilson', 'PER'), ('Serrano', 'PER')], [('I', 'PER')], [('Margarita', 'PER')], [], [('Señora doña M. Del Pilar Sinués de Marco', 'PER')], [('II', 'MISC')], [('Margarita', 'PER')], [('Margarita Aurora de Wilson', 'PER'), ('Serrano', 'PER')], [('María', 'PER')], [('Alteza Real', 'PER'), ('Príncipe de Asturias', 'PER')], [('Margarita', 'PER')], [], [('Soneto', 'PER')], [('SS. MM. II', 'PER')], [('Princesa', 'PER'), ('Inglaterra', 'LOC')], [('Poesía', 'MISC'), ('Oda', 'PER')], [('Alejandro Dumas', 'PER')], [('Soneto', 'PER')], [], [('SS. AA', 'ORG'), ('príncipe Mirza Ally Kan Bahadoor Habláse', 'PER')], [], [], [('Ismail', 'PER')], [('Leviatán', 'MISC')], [], [('M. de Lamartine', 'PER')], [], [('Isabel II', 'PER')], [('Hamlet', 'PER')], [('La Malibran', 'ORG'), ('Londres', 'LOC'), ('Brasil', 'ORG')], [('M. de Lamartine', 'PER')], [('Porvenir', 'PER'), ('Francia', 'ORG'), ('Nuevo Mundo', 'MISC')], [('Confederación Argentina', 'ORG'), ('Uruguay Le Paraguay', 'ORG')], [('S. M. La emperatriz de los franceses', 'MISC')], [], [('Zurbarán', 'LOC')], [], [('Filadelfia Máximas', 'LOC')], [('Ville', 'LOC')], [('Paraguay', 'LOC')], [('Escma', 'ORG'), ('Dª Gertrudis Gómez de Avellaneda', 'PER')], [], [('Leopoldo Robert', 'PER')], [], [], [('Monitor', 'MISC'), ("'Anuario diplomático de 1859", 'MISC'), ('Alto', 'MISC'), ('Bajo Rin', 'LOC'), ('Savonnette', 'PER')], [('Ramón de la Sagra', 'PER')], [('Estados Unidos', 'ORG'), ('Paraguay', 'ORG')], [], [], [('SS. AA. II', 'MISC'), ('princesa Napoleón', 'PER')], [], [('Leopoldo Robert', 'PER'), ('Conclusión', 'ORG')], [('San Petesburgo', 'LOC'), ('Entreacto', 'LOC'), ('Génova', 'LOC')], [('Memorándum especial por la guerra de Italia', 'MISC')], [], [('Pbro', 'PER'), ('D. Félix Varela', 'PER')], [], [('catedral de Bron', 'LOC')], [], [('Artículo II', 'MISC'), ('Estados Unidos', 'ORG'), ('Paraguay', 'ORG')], [], [('Deuda', 'MISC')], [('M. Alejandro Dumas', 'PER')], [('Carta del Sr.', 'MISC'), ('Guillemot', 'PER')], [('Napoleón III', 'PER')], [('Víctor Manuel II', 'PER')], [], [('Poesía', 'MISC'), ('Mariano G. Manrique', 'PER')], [], [], [('Poesía', 'MISC'), ('Napoleón III', 'PER')], [('Montmartre', 'LOC'), ('Fragmento', 'MISC')], [], [('Solferino', 'PER')], [('Memorándum especial por la guerra de Italia', 'MISC')], [('Batalla de Solferino', 'MISC')], [('Ejército de Italia', 'ORG')], [('Villafranca', 'LOC')], [('mariscal Vaillant', 'PER'), ('Italia', 'LOC')], [('Poesía', 'MISC')], [('S. M.', 'PER'), ('Napoleón III', 'PER'), ('Fragmentos', 'ORG')], [], [('Baltasar', 'PER')], [], [], [('Garibaldi', 'PER')], [], [('Señora Doña Emilia Serrano de Wilson', 'PER')], [('Offland', 'PER')], [('doña María Verdejo', 'PER'), ('Durán', 'PER')], [], [('María Leczinska', 'PER')], [('Otello', 'MISC'), ('Rossini', 'PER')], [('señora Hua', 'PER')], [('doña Carolina Coronado', 'PER')], [], [], [('María Leczinska', 'PER')], [], [], [], [], [('niña Adelaida', 'PER')], [('Esther', 'PER')], [], [('Tetuán', 'LOC')], [], [], [], [], [], [], [('Balada', 'PER')], [], [('Velázquez', 'PER')], [], [], [], [('doña Eulogia', 'PER')], [('Velázquez', 'PER')], [('España', 'ORG'), ('Marruecos', 'ORG')], [('D. José Piquer', 'PER')], [], [('Velázquez', 'PER')], [], [], [('Cuba', 'LOC'), ('Cojimar', 'PER')], [('La ópera de Verdi El marqués de Casa Riera', 'LOC')], [('Balada', 'PER')], [('Dolora', 'PER')], [('Colón', 'LOC')], [], [], [], [], [('Macahé', 'PER')], [('Emilia', 'PER')], [('Señor', 'PER')], [], [('Cuba', 'LOC')], [], [], [('Griseldina', 'PER')], [('Araceli Abril de Armendi', 'PER')], [], [('Griseldina',  ...

# %%
#as before, we process NER (tok, lemma, mkw, pos) (NOT depparse)
def processing_2(text, nlp_model):
  doc = nlp_model(text)
  return [(word.text, word.lemma, word.upos) for sent in doc.sentences for word in sent.words]

clean_processed_entities_ES = []

for entity_list in cleaned_entities_ES:
  row_result = []
  for entity in entity_list:
    text = entity[0]
    tok = processing_2(text, nlp_es)
    row_result.append([entity, tok])

  clean_processed_entities_ES.append(row_result) #IMPORTANT TO NOT INDENT THIS LINE, OTHERWISE IT DOES NOT KEEP EMPTY ROWS(WITHOUT ENTITY)

with open("/content/CLEAN_MERGED_TITLE_NER.txt", "w", encoding="utf-8") as f:
    for element in clean_processed_entities_ES:
        f.write(str(element) + "\n")

clean_processed_entities_ES[:10]
# Out:
# [[[('Sr. D. R. P.', 'MISC'),
#    [('Sr', 'sr', 'PROPN'),
#     ('.', '.', 'PUNCT'),
#     ('D.', 'd.', 'PROPN'),
#     ('R.', 'R.', 'PROPN'),
#     ('P.', 'p.', 'PROPN')]]],
#  [[('Fragmentos', 'MISC'), [('Fragmentos', 'fragmentos', 'NOUN')]]],
#  [[('Desvarío', 'MISC'), [('Desvarío', 'desvarío', 'NOUN')]]],
#  [[('Soneto', 'PER'), [('Soneto', 'soneto', 'NOUN')]],
#   [('Quintana', 'PER'), [('Quintana', 'Quintana', 'PROPN')]]],
#  [[('Balada', 'PER'), [('Balada', 'Balada', 'PROPN')]]],
#  [[('Luna', 'MISC'), [('Luna', 'luna', 'PROPN')]],
#   [('Mocquet', 'PER'), [('Mocquet', 'Mocquet', 'PROPN')]]],
#  [[('señora M…', 'PER'),
#    [('señora', 'señora', 'NOUN'), ('M…', 'm…', 'PROPN')]]],
#  [],
#  [],
#  [[('Luna', 'MISC'), [('Luna', 'luna', 'PROPN')]]]]

# %%
cleaned_rows[:5]
# Out:
# ['Al Sr. D. R. P. Enviándole mis obras',
#  'La mujer piadosa (Fragmentos)',
#  'Desvarío',
#  'Soneto. ¡Gloria y pobreza! El inmortal Quintana...',
#  'Balada. La despedida de una hija']

# %%
clean_processed_entities_ES[:5]
# Out:
# [[[('Sr. D. R. P.', 'MISC'),
#    [('Sr', 'sr', 'PROPN'),
#     ('.', '.', 'PUNCT'),
#     ('D.', 'd.', 'PROPN'),
#     ('R.', 'R.', 'PROPN'),
#     ('P.', 'p.', 'PROPN')]]],
#  [[('Fragmentos', 'MISC'), [('Fragmentos', 'fragmentos', 'NOUN')]]],
#  [[('Desvarío', 'MISC'), [('Desvarío', 'desvarío', 'NOUN')]]],
#  [[('Soneto', 'PER'), [('Soneto', 'soneto', 'NOUN')]],
#   [('Quintana', 'PER'), [('Quintana', 'Quintana', 'PROPN')]]],
#  [[('Balada', 'PER'), [('Balada', 'Balada', 'PROPN')]]]]

# %%
#NOR WORKING

#it gets into loop trying to modify the list itself. point to start tomorrow.

new_titulos = []

cleaned_rows_copy = cleaned_rows.copy() #solution to avoid infinite loop, create a new list outside
                                        #as we did in last setps %%

for titulo in clean_processed_entities_ES:
  for componentes in titulo:
    for elementos in componentes:
      for i, row in enumerate(cleaned_rows):
        if elementos[0][0] in row:
          cleaned_rows_copy[i] = row.replace(elementos[0][0], str(elementos))

# %%
cleaned_rows_copy # Result not as expecting.
# Out:
# ["Al Sr. D. ('Revista de París', 'ORG'). P. Enviándole mis obras",
#  "La mujer pia('doña Emilia Serrano de Wilson', 'PER')osa (Fragmentos)",
#  "('D. José Piquer Oda Alzad', 'LOC')esvarío",
#  "('Segundo', 'PER')oneto. ¡Gloria y pobreza! El inmortal Quintana...",
#  "Bala('doña Emilia Serrano de Wilson', 'PER')a. La ('doña Emilia Serrano de Wilson', 'PER')espe('doña Emilia Serrano de Wilson', 'PER')i('doña Emilia Serrano de Wilson', 'PER')a ('doña Emilia Serrano de Wilson', 'PER')e una hija",
#  "Un viaje a la Luna. Prólogo: La pesadilla de ('Moda de Caballeros', 'MISC')ocquet",
#  "En el álbum de la señora ('Moda de Caballeros', 'MISC')…",
#  "('Lemnnier', 'LOC')a primavera",
#  "('Lemnnier', 'LOC')a perejilera",
#  "Un viaje a la ('Lemnnier', 'LOC')una. (Continuación)",
#  "Al señor Don B. ('Moda de Caballeros', 'MISC').",
#  "A orillas del ('Moda de Caballeros', 'MISC')anzanares. La súplica",
#  "Un viaje a la ('Lemnnier', 'LOC')una. (Continuación)",
#  "Fragmentos de la ('Revista de París', 'ORG')osa de Alejandra",
#  "('Guantes', 'LOC')ente morena",
#  "Un viaje a la ('Lemnnier', 'LOC')una. (Continuación)",
#  "Al excmo. ('Segundo', 'PER')r. D. Agustín Esteban Collantes, en el día de su santo",
#  "A la niña Margarita Aurora de Wilson y ('Segundo', 'PER')errano, el día de su cumpleaños",
#  "Costumbres ('doña Emilia Serrano de Wilson', 'PER')el siglo XIX. I",
#  "('Moda de Caballeros', 'MISC')argarita. Novela bretona",
#  "Los escon('doña Emilia Serrano de Wilson', 'PER')i('doña Emilia Serrano de Wilson', 'PER')os y la tapa('doña Emilia Serrano de Wilson', 'PER')a. Fragmentos",
#  "A mi apreciable amiga la ('Segundo', 'PER')eñora doña M. Del Pilar ('Segundo', 'PER')inués de Marco en su álbum",
#  "Costumbres ('doña Emilia Serrano de Wilson', 'PER')el siglo XIX.II",
#  "('Moda de Caballeros', 'MISC')argarita. Novela bretona. (Continuación)",
#  "A la niña Margarita Aurora de Wilson y ('Segundo', 'PER')errano",
#  "A ('Moda de Caballeros', 'MISC')aría",
#  "A su Alteza ('Revista de París', 'ORG')eal el Príncipe de Asturias",
#  "('Moda de Caballeros', 'MISC')argarita. Novela bretona. (Conclusión)",
#  "('Eco Hispano Americano', 'ORG')l otoño",
#  "('Segundo', 'PER')oneto. Aún eco tienen en el alma mía...",
#  "Atentado contra ('Segundo', 'PER')('Segundo', 'PER'). MM. II.",
#  "El matrimonio ('doña Emilia Serrano de Wilson', 'PER')e la Princesa real ('doña Emilia Serrano de Wilson', 'PER')e Inglaterra Hace algunos años que un banquero muy rico Varios perió('doña Emilia Serrano de Wilson', 'PER')icos franceses y ('doña Emilia Serrano de Wilson', 'PER')el extranjero",
#  "A la Poesía. O('doña Emilia Serrano de Wilson', 'PER')a",
#  "A mi buen amigo el ('doña Emilia Serrano de Wilson', 'PER')istingui('doña Emilia Serrano de Wilson', 'PER')o escritor ('doña Emilia Serrano de Wilson', 'PER')on Alejan('doña Emilia Serrano de Wilson', 'PER')ro Dumas en prueba ('doña Emilia Serrano de Wilson', 'PER')e sincera amista('doña Emilia Serrano de Wilson', 'PER')",
#  "A la luna. ('Segundo', 'PER')oneto",
#  "('Lemnnier', 'LOC')as apariencias engañan. Historia cuento",
#  "El viaje de ('Segundo', 'PER')('Segundo', 'PER'). AA. El sábado a la una El príncipe Mirza Ally Kan Bahadoor Habláse mucho en los círculos aristocrático de un matrimonio",
#  "('Eco Hispano Americano', 'ORG')l invierno",
#  "La ha('doña Emilia Serrano de Wilson', 'PER')a azul",
#  "El lunes 5 ('doña Emilia Serrano de Wilson', 'PER')el corriente se ha inaugura('doña Emilia Serrano de Wilson', 'PER')o Vamos a contar una historia ocurri('doña Emilia Serrano de Wilson', 'PER')a en estos ('doña Emilia Serrano de Wilson', 'PER')ías ('doña Emilia Serrano de Wilson', 'PER')e Pascua Cuan('doña Emilia Serrano de Wilson', 'PER')o Ismail, generalísimo ('doña Emilia Serrano de Wilson', 'PER')el ejército otomano",
#  "('Eco Hispano Americano', 'ORG')l navío Leviatán",
#  "Ayes ('doña Emilia Serrano de Wilson', 'PER')el corazón",
#  "Carta de ('Moda de Caballeros', 'MISC'). de Lamartine",
#  "Intro('doña Emilia Serrano de Wilson', 'PER')ucción",
#  "I('señora **', 'MISC')abel II",
#  "('Huéspedes', 'LOC')amlet",
#  "Lo que cada lector pide La trata de blancas De la decadencia de las costumbres La ('Moda de Caballeros', 'MISC')alibran recibía en Londres El gobierno del Brasil",
#  "Consignamos la acarta original qu enos ha dirigido ('Moda de Caballeros', 'MISC'). de Lamartine",
#  "Porvenir de la raza latina y de la Francia en el Nuevo ('Moda de Caballeros', 'MISC')undo. Introducción",
#  "Confe('doña Emilia Serrano de Wilson', 'PER')eración Argentina y república ('doña Emilia Serrano de Wilson', 'PER')el Uruguay Le Paraguay",
#  "('Segundo', 'PER'). M. La emperatriz de los franceses",
#  "Cursos familiares ('doña Emilia Serrano de Wilson', 'PER')e literatura. La pintura",
#  "El perro ('doña Emilia Serrano de Wilson', 'PER')e Zurbarán",
#  "('Segundo', 'PER')erenatas. Introducción. (Fragmentos)",
#  "Lo que viene a ser un periodista inglés Ha sucedido en los alrededores de Filadelfia ('Moda de Caballeros', 'MISC')áximas",
#  "('Revista de París', 'ORG')ecuerdo. Un baile en el hotel de Ville, en 1859",
#  "Abertura ('doña Emilia Serrano de Wilson', 'PER')el Paraguay y ('doña Emilia Serrano de Wilson', 'PER')e los ríos",
#  "La Escma. ('Segundo', 'PER')ra. Dª Gertrudis Gómez de Avellaneda",
#  "El 20 ('doña Emilia Serrano de Wilson', 'PER')e marzo",
#  "Cursos familiares de literatura. Leopoldo ('Revista de París', 'ORG')obert",
#  "Leyen('doña Emilia Serrano de Wilson', 'PER')a pastoral",
#  "La ('doña Emilia Serrano de Wilson', 'PER')alia",
#  "Leemos en el Monitor Según el 'Anuario diplomático de 1859' Hace algunas semanas que los diarios del Alto y del Bajo ('Revista de París', 'ORG')in He aquí la siguiente anécdota Un curioso ha dicho El matrimonio del hijo mayor Savonnette a vilain",
#  "Carta de ('Revista de París', 'ORG')amón de la Sagra",
#  "Artículo I. Los Esta('doña Emilia Serrano de Wilson', 'PER')os Uni('doña Emilia Serrano de Wilson', 'PER')os y el Paraguay",
#  "Costumbres an('doña Emilia Serrano de Wilson', 'PER')aluzas. Los ('doña Emilia Serrano de Wilson', 'PER')os marineros",
#  "Viaje por un vesti('doña Emilia Serrano de Wilson', 'PER')o ('doña Emilia Serrano de Wilson', 'PER')e bo('doña Emilia Serrano de Wilson', 'PER')a",
#  "('Segundo', 'PER')('Segundo', 'PER'). AA. II el príncipe y la princesa Napoleón",
#  "El miércoles ('doña Emilia Serrano de Wilson', 'PER')e ceniza",
#  "Cursos familiares de literatura. Leopoldo ('Revista de París', 'ORG')obert. (Conclusión)",
#  "Pues que en nuestros días se hacen tantos adelantos en la fotografía Acaba de llegar de ('Segundo', 'PER')an Petesburgo El Entreacto publica un acarta fechada en Génova",
#  "('Moda de Caballeros', 'MISC')emorándum especial por la guerra de Italia",
#  "Intro('doña Emilia Serrano de Wilson', 'PER')ucción",
#  "('Petit Courrier des Dames', 'LOC')bro. D. Félix Varela",
#  "Las flores ('doña Emilia Serrano de Wilson', 'PER')e mayo",
#  "A la cate('doña Emilia Serrano de Wilson', 'PER')ral ('doña Emilia Serrano de Wilson', 'PER')e Bron",
#  "Viaje al re('doña Emilia Serrano de Wilson', 'PER')e('doña Emilia Serrano de Wilson', 'PER')pr ('doña Emilia Serrano de Wilson', 'PER')e un vesti('doña Emilia Serrano de Wilson', 'PER')o ('doña Emilia Serrano de Wilson', 'PER')e bo('doña Emilia Serrano de Wilson', 'PER')a. (Conclusiones)",
#  "Artículo II. Los Esta('doña Emilia Serrano de Wilson', 'PER')os Uni('doña Emilia Serrano de Wilson', 'PER')os y el Paraguay",
#  "Una ('doña Emilia Serrano de Wilson', 'PER')e tantas",
#  "Para que se vea cómo los principales intereses y amortización ('doña Emilia Serrano de Wilson', 'PER')e la Deu('doña Emilia Serrano de Wilson', 'PER')a pública",
#  "Carta de ('Moda de Caballeros', 'MISC'). Alejandro Dumas",
#  "Carta del ('Segundo', 'PER')r. Guillemot",
#  "('Nueva Geografía Sangansan', 'MISC')apoleón III",
#  "Víctor ('Moda de Caballeros', 'MISC')anuel II",
#  "('Eco Hispano Americano', 'ORG')l oso",
#  "Poesía. A mi amigo ('Moda de Caballeros', 'MISC')ariano G. ('Moda de Caballeros', 'MISC')anrique",
#  "('Petit Courrier des Dames', 'LOC')erfil inglés",
#  "('Lemnnier', 'LOC')a ostra",
#  "('Petit Courrier des Dames', 'LOC')oesía. A Napoleón III",
#  "A una tumba en el cementerio de ('Moda de Caballeros', 'MISC')ontmartre. (Fragmento)",
#  "Consi('doña Emilia Serrano de Wilson', 'PER')eraciones sobre los vesti('doña Emilia Serrano de Wilson', 'PER')os",
#  "Gran batalla de ('Segundo', 'PER')olferino",
#  "('Moda de Caballeros', 'MISC')emorándum especial por la guerra de Italia",
#  "Batalla de ('Segundo', 'PER')olferino. El emperador a la emperatriz",
#  "Ejército ('doña Emilia Serrano de Wilson', 'PER')e Italia. Proclama",
#  "La entrevista ('doña Emilia Serrano de Wilson', 'PER')e Villafranca. Nuevos ('doña Emilia Serrano de Wilson', 'PER')etalles",
#  "El mariscal Vaillant, mayor general ('doña Emilia Serrano de Wilson', 'PER')el ejército ('doña Emilia Serrano de Wilson', 'PER')e Italia",
#  "Poesía. Costumbres an('doña Emilia Serrano de Wilson', 'PER')aluzas. Un baile ('doña Emilia Serrano de Wilson', 'PER')e can('doña Emilia Serrano de Wilson', 'PER')il",
#  "A ('Segundo', 'PER'). M. el emperador Napoleón III (Fragmentos)",
#  "('Moda de Caballeros', 'MISC')i fotografía",
#  "El festín ('doña Emilia Serrano de Wilson', 'PER')e Baltasar. Estu('doña Emilia Serrano de Wilson', 'PER')io bíblico",
#  "Quién e('señora **', 'MISC') el...",
#  "La primera quincena ('doña Emilia Serrano de Wilson', 'PER')el mes ('doña Emilia Serrano de Wilson', 'PER')e agosto [… ]",
#  "El general Garibal('doña Emilia Serrano de Wilson', 'PER')i",
#  "En sus ('doña Emilia Serrano de Wilson', 'PER')ías",
#  "A la ('Segundo', 'PER')eñora Doña Emilia ('Segundo', 'PER')errano de Wilson en débil muestra de aprecio",
#  "Offlan('doña Emilia Serrano de Wilson', 'PER')",
#  "La señorita doña ('Moda de Caballeros', 'MISC')aría Verdejo y Durán",
#  "Una cifra en un cipré('señora **', 'MISC')",
#  "('Moda de Caballeros', 'MISC')aría Leczinska",
#  "Composición de la ópera Otello por ('Revista de París', 'ORG')ossini",
#  "El robo ('doña Emilia Serrano de Wilson', 'PER')el niño ('doña Emilia Serrano de Wilson', 'PER')e la señora Hua",
#  "La señora [('doña', 'doña', 'NOUN'), ('Emilia', 'emilia', 'PROPN'), ('Serrano', 'Serrano', 'PROPN'), ('de', 'de', 'ADP'), ('Wilson', 'wilson', 'PROPN')] Carolina Coronado",
#  "La granadina. ('Moda de Caballeros', 'MISC')archa guerrera",
#  "('Eco Hispano Americano', 'ORG')l genio",
#  "('Moda de Caballeros', 'MISC')aría Leczinska",
#  "El coro ('doña Emilia Serrano de Wilson', 'PER')e los ángeles",
#  "El kalei('doña Emilia Serrano de Wilson', 'PER')escopio",
#  "El ('doña Emilia Serrano de Wilson', 'PER')uelo ('doña Emilia Serrano de Wilson', 'PER')e las mujeres",
#  "Los secretos ('doña Emilia Serrano de Wilson', 'PER')e la hermosura",
#  "A la niña A('doña Emilia Serrano de Wilson', 'PER')elai('doña Emilia Serrano de Wilson', 'PER')a. En su ('doña Emilia Serrano de Wilson', 'PER')ía",
#  "('Eco Hispano Americano', 'ORG')sther",
#  "Origen ('doña Emilia Serrano de Wilson', 'PER')e algunos instrumentos. La guitarra",
#  "('Teatros', 'ORG')etuán",
#  "El ('doña Emilia Serrano de Wilson', 'PER')uelo ('doña Emilia Serrano de Wilson', 'PER')e las mujeres. (Continuación.)",
#  "('Segundo', 'PER')ecretos de la hermosura. (Continuación)",
#  "L a vuelta ('doña Emilia Serrano de Wilson', 'PER')e la golon('doña Emilia Serrano de Wilson', 'PER')rina. (Fragmentos)",
#  "El ('doña Emilia Serrano de Wilson', 'PER')uelo ('doña Emilia Serrano de Wilson', 'PER')e las mujeres. (Continuación.)",
#  "('Segundo', 'PER')ecretos de la hermosura. (Continuación)",
#  "('Eco Hispano Americano', 'ORG')l sauce",
#  "Bala('doña Emilia Serrano de Wilson', 'PER')a",
#  "El ('doña Emilia Serrano de Wilson', 'PER')uelo ('doña Emilia Serrano de Wilson', 'PER')e las mujeres. (Continuación.)",
#  "La hermana ('doña Emilia Serrano de Wilson', 'PER')e Velázquez",
#  "La cuaresma ('doña Emilia Serrano de Wilson', 'PER')el amor",
#  "Lo mejor ('doña Emilia Serrano de Wilson', 'PER')e una niña",
#  "El ('doña Emilia Serrano de Wilson', 'PER')uelo ('doña Emilia Serrano de Wilson', 'PER')e las mujeres. (Continuación.)",
#  "El museo viviente: colección de cuadros sociales. Cuadro primero: [('doña', 'doña', 'NOUN'), ('Emilia', 'emilia', 'PROPN'), ('Serrano', 'Serrano', 'PROPN'), ('de', 'de', 'ADP'), ('Wilson', 'wilson', 'PROPN')] Eulogia",
#  "La hermana ('doña Emilia Serrano de Wilson', 'PER')e Velázquez",
#  "La oliva. A la paz entre España y ('Moda de Caballeros', 'MISC')arruecos",
#  "Descripción ('doña Emilia Serrano de Wilson', 'PER')el teatro ('doña Emilia Serrano de Wilson', 'PER')e D. José Piquer",
#  "El ('doña Emilia Serrano de Wilson', 'PER')uelo ('doña Emilia Serrano de Wilson', 'PER')e las mujeres. (Continuación.)",
#  "La hermana ('doña Emilia Serrano de Wilson', 'PER')e Velázquez",
#  "El ángel ('doña Emilia Serrano de Wilson', 'PER')e la inclusa",
#  "('Lemnnier', 'LOC')os espejos mágicos. Cuento fantástico",
#  "Cartas ('doña Emilia Serrano de Wilson', 'PER')e Cuba. Cojimar",
#  "Días pasados se hallaba en el bosque La ópera de Verdi El marqués de Casa ('Revista de París', 'ORG')iera No podemos resistir el deseo de copiar",
#  "La cama ('doña Emilia Serrano de Wilson', 'PER')e matrimonio. Bala('doña Emilia Serrano de Wilson', 'PER')a",
#  "Las ('doña Emilia Serrano de Wilson', 'PER')os tumbas. Dolora",
#  "A ('Corsets plastiques de Bonvallet', 'LOC')olón",
#  "Una ma('doña Emilia Serrano de Wilson', 'PER')re",
#  "Un baile ('doña Emilia Serrano de Wilson', 'PER')e manga larga",
#  "La here('doña Emilia Serrano de Wilson', 'PER')a('doña Emilia Serrano de Wilson', 'PER') ben('doña Emilia Serrano de Wilson', 'PER')eci('doña Emilia Serrano de Wilson', 'PER')a",
#  "('Eco Hispano Americano', 'ORG')sto y aquello",
#  "('Moda de Caballeros', 'MISC')acahé",
#  "A ('Eco Hispano Americano', 'ORG')milia. ('Eco Hispano Americano', 'ORG')n su álbum",
#  "La ascensión del ('Segundo', 'PER')eñor",
#  "Una ma('doña Emilia Serrano de Wilson', 'PER')re",
#  "Cartas ('doña Emilia Serrano de Wilson', 'PER')e Cuba. El conuco ('doña Emilia Serrano de Wilson', 'PER')el in('doña Emilia Serrano de Wilson', 'PER')io",
#  "('Austria', 'LOC')mor y fe",
#  "Las ('doña Emilia Serrano de Wilson', 'PER')os rosas",
#  "Grisel('doña Emilia Serrano de Wilson', 'PER')ina",
#  "A mi sobrina Araceli Abril ('doña Emilia Serrano de Wilson', 'PER')e Armen('doña Emilia Serrano de Wilson', 'PER')i",
#  "('Eco Hispano Americano', 'ORG')l mensage",
#  "Grisel('doña Emilia Serrano de Wilson', 'PER')ina",
#  "Cartas ('doña Emilia Serrano de Wilson', 'PER')e Cuba. El conuco ('doña Emilia Serrano de Wilson', 'PER')el in('doña Emilia Serrano de Wilson', 'PER')io",
#  "Una caricia pue('doña Emilia Serrano de Wilson', 'PER')e curar un ('doña Emilia Serrano de Wilson', 'PER')efecto",
#  "('Segundo', 'PER')in princpio ni fin.",
#  "La felici('doña Emilia Serrano de Wilson', 'PER')a('doña Emilia Serrano de Wilson', 'PER')",
#  "En el álbum ('doña Emilia Serrano de Wilson', 'PER')e una niña",
#  "El arte. O('doña Emilia Serrano de Wilson', 'PER')a",
#  "A una ('doña Emilia Serrano de Wilson', 'PER')ama muy galantea('doña Emilia Serrano de Wilson', 'PER')a. En su álbum",
#  "('Segundo', 'PER')in princpio ni fin. Novela de costumbres contemporáneas",
#  "La felici('doña Emilia Serrano de Wilson', 'PER')a('doña Emilia Serrano de Wilson', 'PER')",
#  "Periquito el Velei('doña Emilia Serrano de Wilson', 'PER')oso",
#  "Cartas ('doña Emilia Serrano de Wilson', 'PER')e Cuba (III). El conuco ('doña Emilia Serrano de Wilson', 'PER')el in('doña Emilia Serrano de Wilson', 'PER')io",
#  "A ('Segundo', 'PER')anto Domingo",
#  "El toque ('doña Emilia Serrano de Wilson', 'PER')e la oración",
#  "('Segundo', 'PER')oledad",
#  "('Segundo', 'PER')in princpio ni fin. Novela de costumbres contemporáneas",
#  "Los bailes campestres en ('Segundo', 'PER')antander",
#  "Periquito el Velei('doña Emilia Serrano de Wilson', 'PER')oso (Conclusion)",
#  "Duelos ('doña Emilia Serrano de Wilson', 'PER')e amor",
#  "Allen('doña Emilia Serrano de Wilson', 'PER')e los mares mora",
#  "A la señora doña Emila ('Segundo', 'PER')errano de Wilson en su álbum",
#  "En el álbum de la señorita J. ('Revista de París', 'ORG').",
#  "('Corsets plastiques de Bonvallet', 'LOC')arta",
#  "Ca('doña Emilia Serrano de Wilson', 'PER')a cual en su lugar",
#  "Duelos ('doña Emilia Serrano de Wilson', 'PER')e amor (Conclusión.)",
#  "('Revista de París', 'ORG')olandseck. Tradición",
#  "('Segundo', 'PER')ecretos del tocador",
#  "La ma('doña Emilia Serrano de Wilson', 'PER')re ('doña Emilia Serrano de Wilson', 'PER')e la marquesa",
#  "('Petit Courrier des Dames', 'LOC')oesía",
#  "Ilu('señora **', 'MISC')ión. A el...",
#  "La violeta. ('Segundo', 'PER')oneto",
#  "La ver('doña Emilia Serrano de Wilson', 'PER')a('doña Emilia Serrano de Wilson', 'PER') ('doña Emilia Serrano de Wilson', 'PER')el sentimiento",
#  "De la poesía. ('Segundo', 'PER')u oportunidad y su objeto",
#  "Ca('doña Emilia Serrano de Wilson', 'PER')a cual en su lugar (Conclusión.)",
#  "Viaje de ('Segundo', 'PER')('Segundo', 'PER'). MM.",
#  "('Moda de Caballeros', 'MISC')ariquita",
#  "Entre las aventuras numerosas Cuan('doña Emilia Serrano de Wilson', 'PER')o el general Bonaparte Es notable lo siguiente",
#  "La ma('doña Emilia Serrano de Wilson', 'PER')re ('doña Emilia Serrano de Wilson', 'PER')e la marquesa (Continuación)",
#  "El sargento Pérez. Episodio de dominación francesa en ('Segundo', 'PER')anto Domingo",
#  "('Segundo', 'PER')in princpio ni fin. Novela de costumbres contemporáneas",
#  "('Lemnnier', 'LOC')os pájaros",
#  "('Ucles', 'MISC')na flor",
#  "La mone('doña Emilia Serrano de Wilson', 'PER')a ('doña Emilia Serrano de Wilson', 'PER')e oro",
#  "('Moda de Caballeros', 'MISC')atrimonios por anuncios Los baños de Biarritz Hace pocos días",
#  "La ma('doña Emilia Serrano de Wilson', 'PER')re ('doña Emilia Serrano de Wilson', 'PER')e la marquesa (Continuación)",
#  "A ('Segundo', 'PER')evilla",
#  "('Segundo', 'PER')oneto. Un año más",
#  "Carta I. ('Moda de Caballeros', 'MISC')onserrat",
#  "La mone('doña Emilia Serrano de Wilson', 'PER')a ('doña Emilia Serrano de Wilson', 'PER')e oro",
#  "Un pa('señora **', 'MISC')eo por el lago negro",
#  "La feria ('doña Emilia Serrano de Wilson', 'PER')e Ucles",
#  "La ma('doña Emilia Serrano de Wilson', 'PER')re ('doña Emilia Serrano de Wilson', 'PER')e la marquesa (Continuación)",
#  "Fábula. ('Eco Hispano Americano', 'ORG')l cabello suelto",
#  "('Corsets plastiques de Bonvallet', 'LOC')arta II. Valencia",
#  "La feria ('doña Emilia Serrano de Wilson', 'PER')e Ucles",
#  "De la poesía. ('Segundo', 'PER')u oportunidad y su objeto",
#  "La mone('doña Emilia Serrano de Wilson', 'PER')a ('doña Emilia Serrano de Wilson', 'PER')e oro",
#  "Una ('doña Emilia Serrano de Wilson', 'PER')uquesa octogenaria La señora ('doña Emilia Serrano de Wilson', 'PER')e J El señor X Una al('doña Emilia Serrano de Wilson', 'PER')eana enriqueci('doña Emilia Serrano de Wilson', 'PER')a",
#  "('Lemnnier', 'LOC')a escalera",
#  "('Corsets plastiques de Bonvallet', 'LOC')arta III. Barcelona",
#  "La mone('doña Emilia Serrano de Wilson', 'PER')a ('doña Emilia Serrano de Wilson', 'PER')e oro (Conclusión)",
#  "('Eco Hispano Americano', 'ORG')l Brasil",
#  "El alma ('doña Emilia Serrano de Wilson', 'PER')e ('doña Emilia Serrano de Wilson', 'PER')u('doña Emilia Serrano de Wilson', 'PER')as",
#  "El istmo ('doña Emilia Serrano de Wilson', 'PER')e Panamá",
#  "Una peregrinación a ('Segundo', 'PER')aint Point",
#  "('Segundo', 'PER')in destinos no hay amigos. Proverbio en tres cuadros",
#  "El sombrero ('doña Emilia Serrano de Wilson', 'PER')el empera('doña Emilia Serrano de Wilson', 'PER')or ('doña Emilia Serrano de Wilson', 'PER')e Austria",
#  "('Eco Hispano Americano', 'ORG')l amor",
#  "Feria en ('Segundo', 'PER')evilla",
#  "('Eco Hispano Americano', 'ORG')l lentigo. De su tratamiento",
#  "En la primera página ('doña Emilia Serrano de Wilson', 'PER')e un álbum",
#  "El mundo para unos. ('Segundo', 'PER')oneto",
#  "El mundo para otros. ('Segundo', 'PER')oneto",
#  "Últi('marquesa', 'PER')a hora",
#  "Francisco José. Empera('doña Emilia Serrano de Wilson', 'PER')or ('doña Emilia Serrano de Wilson', 'PER')el Austria",
#  "Constituido ya oficialmente el nuevo ('Moda de Caballeros', 'MISC')inisterio Inglés",
#  "Parte oficial publicado por el Monitor de París sobre la atalla de ('Segundo', 'PER')olferino",
#  "Censo aproximativo En un perió('doña Emilia Serrano de Wilson', 'PER')ico se lee lo siguiente Invento Histórico",
#  "Al señor ('doña Emilia Serrano de Wilson', 'PER')e N. y la señora ***",
#  "El fauno ('doña Emilia Serrano de Wilson', 'PER')e Goysevox",
#  "El prólogo. Episo('doña Emilia Serrano de Wilson', 'PER')io",
#  "('Eco Hispano Americano', 'ORG')l collar",
#  "('Eco Hispano Americano', 'ORG')l cabello rubio",
#  "La esposa ('doña Emilia Serrano de Wilson', 'PER')el sol",
#  "Inauguración ('doña Emilia Serrano de Wilson', 'PER')el teatro ('doña Emilia Serrano de Wilson', 'PER')e D. José Piquer O('doña Emilia Serrano de Wilson', 'PER')a Alza('doña Emilia Serrano de Wilson', 'PER') vuestras tumbas",
#  "Estudios sobre los primeros tiempos de la ('Revista de París', 'ORG')usia",
#  "Estudios sobre los primeros tiempos de la ('Revista de París', 'ORG')usia. (Conclusión.)",
#  "A ('Segundo', 'PER')afo",
#  "('Austria', 'LOC')bnegación",
#  "('Segundo', 'PER')ombreros de Alexandrine",
#  "('Segundo', 'PER')ombreros d'Alexandrine",
#  "('Segundo', 'PER')ombreros De Alexandrine",
#  "('Segundo', 'PER')ombreros De Alexandrine",
#  "('Segundo', 'PER')ombreros d'Alexandrine",
#  "('Segundo', 'PER')ombreros d'Alexandrine",
#  "('Segundo', 'PER')ombreros d'Alexandrine",
#  "En la perfumería ('doña Emilia Serrano de Wilson', 'PER')e Planchais",
#  "('Revista de París', 'ORG')ecomendamos a nuestros lectores los pianos",
#  "Casa ('doña Emilia Serrano de Wilson', 'PER')e comisión para París",
#  "Las enferme('doña Emilia Serrano de Wilson', 'PER')a('doña Emilia Serrano de Wilson', 'PER')es ('doña Emilia Serrano de Wilson', 'PER')el pecho",
#  "('Petit Courrier des Dames', 'LOC')revenimos a nuestros lectores",
#  "('Segundo', 'PER')ombreros d'Alexandrine y Corsets Plastiques Mme. Bonvallet",
#  "('Segundo', 'PER')e alquila una lindísima habitación",
#  "Casas recomen('doña Emilia Serrano de Wilson', 'PER')a('doña Emilia Serrano de Wilson', 'PER')as y artículos en voga",
#  "Corsets plastiques de Bonvallet, Guantes, abanicos y parfumes de Faguer Labollée, Joyas de cabellos Lemnnier, Porcelaines et Cristaux ('Moda de Caballeros', 'MISC')aison de l'Escalier de Cristal",
#  "Casas recomen('doña Emilia Serrano de Wilson', 'PER')a('doña Emilia Serrano de Wilson', 'PER')as",
#  "Cintas y pasamanerías de la fábrica ('Segundo', 'PER')orré Dehsle, Corsets plastiques de Bonvallet, Guantes, abanicos y parfumes de Faguer Labollée, Joyas de cabellos Lemnnier, Porcelaines et Cristaux Maison de l'Escalier de Cristal",
#  "Lait antephelique. Pecas y manchas ('doña Emilia Serrano de Wilson', 'PER')e la cara",
#  "Camisas Clau('doña Emilia Serrano de Wilson', 'PER')io, Hermanos",
#  "('Teatros', 'ORG')intura inglesa instantánea",
#  "Casa particular ('doña Emilia Serrano de Wilson', 'PER')e Huéspe('doña Emilia Serrano de Wilson', 'PER')es",
#  "('Corsets plastiques de Bonvallet', 'LOC')asa Delacroix",
#  "Jules Bloch, ('doña Emilia Serrano de Wilson', 'PER')entista",
#  "La Gaceta ('doña Emilia Serrano de Wilson', 'PER')e Bellas Artes",
#  "Pecas y manchas ('doña Emilia Serrano de Wilson', 'PER')e la cara",
#  "Casas recomen('doña Emilia Serrano de Wilson', 'PER')a('doña Emilia Serrano de Wilson', 'PER')as",
#  "Porta mone('doña Emilia Serrano de Wilson', 'PER')as Despierres",
#  "('Teatros', 'ORG')arifs des insertions",
#  "Cintas y pasamanerías de la fábrica ('Segundo', 'PER')orré Dehsle, Corsets plastiques de Bonvallet, Guantes, abanicos y parfumes de Faguer Labollée, Joyas de cabellos Lemnnier, Porcelaines et Cristaux Maison de l'Escalier de Cristal",
#  "Camisas Clau('doña Emilia Serrano de Wilson', 'PER')io, Hermanos",
#  "Nueva Geografía ('Segundo', 'PER')angansan",
#  "Casa particular ('doña Emilia Serrano de Wilson', 'PER')e Huéspe('doña Emilia Serrano de Wilson', 'PER')es",
#  "('Corsets plastiques de Bonvallet', 'LOC')asa Delacroix",
#  "Jules Bloch, ('doña Emilia Serrano de Wilson', 'PER')entista",
#  "('Petit Courrier des Dames', 'LOC')latería Cristofle",
#  "Casas recomen('doña Emilia Serrano de Wilson', 'PER')a('doña Emilia Serrano de Wilson', 'PER')as",
#  "('Teatros', 'ORG')arifs des insertions",
#  "Cintas y pasamanerías de la fábrica ('Segundo', 'PER')orré Dehsle, Corsets plastiques de Bonvallet, Guantes, abanicos y parfumes de Faguer Labollée, Joyas de cabellos Lemnnier, Porcelaines et Cristaux Maison de l'Escalier de Cristal",
#  "Camisas Clau('doña Emilia Serrano de Wilson', 'PER')io, Hermanos",
#  "Nueva Geografía ('Segundo', 'PER')angansan",
#  "Casa particular ('doña Emilia Serrano de Wilson', 'PER')e Huéspe('doña Emilia Serrano de Wilson', 'PER')es",
#  "('Corsets plastiques de Bonvallet', 'LOC')asa Delacroix",
#  "Jules Bloch, ('doña Emilia Serrano de Wilson', 'PER')entista",
#  "('Petit Courrier des Dames', 'LOC')latería Cristofle",
#  "Casas recomen('doña Emilia Serrano de Wilson', 'PER')a('doña Emilia Serrano de Wilson', 'PER')as",
#  "('Teatros', 'ORG')arifs des insertions",
#  "Camisas Clau('doña Emilia Serrano de Wilson', 'PER')io, Hermanos",
#  "Nueva Geografía ('Segundo', 'PER')angansan",
#  "Casa particular ('doña Emilia Serrano de Wilson', 'PER')e Huéspe('doña Emilia Serrano de Wilson', 'PER')es",
#  "('Corsets plastiques de Bonvallet', 'LOC')asa Delacroix",
#  "Jules Bloch, ('doña Emilia Serrano de Wilson', 'PER')entista",
#  "('Petit Courrier des Dames', 'LOC')latería Cristofle",
#  "Casas recomen('doña Emilia Serrano de Wilson', 'PER')a('doña Emilia Serrano de Wilson', 'PER')as",
#  "('Teatros', 'ORG')arifs des insertions",
#  "Camisas Clau('doña Emilia Serrano de Wilson', 'PER')io, Hermanos",
#  "Nueva Geografía ('Segundo', 'PER')angansan",
#  "Casa particular ('doña Emilia Serrano de Wilson', 'PER')e Huéspe('doña Emilia Serrano de Wilson', 'PER')es",
#  "('Corsets plastiques de Bonvallet', 'LOC')asa Delacroix",
#  "Jules Bloch, ('doña Emilia Serrano de Wilson', 'PER')entista",
#  "('Petit Courrier des Dames', 'LOC')latería Cristofle",
#  "Casas recomen('doña Emilia Serrano de Wilson', 'PER')a('doña Emilia Serrano de Wilson', 'PER')as",
#  "('Petit Courrier des Dames', 'LOC')latería Cristofle",
#  "Camisas Clau('doña Emilia Serrano de Wilson', 'PER')io, Hermanos",
#  "Nueva Geografía ('Segundo', 'PER')angansan",
#  "Casa particular ('doña Emilia Serrano de Wilson', 'PER')e Huéspe('doña Emilia Serrano de Wilson', 'PER')es",
#  "('Corsets plastiques de Bonvallet', 'LOC')asa Delacroix",
#  "Jules Bloch, ('doña Emilia Serrano de Wilson', 'PER')entista",
#  "Casas recomen('doña Emilia Serrano de Wilson', 'PER')a('doña Emilia Serrano de Wilson', 'PER')as",
#  "Cintas y pasamanerías de la fábrica ('Segundo', 'PER')orré Dehsle, Corsets plastiques de Bonvallet, Guantes, abanicos y parfumes de Faguer Labollée, Joyas de cabellos Lemnnier, Porcelaines et Cristaux Maison de l'Escalier de Cristal",
#  "Camisas Clau('doña Emilia Serrano de Wilson', 'PER')io, Hermanos",
#  "Nueva Geografía ('Segundo', 'PER')angansan",
#  "Casa particular ('doña Emilia Serrano de Wilson', 'PER')e Huéspe('doña Emilia Serrano de Wilson', 'PER')es",
#  "('Corsets plastiques de Bonvallet', 'LOC')asa Delacroix",
#  "Jules Bloch, ('doña Emilia Serrano de Wilson', 'PER')entista",
#  "('Petit Courrier des Dames', 'LOC')latería Cristofle",
#  "Camisas Clau('doña Emilia Serrano de Wilson', 'PER')io, Hermanos",
#  "Nueva Geografía ('Segundo', 'PER')angansan",
#  "Casa particular ('doña Emilia Serrano de Wilson', 'PER')e Huéspe('doña Emilia Serrano de Wilson', 'PER')es",
#  "('Corsets plastiques de Bonvallet', 'LOC')asa Delacroix",
#  "Jules Bloch, ('doña Emilia Serrano de Wilson', 'PER')entista",
#  "('Petit Courrier des Dames', 'LOC')latería Cristofle",
#  "Casas recomen('doña Emilia Serrano de Wilson', 'PER')a('doña Emilia Serrano de Wilson', 'PER')as",
#  "Cintas y pasamanerías de la fábrica ('Segundo', 'PER')orré Dehsle, Corsets plastiques de Bonvallet, Guantes, abanicos y parfumes de Faguer Labollée, Joyas de cabellos Lemnnier, Porcelaines et Cristaux Maison de l'Escalier de Cristal",
#  "Camisas Clau('doña Emilia Serrano de Wilson', 'PER')io, Hermanos",
#  "Nueva Geografía ('Segundo', 'PER')angansan",
#  "Casa particular ('doña Emilia Serrano de Wilson', 'PER')e Huéspe('doña Emilia Serrano de Wilson', 'PER')es",
#  "('Corsets plastiques de Bonvallet', 'LOC')asa Delacroix",
#  "Jules Bloch, ('doña Emilia Serrano de Wilson', 'PER')entista",
#  "('Petit Courrier des Dames', 'LOC')latería Cristofle",
#  "Cintas y pasamanerías de la fábrica ('Segundo', 'PER')orré Dehsle, Corsets plastiques de Bonvallet, Guantes, abanicos y parfumes de Faguer Labollée, Joyas de cabellos Lemnnier, Porcelaines et Cristaux Maison de l'Escalier de Cristal",
#  "('Petit Courrier des Dames', 'LOC')latería Cristofle",
#  "Obras de la señora doña Emilia ('Segundo', 'PER')errano de Wilson",
#  "('Petit Courrier des Dames', 'LOC')latería Cristofle",
#  "Obras de la señora doña Emilia ('Segundo', 'PER')errano de Wilson",
#  "('Petit Courrier des Dames', 'LOC')latería Cristofle",
#  "Obras de la señora doña Emilia ('Segundo', 'PER')errano de Wilson",
#  "('Moda de Caballeros', 'MISC')odes de Paris. Petit Courrier des Dames",
#  "El [('Eco', 'Eco', 'PROPN'), ('Hispano', 'hispano', 'PROPN'), ('Americano', 'americano', 'PROPN')] Hispano Americano",
#  "Obras de la señora doña Emilia ('Segundo', 'PER')errano de Wilson",
#  "El [('Eco', 'Eco', 'PROPN'), ('Hispano', 'hispano', 'PROPN'), ('Americano', 'americano', 'PROPN')] Hispano Americano",
#  "('Austria', 'LOC')nuncio",
#  "Obras de la señora doña Emilia ('Segundo', 'PER')errano de Wilson",
#  "Explicación ('doña Emilia Serrano de Wilson', 'PER')e la lámina ('doña Emilia Serrano de Wilson', 'PER')e tapicería",
#  "Explicación ('doña Emilia Serrano de Wilson', 'PER')e la lámina ('doña Emilia Serrano de Wilson', 'PER')e tapicería",
#  "Explicación ('doña Emilia Serrano de Wilson', 'PER')el figurín",
#  "[('Moda', 'Moda', 'PROPN'), ('de', 'de', 'ADP'), ('Caballeros', 'Caballeros', 'PROPN')] de Caballeros",
#  "Explicación ('doña Emilia Serrano de Wilson', 'PER')el figurín 1º",
#  "Explicación ('doña Emilia Serrano de Wilson', 'PER')el figurín 2º",
#  "Descripción ('doña Emilia Serrano de Wilson', 'PER')el figurín: primer y segun('doña Emilia Serrano de Wilson', 'PER')o traje",
#  "Descripción ('doña Emilia Serrano de Wilson', 'PER')el figurín: traje ('doña Emilia Serrano de Wilson', 'PER')e la novia y ('doña Emilia Serrano de Wilson', 'PER')e la ma('doña Emilia Serrano de Wilson', 'PER')re",
#  "Explicación ('doña Emilia Serrano de Wilson', 'PER')el figurín",
#  "Descripción ('doña Emilia Serrano de Wilson', 'PER')el figurín ('doña Emilia Serrano de Wilson', 'PER')e baile",
#  "Figurín ('doña Emilia Serrano de Wilson', 'PER')e visita",
#  "Explicación ('doña Emilia Serrano de Wilson', 'PER')el figurín",
#  "Explicación ('doña Emilia Serrano de Wilson', 'PER')el figurín",
#  "Explicación ('doña Emilia Serrano de Wilson', 'PER')el figurín",
#  "Explicación ('doña Emilia Serrano de Wilson', 'PER')el figurín",
#  "Explicación ('doña Emilia Serrano de Wilson', 'PER')el figurín",
#  "Explicación ('doña Emilia Serrano de Wilson', 'PER')el figurín",
#  "Explicación ('doña Emilia Serrano de Wilson', 'PER')e los figurines. Primero",
#  "Explicación de los figurines. [('Segundo', 'segundo', 'ADJ')]",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de la moda",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de la moda",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de la moda",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de la moda",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de la moda",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de la moda",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas, salones y teatros",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas, salones y teatros",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas, salones y teatros",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas, salones y teatros",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas, salones y teatros",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórica del mes",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] Parisense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórica del mes",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] Parisense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórica del mes",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] Parisense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] Parisense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] Parisense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] Parisiense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] Parisiense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórico política",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] Parisiense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórico política",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] Parisiense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórico política",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de teatros",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de Madrid",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de teatros",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] Parisiense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de Madrid",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de teatros",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] Parisiense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de Madrid",
#  "('Corsets plastiques de Bonvallet', 'LOC')rónica parisiense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de teatros",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] Parisiense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de Madrid",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de teatros",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] Parisiense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de Madrid",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] Parisiense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de Madrid",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] Parisiense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de Madrid",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] Parisiense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de Madrid",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de Madrid",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París",
#  "[('Teatros', 'Teatros', 'PROPN')]",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de Madrid",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de Madrid",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de Madrid",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de Madrid",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de Madrid",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de Madrid",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de Madrid",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de Madrid",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de Madrid",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de modas",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórica del mes",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórica del mes",
#  "('Corsets plastiques de Bonvallet', 'LOC')rónica parisiense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórica del mes",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórica del mes",
#  "('Corsets plastiques de Bonvallet', 'LOC')rónica parisiense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórica del mes",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórica del mes",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórica del mes",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórica del mes",
#  "('Corsets plastiques de Bonvallet', 'LOC')rónica parisiense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórica del mes",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórica del mes",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórica del mes",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórica del mes",
#  "('Corsets plastiques de Bonvallet', 'LOC')rónica parisiense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórica del mes",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórica del mes",
#  "('Corsets plastiques de Bonvallet', 'LOC')rónica parisiense",
#  "[('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] histórica del mes",
#  "('Corsets plastiques de Bonvallet', 'LOC')rónica parisiense",
#  "('Corsets plastiques de Bonvallet', 'LOC')rónica parisiense",
#  "('Corsets plastiques de Bonvallet', 'LOC')rónica parisiense",
#  "('Corsets plastiques de Bonvallet', 'LOC')rónica parisiense"]

# %%
#Let's try another way using 're'

import re
#clean_processed_entities_ES
cleaned_rows_copy = cleaned_rows.copy()

for i, titulo in enumerate(clean_processed_entities_ES):
  for componentes in titulo:
    for elementos in componentes:
      entity_str = elementos[0][0]
      replacement_str = f"[({elementos[0]}, {elementos[1]})]" if len(elementos) > 1 else f"[({elementos[0]})]"
      cleaned_rows_copy[i] = re.sub(rf'\b{entity_str}\b', replacement_str, cleaned_rows_copy[i])

      #for i, row in enumerate(cleaned_rows):
        #if entity_str in row:
          #for row_copy in cleaned_rows_copy:
            #cleaned_rows_copy[i] = re.sub(rf'\b{entity_str}\b', replacement_str, cleaned_rows_copy[i])

print("\n".join(cleaned_rows_copy))
#!!!RESULT NOT AS EXPECTED. failing to identify all the string
#wrong results as these ones (not identifying properly and completely string to identify so leading to wrong results): &&
#[(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid &&
# Out:
# Al [(('Sr', 'sr', 'PROPN'), ('.', '.', 'PUNCT'))]. D. R. P. Enviándole mis obras
# La mujer piadosa ([(('Fragmentos', 'fragmentos', 'NOUN'))])
# [(('Desvarío', 'desvarío', 'NOUN'))]
# [(('Soneto', 'soneto', 'NOUN'))]. ¡Gloria y pobreza! El inmortal [(('Quintana', 'Quintana', 'PROPN'))]...
# [(('Balada', 'Balada', 'PROPN'))]. La despedida de una hija
# Un viaje a la [(('Luna', 'luna', 'PROPN'))]. Prólogo: La pesadilla de [(('Mocquet', 'Mocquet', 'PROPN'))]
# En el álbum de la [(('señora', 'señora', 'NOUN'), ('M…', 'm…', 'PROPN'))] M…
# La primavera
# La perejilera
# Un viaje a la [(('Luna', 'luna', 'PROPN'))]. (Continuación)
# Al señor [(('Don', 'Don', 'PROPN'), ('B.', 'B.', 'PROPN'))] B. M.
# A orillas del [(('Manzanares', 'manzanares', 'PROPN'))]. La súplica
# Un viaje a la [(('Luna', 'luna', 'PROPN'))]. (Continuación)
# Fragmentos [(('de', 'de', 'ADP'), ('la', 'el', 'DET'))] la Rosa [(('de', 'de', 'ADP'), ('la', 'el', 'DET'))] Alejandra
# Gente morena
# Un viaje a la [(('Luna', 'luna', 'PROPN'))]. (Continuación)
# Al excmo. [(('Sr', 'sr', 'PROPN'), ('.', '.', 'PUNCT'))]. D. Agustín Esteban Collantes, en el día de su santo
# A la niña [(('Margarita', 'margarita', 'PROPN'), ('Aurora', 'aurora', 'PROPN'))] Aurora de Wilson y [(('Serrano', 'Serrano', 'PROPN'))], el día de su cumpleaños
# Costumbres del siglo XIX. [([(('I', 'i', 'NUM'))], PER)]
# [(('Margarita', 'margarita', 'PROPN'))]. Novela bretona
# Los escondidos y la tapada. Fragmentos
# A mi apreciable amiga la [(('Señora', 'señora', 'NOUN'), ('doña', 'doña', 'ADJ'))] doña M. Del Pilar Sinués de Marco en su álbum
# Costumbres del siglo XIX.[(('II', 'ii', 'NUM'))]
# [(('Margarita', 'margarita', 'PROPN'))]. Novela bretona. (Continuación)
# A la niña [(('Margarita', 'margarita', 'PROPN'), ('Aurora', 'aurora', 'PROPN'))] Aurora de Wilson y [(('Serrano', 'Serrano', 'PROPN'))]
# A [(('María', 'María', 'PROPN'))]
# [([(('Alteza', 'alteza', 'PROPN'), ('Real', 'real', 'PROPN'))] Real, PER)] su [(('Alteza', 'alteza', 'PROPN'), ('Real', 'real', 'PROPN'))] Real el [(('Príncipe', 'Príncipe', 'PROPN'), ('de', 'de', 'ADP'))] de Asturias
# [(('Margarita', 'margarita', 'PROPN'))]. Novela bretona. (Conclusión)
# El otoño
# [(('Soneto', 'soneto', 'NOUN'))]. Aún eco tienen en el alma mía...
# Atentado contra SS. MM. II.
# El matrimonio de la [(('Princesa', 'Princesa', 'PROPN'))] real de [(('Inglaterra', 'inglaterra', 'PROPN'))] Hace algunos años que un banquero muy rico Varios periódicos franceses y del extranjero
# A la [(('Poesía', 'poesía', 'NOUN'))]. [(('Oda', 'oda', 'PROPN'))]
# [([(('Alejandro', 'alejandro', 'PROPN'), ('Dumas', 'dumas', 'PROPN'))] Dumas, PER)] mi buen amigo el distinguido escritor don [(('Alejandro', 'alejandro', 'PROPN'), ('Dumas', 'dumas', 'PROPN'))] Dumas en prueba de sincera amistad
# A la luna. [(('Soneto', 'soneto', 'NOUN'))]
# Las apariencias engañan. Historia cuento
# El viaje de [(('SS', 'ss', 'PROPN'), ('.', '.', 'PUNCT'))]. AA. El sábado a la una El [(('príncipe', 'príncipe', 'NOUN'), ('Mirza', 'Mirza', 'PROPN'))] Mirza Ally Kan Bahadoor Habláse mucho en los círculos aristocrático de un matrimonio
# El invierno
# La hada azul
# El lunes 5 del corriente se ha inaugurado Vamos a contar una historia ocurrida en estos días de Pascua Cuando [(('Ismail', 'Ismail', 'PROPN'))], generalísimo del ejército otomano
# El navío [(('Leviatán', 'leviatán', 'PROPN'))]
# Ayes del corazón
# Carta de [(M. de Lamartine, PER)]. de Lamartine
# Introducción
# [(('Isabel', 'isabel', 'PROPN'), ('II', 'ii', 'NUM'))] II
# [(('Hamlet', 'Hamlet', 'PROPN'))]
# Lo que cada lector pide [(('La', 'el', 'DET'), ('Malibran', 'malibran', 'PROPN'))] trata de blancas De la decadencia de las costumbres [(('La', 'el', 'DET'), ('Malibran', 'malibran', 'PROPN'))] Malibran recibía en [(('Londres', 'Londres', 'PROPN'))] El gobierno del [(('Brasil', 'Brasil', 'PROPN'))]
# Consignamos la acarta original qu enos ha dirigido [(M. de Lamartine, PER)]. de Lamartine
# [(('Porvenir', 'porvenir', 'PROPN'))] de la raza latina y de la [(('Francia', 'francia', 'PROPN'))] en el [(('Nuevo', 'nuevo', 'PROPN'), ('Mundo', 'Mundo', 'PROPN'))] Mundo. Introducción
# [(('Confederación', 'Confederación', 'PROPN'), ('Argentina', 'argentina', 'PROPN'))] Argentina y república del [(('Uruguay', 'Uruguay', 'PROPN'), ('Le', 'él', 'PRON'))] Le Paraguay
# [(S. M. La emperatriz de los franceses, MISC)]. M. La emperatriz de los franceses
# Cursos familiares de literatura. La pintura
# El perro de [(('Zurbarán', 'zurbarán', 'PROPN'))]
# Serenatas. Introducción. (Fragmentos)
# Lo que viene a ser un periodista inglés Ha sucedido en los alrededores de [(('Filadelfia', 'filadelfia', 'PROPN'), ('Máximas', 'Máximas', 'PROPN'))] Máximas
# Recuerdo. Un baile en el hotel de [(('Ville', 'ville', 'PROPN'))], en 1859
# Abertura del [(('Paraguay', 'paraguay', 'PROPN'))] y de los ríos
# La [(('Escma', 'Escma', 'PROPN'))]. Sra. [(('Dª', 'dª', 'PROPN'), ('Gertrudis', 'Gertrudis', 'PROPN'))] Gertrudis Gómez de Avellaneda
# El 20 de marzo
# Cursos familiares de literatura. [(('Leopoldo', 'Leopoldo', 'PROPN'), ('Robert', 'robert', 'PROPN'))] Robert
# Leyenda pastoral
# La dalia
# Leemos en el [(('Monitor', 'Monitor', 'PROPN'))] Según el 'Anuario diplomático de 1859' Hace algunas semanas que los diarios del [(('Alto', 'alto', 'ADJ'))] y del [(('Bajo', 'bajo', 'PROPN'), ('Rin', 'rin', 'PROPN'))] Rin He aquí la siguiente anécdota Un curioso ha dicho El matrimonio del hijo mayor [(('Savonnette', 'savonnette', 'PROPN'))] a vilain
# Carta de [(('Ramón', 'ramón', 'PROPN'), ('de', 'de', 'ADP'))] de la Sagra
# Artículo I. Los [(('Estados', 'Estados', 'PROPN'), ('Unidos', 'unido', 'PROPN'))] Unidos y el [(('Paraguay', 'paraguay', 'PROPN'))]
# Costumbres andaluzas. Los dos marineros
# Viaje por un vestido de boda
# SS. AA. II el príncipe y la [(('princesa', 'princesa', 'NOUN'), ('Napoleón', 'napoleón', 'PROPN'))] Napoleón
# El miércoles de ceniza
# Cursos familiares de literatura. [(('Leopoldo', 'Leopoldo', 'PROPN'), ('Robert', 'robert', 'PROPN'))] Robert. ([(('Conclusión', 'conclusión', 'NOUN'))])
# Pues que en nuestros días se hacen tantos adelantos en la fotografía Acaba de llegar de [(('San', 'san', 'PROPN'), ('Petesburgo', 'petesburgo', 'PROPN'))] Petesburgo El [(('Entreacto', 'entreacto', 'NOUN'))] publica un acarta fechada en [(('Génova', 'génova', 'PROPN'))]
# [(('Memorándum', 'Memorándum', 'NOUN'), ('especial', 'especial', 'ADJ'))] especial por la guerra de Italia
# Introducción
# [(('Pbro', 'pbro', 'PROPN'))]. [(D. Félix Varela, PER)]. Félix Varela
# Las flores de mayo
# A la [(('catedral', 'catedral', 'NOUN'), ('de', 'de', 'ADP'))] de Bron
# Viaje al rededpr de un vestido de boda. (Conclusiones)
# [(('Artículo', 'artículo', 'NOUN'), ('II', 'ii', 'NUM'))] II. Los [(('Estados', 'Estados', 'PROPN'), ('Unidos', 'unido', 'PROPN'))] Unidos y el [(('Paraguay', 'paraguay', 'PROPN'))]
# Una de tantas
# Para que se vea cómo los principales intereses y amortización de la [(('Deuda', 'deuda', 'PROPN'))] pública
# Carta de [(M. Alejandro Dumas, PER)]. Alejandro Dumas
# [(('Carta', 'carta', 'NOUN'), ('de', 'de', 'ADP'))] del Sr. [(('Guillemot', 'Guillemot', 'PROPN'))]
# [(('Napoleón', 'napoleón', 'PROPN'), ('III', 'iii', 'NUM'))] III
# [(('Víctor', 'Víctor', 'PROPN'), ('Manuel', 'Manuel', 'PROPN'))] Manuel II
# El oso
# [(('Poesía', 'poesía', 'NOUN'))]. A mi amigo [(('Mariano', 'mariano', 'PROPN'), ('G.', 'G.', 'PROPN'))] G. Manrique
# Perfil inglés
# La ostra
# [(('Poesía', 'poesía', 'NOUN'))]. A [(('Napoleón', 'napoleón', 'PROPN'), ('III', 'iii', 'NUM'))] III
# A una tumba en el cementerio de [(('Montmartre', 'montmartre', 'PROPN'))]. ([(('Fragmento', 'fragmento', 'NOUN'))])
# Consideraciones sobre los vestidos
# Gran batalla de [(('Solferino', 'Solferino', 'PROPN'))]
# [(('Memorándum', 'Memorándum', 'NOUN'), ('especial', 'especial', 'ADJ'))] especial por la guerra de Italia
# [(('Batalla', 'batalla', 'NOUN'), ('de', 'de', 'ADP'))] de Solferino. El emperador a la emperatriz
# [(('Ejército', 'Ejército', 'PROPN'), ('de', 'de', 'ADP'))] de Italia. Proclama
# La entrevista de [(('Villafranca', 'villafranca', 'PROPN'))]. Nuevos detalles
# El [(('mariscal', 'mariscal', 'NOUN'), ('Vaillant', 'Vaillant', 'PROPN'))] Vaillant, mayor general del ejército de [(('Italia', 'Italia', 'PROPN'))]
# [(('Poesía', 'poesía', 'NOUN'))]. Costumbres andaluzas. Un baile de candil
# A [(S. M., PER)]. M. el emperador [(('Napoleón', 'napoleón', 'PROPN'), ('III', 'iii', 'NUM'))] III ([(('Fragmentos', 'fragmentos', 'NOUN'))])
# Mi fotografía
# El festín de [(('Baltasar', 'Baltasar', 'PROPN'))]. Estudio bíblico
# Quién es el...
# La primera quincena del mes de agosto [… ]
# El general [(('Garibaldi', 'garibaldi', 'PROPN'))]
# En sus días
# A la [(('Señora', 'señora', 'NOUN'), ('Doña', 'Doña', 'PROPN'))] Doña Emilia Serrano de Wilson en débil muestra de aprecio
# [(('Offland', 'offland', 'PROPN'))]
# La señorita [(('doña', 'doña', 'NOUN'), ('María', 'María', 'PROPN'))] María Verdejo y [(('Durán', 'durán', 'PROPN'))]
# Una cifra en un ciprés
# [(('María', 'María', 'PROPN'), ('Leczinska', 'leczinska', 'PROPN'))] Leczinska
# Composición de la ópera [(('Otello', 'otello', 'PROPN'))] por [(('Rossini', 'Rossini', 'PROPN'))]
# El robo del niño de la [(('señora', 'señora', 'NOUN'), ('Hua', 'hua', 'PROPN'))] Hua
# La señora [(('doña', 'doña', 'NOUN'), ('Carolina', 'carolina', 'PROPN'))] Carolina Coronado
# La granadina. Marcha guerrera
# El genio
# [(('María', 'María', 'PROPN'), ('Leczinska', 'leczinska', 'PROPN'))] Leczinska
# El coro de los ángeles
# El kaleidescopio
# El duelo de las mujeres
# Los secretos de la hermosura
# A la [(('niña', 'niña', 'NOUN'), ('Adelaida', 'adelaida', 'PROPN'))] Adelaida. En su día
# [(('Esther', 'Esther', 'PROPN'))]
# Origen de algunos instrumentos. La guitarra
# [(('Tetuán', 'tetuán', 'PROPN'))]
# El duelo de las mujeres. (Continuación.)
# Secretos de la hermosura. (Continuación)
# L a vuelta de la golondrina. (Fragmentos)
# El duelo de las mujeres. (Continuación.)
# Secretos de la hermosura. (Continuación)
# El sauce
# [(('Balada', 'Balada', 'PROPN'))]
# El duelo de las mujeres. (Continuación.)
# La hermana de [(('Velázquez', 'velázquez', 'PROPN'))]
# La cuaresma del amor
# Lo mejor de una niña
# El duelo de las mujeres. (Continuación.)
# El museo viviente: colección de cuadros sociales. Cuadro primero: [(('doña', 'doña', 'NOUN'), ('Eulogia', 'Eulogia', 'PROPN'))] Eulogia
# La hermana de [(('Velázquez', 'velázquez', 'PROPN'))]
# La oliva. A la paz entre [(('España', 'España', 'PROPN'))] y [(('Marruecos', 'Marruecos', 'PROPN'))]
# Descripción del teatro de [(D. José Piquer, PER)]. José Piquer
# El duelo de las mujeres. (Continuación.)
# La hermana de [(('Velázquez', 'velázquez', 'PROPN'))]
# El ángel de la inclusa
# Los espejos mágicos. Cuento fantástico
# Cartas de [(('Cuba', 'Cuba', 'PROPN'))]. [(('Cojimar', 'cojimar', 'PROPN'))]
# Días pasados se hallaba en el bosque [(('La', 'el', 'DET'), ('ópera', 'ópera', 'NOUN'))] ópera de Verdi El marqués de Casa Riera No podemos resistir el deseo de copiar
# La cama de matrimonio. [(('Balada', 'Balada', 'PROPN'))]
# Las dos tumbas. [(('Dolora', 'Dolora', 'PROPN'))]
# A [(('Colón', 'colón', 'PROPN'))]
# Una madre
# Un baile de manga larga
# La heredad bendecida
# Esto y aquello
# [(('Macahé', 'Macahé', 'PROPN'))]
# A [(('Emilia', 'emilia', 'PROPN'))]. En su álbum
# La ascensión del [(('Señor', 'señor', 'NOUN'))]
# Una madre
# Cartas de [(('Cuba', 'Cuba', 'PROPN'))]. El conuco del indio
# Amor y fe
# Las dos rosas
# [(('Griseldina', 'griseldina', 'PROPN'))]
# [([(('Araceli', 'Araceli', 'PROPN'), ('Abril', 'abril', 'PROPN'))] Abril de Armendi, PER)] mi sobrina [(('Araceli', 'Araceli', 'PROPN'), ('Abril', 'abril', 'PROPN'))] Abril de Armendi
# El mensage
# [(('Griseldina', 'griseldina', 'PROPN'))]
# Cartas de [(('Cuba', 'Cuba', 'PROPN'))]. El conuco del indio
# Una caricia puede curar un defecto
# Sin princpio ni fin.
# La felicidad
# En el álbum de una niña
# El arte. [(('Oda', 'oda', 'PROPN'))]
# A una dama muy galanteada. En su álbum
# Sin princpio ni fin. Novela de costumbres contemporáneas
# La felicidad
# [(('Periquito', 'periquito', 'PROPN'), ('el', 'el', 'DET'))] el Veleidoso
# Cartas de [(('Cuba', 'Cuba', 'PROPN'))] (III). El conuco del indio
# A [(('Santo', 'santo', 'PROPN'), ('Domingo', 'domingo', 'PROPN'))] Domingo
# El toque de la oración
# [(('Soledad', 'soledad', 'PROPN'))]
# Sin princpio ni fin. Novela de costumbres contemporáneas
# Los bailes campestres en [(('Santander', 'Santander', 'PROPN'))]
# [(('Periquito', 'periquito', 'PROPN'), ('el', 'el', 'DET'))] el Veleidoso ([(('Conclusion', 'conclusion', 'PROPN'))])
# Duelos de amor
# [(('Allende', 'allende', 'PROPN'))] los mares mora
# A la señora [(('doña', 'doña', 'NOUN'), ('Emila', 'Emila', 'PROPN'))] Emila Serrano de Wilson en su álbum
# En el álbum de la señorita [(J. R., PER)]. R.
# Carta
# Cada cual en su lugar
# Duelos de amor (Conclusión.)
# [(('Rolandseck', 'rolandseck', 'PROPN'))]. Tradición
# Secretos del tocador
# La madre de la [(('marquesa', 'marquesa', 'NOUN'))]
# [(('Poesía', 'poesía', 'NOUN'))]
# Ilusión. A el...
# La violeta. [(('Soneto', 'soneto', 'NOUN'))]
# La verdad del sentimiento
# De la poesía. Su oportunidad y su objeto
# Cada cual en su lugar (Conclusión.)
# Viaje de [(('SS', 'ss', 'PROPN'), ('.', '.', 'PUNCT'))]. MM.
# [(('Mariquita', 'mariquita', 'PROPN'))]
# Entre las aventuras numerosas Cuando el general [(('Bonaparte', 'bonaparte', 'PROPN'))] Es notable lo siguiente
# La madre de la marquesa (Continuación)
# El [(('sargento', 'sargento', 'NOUN'), ('Pérez', 'Pérez', 'PROPN'))] Pérez. Episodio de dominación francesa en [(('Santo', 'santo', 'PROPN'), ('Domingo', 'domingo', 'PROPN'))] Domingo
# Sin princpio ni fin. Novela de costumbres contemporáneas
# Los pájaros
# Una flor
# La moneda de oro
# Matrimonios por anuncios Los baños de [(('Biarritz', 'Biarritz', 'PROPN'))] Hace pocos días
# La madre de la marquesa (Continuación)
# A [(('Sevilla', 'Sevilla', 'PROPN'))]
# [(('Soneto', 'soneto', 'NOUN'))]. Un año más
# [(('Carta', 'Carta', 'PROPN'), ('I.', 'i.', 'PROPN'))] I. Monserrat
# La moneda de oro
# Un paseo por el lago negro
# La feria de [(('Ucles', 'ucles', 'PROPN'))]
# La madre de la marquesa (Continuación)
# [(('Fábula', 'Fábula', 'PROPN'))]. El cabello suelto
# [(('Carta', 'Carta', 'PROPN'), ('II', 'ii', 'NUM'))] II. [(('Valencia', 'Valencia', 'PROPN'))]
# La feria de [(('Ucles', 'ucles', 'PROPN'))]
# De la poesía. Su oportunidad y su objeto
# La moneda de oro
# Una duquesa octogenaria [(('La', 'el', 'DET'), ('señora', 'señora', 'NOUN'))] señora de J El señor X Una aldeana enriquecida
# La escalera
# [(('Carta', 'Carta', 'PROPN'), ('III', 'iii', 'NUM'))] III. [(('Barcelona', 'Barcelona', 'PROPN'))]
# La moneda de oro ([(('Conclusión', 'conclusión', 'NOUN'))])
# El [(('Brasil', 'Brasil', 'PROPN'))]
# El alma de dudas
# El istmo de [(('Panamá', 'Panamá', 'PROPN'))]
# Una peregrinación a [(('Saint', 'saint', 'PROPN'), ('Point', 'point', 'PROPN'))] Point
# Sin destinos no hay amigos. Proverbio en tres cuadros
# El sombrero del emperador de [(('Austria', 'Austria', 'PROPN'))]
# El amor
# [(('Feria', 'Feria', 'PROPN'))] en [(('Sevilla', 'Sevilla', 'PROPN'))]
# El lentigo. De su tratamiento
# En la primera página de un álbum
# El mundo para unos. [(('Soneto', 'soneto', 'NOUN'))]
# El mundo para otros. [(('Soneto', 'soneto', 'NOUN'))]
# Última hora
# [(('Francisco', 'francisco', 'PROPN'), ('José', 'José', 'PROPN'))] José. [(('Emperador', 'Emperador', 'PROPN'), ('de', 'de', 'ADP'))] del Austria
# Constituido ya oficialmente el nuevo [(('Ministerio', 'Ministerio', 'PROPN'), ('Inglés', 'Inglés', 'PROPN'))] Inglés
# Parte oficial publicado por el [(('Monitor', 'Monitor', 'NOUN'), ('de', 'de', 'ADP'))] de París sobre la atalla de [(('Solferino', 'Solferino', 'PROPN'))]
# Censo aproximativo En un periódico se lee lo siguiente [(('Invento', 'invento', 'NOUN'), ('Histórico', 'histórico', 'PROPN'))] Histórico
# Al señor de [(N., PER)]. y la [(('señora', 'señora', 'NOUN'), ('*', '*', 'PUNCT'))] ***
# El fauno de [(('Goysevox', 'Goysevox', 'PROPN'))]
# El prólogo. Episodio
# El collar
# El cabello rubio
# La esposa del sol
# Inauguración del teatro de [(D. José Piquer Oda Alzad, LOC)]. José Piquer Oda Alzad vuestras tumbas
# Estudios sobre los primeros tiempos de la [(('Rusia', 'Rusia', 'PROPN'))]
# Estudios sobre los primeros tiempos de la [(('Rusia', 'Rusia', 'PROPN'))]. (Conclusión.)
# A [(('Safo', 'Safo', 'PROPN'))]
# Abnegación
# [(('Sombreros', 'sombreros', 'NOUN'), ('de', 'de', 'ADP'))] de Alexandrine
# [(('Sombreros', 'Sombreros', 'PROPN'), ("d'", "d'", 'ADP'))] d'Alexandrine
# [(('Sombreros', 'Sombreros', 'PROPN'), ('De', 'de', 'ADP'))] De Alexandrine
# [(('Sombreros', 'Sombreros', 'PROPN'), ('De', 'de', 'ADP'))] De Alexandrine
# [(('Sombreros', 'Sombreros', 'PROPN'), ("d'", "d'", 'ADP'))] d'Alexandrine
# [(('Sombreros', 'Sombreros', 'PROPN'), ("d'", "d'", 'ADP'))] d'Alexandrine
# [(('Sombreros', 'Sombreros', 'PROPN'), ("d'", "d'", 'ADP'))] d'Alexandrine
# En la perfumería de [(('Planchais', 'planchais', 'PROPN'))]
# Recomendamos a nuestros lectores los pianos
# Casa de comisión para [(('París', 'París', 'PROPN'))]
# Las enfermedades del pecho
# Prevenimos a nuestros lectores
# [(('Sombreros', 'Sombreros', 'PROPN'), ("d'", "d'", 'ADP'))] d'Alexandrine y [(('Corsets', 'Corsets', 'PROPN'), ('Plastiques', 'Plastiques', 'PROPN'))] Plastiques Mme. [(('Bonvallet', 'Bonvallet', 'PROPN'))]
# Se alquila una lindísima habitación
# Casas recomendadas y artículos en voga
# Corsets plastiques de [(('Bonvallet', 'Bonvallet', 'PROPN'))], Guantes, abanicos y parfumes de [(('Faguer', 'Faguer', 'PROPN'), ('Labollée', 'labollée', 'PROPN'))] Labollée, Joyas de cabellos [(('Lemnnier', 'lemnnier', 'PROPN'))], [(('Porcelaines', 'porcelaines', 'PROPN'))] et [(('Cristaux', 'cristaux', 'PROPN'), ('Maison', 'maison', 'PROPN'))] Maison de l'Escalier de Cristal
# Casas recomendadas
# Cintas y pasamanerías de la fábrica [(('Sorré', 'sorré', 'PROPN'), ('Dehsle', 'dehsle', 'PROPN'))] Dehsle, [(('Corsets', 'Corsets', 'PROPN'), ('plastiques', 'plastiques', 'PROPN'))] plastiques de Bonvallet, [(('Guantes', 'guantes', 'NOUN'))], abanicos y parfumes de [(('Faguer', 'Faguer', 'PROPN'), ('Labollée', 'labollée', 'PROPN'))] Labollée, Joyas de cabellos [(('Lemnnier', 'lemnnier', 'PROPN'))], [(('Porcelaines', 'porcelaines', 'PROPN'), ('et', 'et', 'PROPN'))] et Cristaux Maison de l'Escalier de Cristal
# [(('Lait', 'lait', 'PROPN'))] antephelique. Pecas y manchas de la cara
# [(('Camisas', 'Camisas', 'PROPN'), ('Claudio', 'Claudio', 'PROPN'))] Claudio, [(('Hermanos', 'hermano', 'PROPN'))]
# Tintura inglesa instantánea
# Casa particular de [(('Huéspedes', 'Huéspedes', 'PROPN'))]
# [(('Casa', 'casa', 'PROPN'), ('Delacroix', 'delacroix', 'PROPN'))] Delacroix
# [(('Jules', 'jules', 'PROPN'), ('Bloch', 'bloch', 'PROPN'))] Bloch, dentista
# La [(('Gaceta', 'gaceta', 'PROPN'), ('de', 'de', 'ADP'))] de Bellas Artes
# Pecas y manchas de la cara
# Casas recomendadas
# Porta monedas Despierres
# [(('Tarifs', 'tarifs', 'PROPN'), ('des', 'd', 'PROPN'))] des insertions
# Cintas y pasamanerías de la fábrica [(('Sorré', 'sorré', 'PROPN'), ('Dehsle', 'dehsle', 'PROPN'))] Dehsle, [(('Corsets', 'Corsets', 'PROPN'), ('plastiques', 'plastiques', 'PROPN'))] plastiques de Bonvallet, [(('Guantes', 'guantes', 'NOUN'))], abanicos y parfumes de [(('Faguer', 'Faguer', 'PROPN'), ('Labollée', 'labollée', 'PROPN'))] Labollée, Joyas de cabellos [(('Lemnnier', 'lemnnier', 'PROPN'))], [(('Porcelaines', 'porcelaines', 'PROPN'), ('et', 'et', 'PROPN'))] et Cristaux Maison de l'Escalier de Cristal
# [(('Camisas', 'Camisas', 'PROPN'), ('Claudio', 'Claudio', 'PROPN'))] Claudio, [(('Hermanos', 'hermano', 'PROPN'))]
# [(('Nueva', 'nueva', 'PROPN'), ('Geografía', 'geografía', 'PROPN'))] Geografía Sangansan
# Casa particular de [(('Huéspedes', 'Huéspedes', 'PROPN'))]
# [(('Casa', 'casa', 'PROPN'), ('Delacroix', 'delacroix', 'PROPN'))] Delacroix
# [(('Jules', 'jules', 'PROPN'), ('Bloch', 'bloch', 'PROPN'))] Bloch, dentista
# [(('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN'))] Cristofle
# Casas recomendadas
# [(('Tarifs', 'tarifs', 'PROPN'), ('des', 'd', 'PROPN'))] des insertions
# Cintas y pasamanerías de la fábrica [(('Sorré', 'sorré', 'PROPN'), ('Dehsle', 'dehsle', 'PROPN'))] Dehsle, [(('Corsets', 'Corsets', 'PROPN'), ('plastiques', 'plastiques', 'PROPN'))] plastiques de Bonvallet, [(('Guantes', 'guantes', 'NOUN'))], abanicos y parfumes de [(('Faguer', 'Faguer', 'PROPN'), ('Labollée', 'labollée', 'PROPN'))] Labollée, Joyas de cabellos [(('Lemnnier', 'lemnnier', 'PROPN'))], [(('Porcelaines', 'porcelaines', 'PROPN'), ('et', 'et', 'PROPN'))] et Cristaux Maison de l'Escalier de Cristal
# [(('Camisas', 'Camisas', 'PROPN'), ('Claudio', 'Claudio', 'PROPN'))] Claudio, [(('Hermanos', 'hermano', 'PROPN'))]
# [(('Nueva', 'nueva', 'PROPN'), ('Geografía', 'geografía', 'PROPN'))] Geografía Sangansan
# Casa particular de [(('Huéspedes', 'Huéspedes', 'PROPN'))]
# [(('Casa', 'casa', 'PROPN'), ('Delacroix', 'delacroix', 'PROPN'))] Delacroix
# [(('Jules', 'jules', 'PROPN'), ('Bloch', 'bloch', 'PROPN'))] Bloch, dentista
# [(('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN'))] Cristofle
# Casas recomendadas
# [(('Tarifs', 'tarifs', 'PROPN'), ('des', 'd', 'PROPN'))] des insertions
# [(('Camisas', 'Camisas', 'PROPN'), ('Claudio', 'Claudio', 'PROPN'))] Claudio, [(('Hermanos', 'hermano', 'PROPN'))]
# [(('Nueva', 'nueva', 'PROPN'), ('Geografía', 'geografía', 'PROPN'))] Geografía Sangansan
# Casa particular de [(('Huéspedes', 'Huéspedes', 'PROPN'))]
# [(('Casa', 'casa', 'PROPN'), ('Delacroix', 'delacroix', 'PROPN'))] Delacroix
# [(('Jules', 'jules', 'PROPN'), ('Bloch', 'bloch', 'PROPN'))] Bloch, dentista
# [(('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN'))] Cristofle
# Casas recomendadas
# [(('Tarifs', 'tarifs', 'PROPN'), ('des', 'd', 'PROPN'))] des insertions
# [(('Camisas', 'Camisas', 'PROPN'), ('Claudio', 'Claudio', 'PROPN'))] Claudio, [(('Hermanos', 'hermano', 'PROPN'))]
# [(('Nueva', 'nueva', 'PROPN'), ('Geografía', 'geografía', 'PROPN'))] Geografía Sangansan
# Casa particular de [(('Huéspedes', 'Huéspedes', 'PROPN'))]
# [(('Casa', 'casa', 'PROPN'), ('Delacroix', 'delacroix', 'PROPN'))] Delacroix
# [(('Jules', 'jules', 'PROPN'), ('Bloch', 'bloch', 'PROPN'))] Bloch, dentista
# [(('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN'))] Cristofle
# Casas recomendadas
# [(('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN'))] Cristofle
# [(('Camisas', 'Camisas', 'PROPN'), ('Claudio', 'Claudio', 'PROPN'))] Claudio, [(('Hermanos', 'hermano', 'PROPN'))]
# [(('Nueva', 'nueva', 'PROPN'), ('Geografía', 'geografía', 'PROPN'))] Geografía Sangansan
# Casa particular de [(('Huéspedes', 'Huéspedes', 'PROPN'))]
# [(('Casa', 'casa', 'PROPN'), ('Delacroix', 'delacroix', 'PROPN'))] Delacroix
# [(('Jules', 'jules', 'PROPN'), ('Bloch', 'bloch', 'PROPN'))] Bloch, dentista
# Casas recomendadas
# Cintas y pasamanerías de la fábrica [(('Sorré', 'sorré', 'PROPN'), ('Dehsle', 'dehsle', 'PROPN'))] Dehsle, [(('Corsets', 'Corsets', 'PROPN'), ('plastiques', 'plastiques', 'PROPN'))] plastiques de Bonvallet, [(('Guantes', 'guantes', 'NOUN'))], abanicos y parfumes de [(('Faguer', 'Faguer', 'PROPN'), ('Labollée', 'labollée', 'PROPN'))] Labollée, Joyas de cabellos [(('Lemnnier', 'lemnnier', 'PROPN'))], [(('Porcelaines', 'porcelaines', 'PROPN'), ('et', 'et', 'PROPN'))] et Cristaux Maison de l'Escalier de Cristal
# [(('Camisas', 'Camisas', 'PROPN'), ('Claudio', 'Claudio', 'PROPN'))] Claudio, [(('Hermanos', 'hermano', 'PROPN'))]
# [(('Nueva', 'nueva', 'PROPN'), ('Geografía', 'geografía', 'PROPN'))] Geografía Sangansan
# Casa particular de [(('Huéspedes', 'Huéspedes', 'PROPN'))]
# [(('Casa', 'casa', 'PROPN'), ('Delacroix', 'delacroix', 'PROPN'))] Delacroix
# [(('Jules', 'jules', 'PROPN'), ('Bloch', 'bloch', 'PROPN'))] Bloch, dentista
# [(('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN'))] Cristofle
# [(('Camisas', 'Camisas', 'PROPN'), ('Claudio', 'Claudio', 'PROPN'))] Claudio, [(('Hermanos', 'hermano', 'PROPN'))]
# [(('Nueva', 'nueva', 'PROPN'), ('Geografía', 'geografía', 'PROPN'))] Geografía Sangansan
# Casa particular de [(('Huéspedes', 'Huéspedes', 'PROPN'))]
# [(('Casa', 'casa', 'PROPN'), ('Delacroix', 'delacroix', 'PROPN'))] Delacroix
# [(('Jules', 'jules', 'PROPN'), ('Bloch', 'bloch', 'PROPN'))] Bloch, dentista
# [(('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN'))] Cristofle
# Casas recomendadas
# Cintas y pasamanerías de la fábrica [(('Sorré', 'sorré', 'PROPN'), ('Dehsle', 'dehsle', 'PROPN'))] Dehsle, [(('Corsets', 'Corsets', 'PROPN'), ('plastiques', 'plastiques', 'PROPN'))] plastiques de Bonvallet, [(('Guantes', 'guantes', 'NOUN'))], abanicos y parfumes de [(('Faguer', 'Faguer', 'PROPN'), ('Labollée', 'labollée', 'PROPN'))] Labollée, Joyas de cabellos [(('Lemnnier', 'lemnnier', 'PROPN'))], [(('Porcelaines', 'porcelaines', 'PROPN'), ('et', 'et', 'PROPN'))] et Cristaux Maison de l'Escalier de Cristal
# [(('Camisas', 'Camisas', 'PROPN'), ('Claudio', 'Claudio', 'PROPN'))] Claudio, [(('Hermanos', 'hermano', 'PROPN'))]
# [(('Nueva', 'nueva', 'PROPN'), ('Geografía', 'geografía', 'PROPN'))] Geografía Sangansan
# Casa particular de [(('Huéspedes', 'Huéspedes', 'PROPN'))]
# [(('Casa', 'casa', 'PROPN'), ('Delacroix', 'delacroix', 'PROPN'))] Delacroix
# [(('Jules', 'jules', 'PROPN'), ('Bloch', 'bloch', 'PROPN'))] Bloch, dentista
# [(('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN'))] Cristofle
# Cintas y pasamanerías de la fábrica [(('Sorré', 'sorré', 'PROPN'), ('Dehsle', 'dehsle', 'PROPN'))] Dehsle, [(('Corsets', 'Corsets', 'PROPN'), ('plastiques', 'plastiques', 'PROPN'))] plastiques de Bonvallet, [(('Guantes', 'guantes', 'NOUN'))], abanicos y parfumes de [(('Faguer', 'Faguer', 'PROPN'), ('Labollée', 'labollée', 'PROPN'))] Labollée, Joyas de cabellos [(('Lemnnier', 'lemnnier', 'PROPN'))], [(('Porcelaines', 'porcelaines', 'PROPN'), ('et', 'et', 'PROPN'))] et Cristaux Maison de l'Escalier de Cristal
# [(('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN'))] Cristofle
# Obras de la señora [(('doña', 'doña', 'NOUN'), ('Emilia', 'emilia', 'PROPN'))] Emilia Serrano de Wilson
# [(('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN'))] Cristofle
# Obras de la señora [(('doña', 'doña', 'NOUN'), ('Emilia', 'emilia', 'PROPN'))] Emilia Serrano de Wilson
# [(('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN'))] Cristofle
# Obras de la señora [(('doña', 'doña', 'NOUN'), ('Emilia', 'emilia', 'PROPN'))] Emilia Serrano de Wilson
# [(('Modes', 'Modes', 'PROPN'), ('de', 'de', 'ADP'))] de Paris. [(('Petit', 'petit', 'PROPN'), ('Courrier', 'courrier', 'PROPN'))] Courrier des Dames
# El [(('Eco', 'Eco', 'PROPN'), ('Hispano', 'hispano', 'PROPN'))] Hispano Americano
# Obras de la señora [(('doña', 'doña', 'NOUN'), ('Emilia', 'emilia', 'PROPN'))] Emilia Serrano de Wilson
# El [(('Eco', 'Eco', 'PROPN'), ('Hispano', 'hispano', 'PROPN'))] Hispano Americano
# Anuncio
# Obras de la señora [(('doña', 'doña', 'NOUN'), ('Emilia', 'emilia', 'PROPN'))] Emilia Serrano de Wilson
# Explicación de la lámina de tapicería
# Explicación de la lámina de tapicería
# Explicación del figurín
# [(('Moda', 'Moda', 'PROPN'), ('de', 'de', 'ADP'))] de Caballeros
# Explicación del figurín 1º
# Explicación del figurín 2º
# Descripción del figurín: primer y segundo traje
# Descripción del figurín: traje de la novia y de la madre
# Explicación del figurín
# Descripción del figurín de baile
# Figurín de visita
# Explicación del figurín
# Explicación del figurín
# Explicación del figurín
# Explicación del figurín
# Explicación del figurín
# Explicación del figurín
# Explicación de los figurines. Primero
# Explicación de los figurines. [(('Segundo', 'segundo', 'ADJ'))]
# Revista de la moda
# [(('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'))] de París
# Revista de la moda
# [(('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'))] de París
# Revista de la moda
# [(('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'))] de París
# Revista de la moda
# [(('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'))] de París
# Revista de la moda
# [(('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'))] de París
# Revista de la moda
# Revista de modas, salones y teatros
# Revista de modas, salones y teatros
# Revista de modas, salones y teatros
# Revista de modas, salones y teatros
# Revista de modas, salones y teatros
# Revista histórica del mes
# [(('Revista', 'revista', 'PROPN'), ('Parisense', 'Parisense', 'PROPN'))] Parisense
# Revista de modas
# Revista histórica del mes
# [(('Revista', 'revista', 'PROPN'), ('Parisense', 'Parisense', 'PROPN'))] Parisense
# Revista de modas
# Revista histórica del mes
# [(('Revista', 'revista', 'PROPN'), ('Parisense', 'Parisense', 'PROPN'))] Parisense
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('Parisense', 'Parisense', 'PROPN'))] Parisense
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('Parisense', 'Parisense', 'PROPN'))] Parisense
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN'))] Parisiense
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN'))] Parisiense
# Revista histórico política
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN'))] Parisiense
# Revista histórico política
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN'))] Parisiense
# Revista histórico política
# Revista de teatros
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid
# Revista de teatros
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN'))] Parisiense
# [(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid
# Revista de teatros
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN'))] Parisiense
# [(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid
# Crónica parisiense
# Revista de teatros
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN'))] Parisiense
# [(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid
# Revista de teatros
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN'))] Parisiense
# [(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN'))] Parisiense
# [(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN'))] Parisiense
# [(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid
# [(('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN'))] Parisiense
# [(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid
# [(('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'))] de París
# [(('Teatros', 'Teatros', 'PROPN'))]
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid
# [(('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'))] de París
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid
# [(('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'))] de París
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid
# [(('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'))] de París
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid
# [(('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'))] de París
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid
# [(('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'))] de París
# Revista de modas
# Revista de modas
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid
# [(('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'))] de París
# Revista de modas
# [(('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'))] de Madrid
# [(('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'))] de París
# Revista de modas
# Revista histórica del mes
# Revista histórica del mes
# Crónica parisiense
# Revista histórica del mes
# Revista histórica del mes
# Crónica parisiense
# Revista histórica del mes
# Revista histórica del mes
# Revista histórica del mes
# Revista histórica del mes
# Crónica parisiense
# Revista histórica del mes
# Revista histórica del mes
# Revista histórica del mes
# Revista histórica del mes
# Crónica parisiense
# Revista histórica del mes
# Revista histórica del mes
# Crónica parisiense
# Revista histórica del mes
# Crónica parisiense
# Crónica parisiense
# Crónica parisiense
# Crónica parisiense

# %%
#this one actually works better:
import re
#clean_processed_entities_ES
cleaned_rows_copy = cleaned_rows.copy()

for i, titulo in enumerate(clean_processed_entities_ES):
  for componentes in titulo:
    for tuple_item in componentes:
      entity_str = tuple_item[0][0]
      if entity_str in cleaned_rows_copy[i]:
        replacement_str = f"{tuple_item}"
        cleaned_rows_copy[i] = re.sub(rf'\b{entity_str}\b', replacement_str, cleaned_rows_copy[i])

print("\n".join(cleaned_rows_copy))
# Out:
# Al [('Sr', 'sr', 'PROPN'), ('.', '.', 'PUNCT'), ('D.', 'd.', 'PROPN'), ('R.', 'R.', 'PROPN'), ('P.', 'p.', 'PROPN')]. D. R. P. Enviándole mis obras
# La mujer piadosa ([('Fragmentos', 'fragmentos', 'NOUN')])
# [('Desvarío', 'desvarío', 'NOUN')]
# [('Soneto', 'soneto', 'NOUN')]. ¡Gloria y pobreza! El inmortal [('Quintana', 'Quintana', 'PROPN')]...
# [('Balada', 'Balada', 'PROPN')]. La despedida de una hija
# Un viaje a la [('Luna', 'luna', 'PROPN')]. Prólogo: La pesadilla de [('Mocquet', 'Mocquet', 'PROPN')]
# En el álbum de la [('señora', 'señora', 'NOUN'), ('M…', 'm…', 'PROPN')] M…
# La primavera
# La perejilera
# Un viaje a la [('Luna', 'luna', 'PROPN')]. (Continuación)
# Al señor [('Don', 'Don', 'PROPN'), ('B.', 'B.', 'PROPN'), ('M.', 'M.', 'PROPN')] B. M.
# A orillas del [('Manzanares', 'manzanares', 'PROPN')]. La súplica
# Un viaje a la [('Luna', 'luna', 'PROPN')]. (Continuación)
# Fragmentos [('de', 'de', 'ADP'), ('la', 'el', 'DET'), ('Rosa', 'Rosa', 'PROPN'), ('de', 'de', 'ADP'), ('Alejandra', 'Alejandra', 'PROPN')] la Rosa [('de', 'de', 'ADP'), ('la', 'el', 'DET'), ('Rosa', 'Rosa', 'PROPN'), ('de', 'de', 'ADP'), ('Alejandra', 'Alejandra', 'PROPN')] Alejandra
# Gente morena
# Un viaje a la [('Luna', 'luna', 'PROPN')]. (Continuación)
# Al excmo. [('Sr', 'sr', 'PROPN'), ('.', '.', 'PUNCT'), ('D.', 'd.', 'PROPN'), ('Agustín', 'agustín', 'PROPN'), ('Esteban', 'esteban', 'PROPN'), ('Collantes', 'Collantes', 'PROPN')]. D. Agustín Esteban Collantes, en el día de su santo
# A la niña [('Margarita', 'margarita', 'PROPN'), ('Aurora', 'aurora', 'PROPN'), ('de', 'de', 'ADP'), ('Wilson', 'wilson', 'PROPN')] Aurora de Wilson y [('Serrano', 'Serrano', 'PROPN')], el día de su cumpleaños
# Costumbres del siglo XIX. ('[('I', 'i', 'NUM')]', 'PER')
# [('Margarita', 'margarita', 'PROPN')]. Novela bretona
# Los escondidos y la tapada. Fragmentos
# A mi apreciable amiga la [('Señora', 'señora', 'NOUN'), ('doña', 'doña', 'ADJ'), ('M.', 'M.', 'PROPN'), ('De', 'de', 'ADP'), ('el', 'el', 'DET'), ('Pilar', 'Pilar', 'PROPN'), ('Sinués', 'Sinués', 'PROPN'), ('de', 'de', 'ADP'), ('Marco', 'marco', 'PROPN')] doña M. Del Pilar Sinués de Marco en su álbum
# Costumbres del siglo XIX.[('II', 'ii', 'NUM')]
# [('Margarita', 'margarita', 'PROPN')]. Novela bretona. (Continuación)
# A la niña [('Margarita', 'margarita', 'PROPN'), ('Aurora', 'aurora', 'PROPN'), ('de', 'de', 'ADP'), ('Wilson', 'wilson', 'PROPN')] Aurora de Wilson y [('Serrano', 'Serrano', 'PROPN')]
# A [('María', 'María', 'PROPN')]
# ('[('Alteza', 'alteza', 'PROPN'), ('Real', 'real', 'PROPN')] Real', 'PER') su [('Alteza', 'alteza', 'PROPN'), ('Real', 'real', 'PROPN')] Real el [('Príncipe', 'Príncipe', 'PROPN'), ('de', 'de', 'ADP'), ('Asturias', 'Asturias', 'PROPN')] de Asturias
# [('Margarita', 'margarita', 'PROPN')]. Novela bretona. (Conclusión)
# El otoño
# [('Soneto', 'soneto', 'NOUN')]. Aún eco tienen en el alma mía...
# Atentado contra SS. MM. II.
# El matrimonio de la [('Princesa', 'Princesa', 'PROPN')] real de [('Inglaterra', 'inglaterra', 'PROPN')] Hace algunos años que un banquero muy rico Varios periódicos franceses y del extranjero
# A la [('Poesía', 'poesía', 'NOUN')]. [('Oda', 'oda', 'PROPN')]
# ('[('Alejandro', 'alejandro', 'PROPN'), ('Dumas', 'dumas', 'PROPN')] Dumas', 'PER') mi buen amigo el distinguido escritor don [('Alejandro', 'alejandro', 'PROPN'), ('Dumas', 'dumas', 'PROPN')] Dumas en prueba de sincera amistad
# A la luna. [('Soneto', 'soneto', 'NOUN')]
# Las apariencias engañan. Historia cuento
# El viaje de [('SS', 'ss', 'PROPN'), ('.', '.', 'PUNCT'), ('AA', 'aa', 'PROPN')]. AA. El sábado a la una El [('príncipe', 'príncipe', 'NOUN'), ('Mirza', 'Mirza', 'PROPN'), ('Ally', 'ally', 'PROPN'), ('Kan', 'kan', 'PROPN'), ('Bahadoor', 'bahadoor', 'PROPN'), ('Habláse', 'habláse', 'PROPN')] Mirza Ally Kan Bahadoor Habláse mucho en los círculos aristocrático de un matrimonio
# El invierno
# La hada azul
# El lunes 5 del corriente se ha inaugurado Vamos a contar una historia ocurrida en estos días de Pascua Cuando [('Ismail', 'Ismail', 'PROPN')], generalísimo del ejército otomano
# El navío [('Leviatán', 'leviatán', 'PROPN')]
# Ayes del corazón
# Carta de ('M. de Lamartine', 'PER'). de Lamartine
# Introducción
# [('Isabel', 'isabel', 'PROPN'), ('II', 'ii', 'NUM')] II
# [('Hamlet', 'Hamlet', 'PROPN')]
# Lo que cada lector pide [('La', 'el', 'DET'), ('Malibran', 'malibran', 'PROPN')] trata de blancas De la decadencia de las costumbres [('La', 'el', 'DET'), ('Malibran', 'malibran', 'PROPN')] Malibran recibía en [('Londres', 'Londres', 'PROPN')] El gobierno del [('Brasil', 'Brasil', 'PROPN')]
# Consignamos la acarta original qu enos ha dirigido ('M. de Lamartine', 'PER'). de Lamartine
# [('Porvenir', 'porvenir', 'PROPN')] de la raza latina y de la [('Francia', 'francia', 'PROPN')] en el [('Nuevo', 'nuevo', 'PROPN'), ('Mundo', 'Mundo', 'PROPN')] Mundo. Introducción
# [('Confederación', 'Confederación', 'PROPN'), ('Argentina', 'argentina', 'PROPN')] Argentina y república del [('Uruguay', 'Uruguay', 'PROPN'), ('Le', 'él', 'PRON'), ('Paraguay', 'paraguay', 'PROPN')] Le Paraguay
# ('S. M. La emperatriz de los franceses', 'MISC'). M. La emperatriz de los franceses
# Cursos familiares de literatura. La pintura
# El perro de [('Zurbarán', 'zurbarán', 'PROPN')]
# Serenatas. Introducción. (Fragmentos)
# Lo que viene a ser un periodista inglés Ha sucedido en los alrededores de [('Filadelfia', 'filadelfia', 'PROPN'), ('Máximas', 'Máximas', 'PROPN')] Máximas
# Recuerdo. Un baile en el hotel de [('Ville', 'ville', 'PROPN')], en 1859
# Abertura del [('Paraguay', 'paraguay', 'PROPN')] y de los ríos
# La [('Escma', 'Escma', 'PROPN')]. Sra. [('Dª', 'dª', 'PROPN'), ('Gertrudis', 'Gertrudis', 'PROPN'), ('Gómez', 'Gómez', 'PROPN'), ('de', 'de', 'ADP'), ('Avellaneda', 'avellaneda', 'PROPN')] Gertrudis Gómez de Avellaneda
# El 20 de marzo
# Cursos familiares de literatura. [('Leopoldo', 'Leopoldo', 'PROPN'), ('Robert', 'robert', 'PROPN')] Robert
# Leyenda pastoral
# La dalia
# Leemos en el [('Monitor', 'Monitor', 'PROPN')] Según el 'Anuario diplomático de 1859' Hace algunas semanas que los diarios del [('Alto', 'alto', 'ADJ')] y del [('Bajo', 'bajo', 'PROPN'), ('Rin', 'rin', 'PROPN')] Rin He aquí la siguiente anécdota Un curioso ha dicho El matrimonio del hijo mayor [('Savonnette', 'savonnette', 'PROPN')] a vilain
# Carta de [('Ramón', 'ramón', 'PROPN'), ('de', 'de', 'ADP'), ('la', 'el', 'DET'), ('Sagra', 'sagra', 'PROPN')] de la Sagra
# Artículo I. Los [('Estados', 'Estados', 'PROPN'), ('Unidos', 'unido', 'PROPN')] Unidos y el [('Paraguay', 'paraguay', 'PROPN')]
# Costumbres andaluzas. Los dos marineros
# Viaje por un vestido de boda
# SS. AA. II el príncipe y la [('princesa', 'princesa', 'NOUN'), ('Napoleón', 'napoleón', 'PROPN')] Napoleón
# El miércoles de ceniza
# Cursos familiares de literatura. [('Leopoldo', 'Leopoldo', 'PROPN'), ('Robert', 'robert', 'PROPN')] Robert. ([('Conclusión', 'conclusión', 'NOUN')])
# Pues que en nuestros días se hacen tantos adelantos en la fotografía Acaba de llegar de [('San', 'san', 'PROPN'), ('Petesburgo', 'petesburgo', 'PROPN')] Petesburgo El [('Entreacto', 'entreacto', 'NOUN')] publica un acarta fechada en [('Génova', 'génova', 'PROPN')]
# [('Memorándum', 'Memorándum', 'NOUN'), ('especial', 'especial', 'ADJ'), ('por', 'por', 'ADP'), ('la', 'el', 'DET'), ('guerra', 'guerra', 'NOUN'), ('de', 'de', 'ADP'), ('Italia', 'Italia', 'PROPN')] especial por la guerra de Italia
# Introducción
# [('Pbro', 'pbro', 'PROPN')]. ('D. Félix Varela', 'PER'). Félix Varela
# Las flores de mayo
# A la [('catedral', 'catedral', 'NOUN'), ('de', 'de', 'ADP'), ('Bron', 'bron', 'PROPN')] de Bron
# Viaje al rededpr de un vestido de boda. (Conclusiones)
# [('Artículo', 'artículo', 'NOUN'), ('II', 'ii', 'NUM')] II. Los [('Estados', 'Estados', 'PROPN'), ('Unidos', 'unido', 'PROPN')] Unidos y el [('Paraguay', 'paraguay', 'PROPN')]
# Una de tantas
# Para que se vea cómo los principales intereses y amortización de la [('Deuda', 'deuda', 'PROPN')] pública
# Carta de ('M. Alejandro Dumas', 'PER'). Alejandro Dumas
# [('Carta', 'carta', 'NOUN'), ('de', 'de', 'ADP'), ('el', 'el', 'DET'), ('Sr.', 'sr.', 'PROPN')] del Sr. [('Guillemot', 'Guillemot', 'PROPN')]
# [('Napoleón', 'napoleón', 'PROPN'), ('III', 'iii', 'NUM')] III
# [('Víctor', 'Víctor', 'PROPN'), ('Manuel', 'Manuel', 'PROPN'), ('II', 'ii', 'NUM')] Manuel II
# El oso
# [('Poesía', 'poesía', 'NOUN')]. A mi amigo [('Mariano', 'mariano', 'PROPN'), ('G.', 'G.', 'PROPN'), ('Manrique', 'Manrique', 'PROPN')] G. Manrique
# Perfil inglés
# La ostra
# [('Poesía', 'poesía', 'NOUN')]. A [('Napoleón', 'napoleón', 'PROPN'), ('III', 'iii', 'NUM')] III
# A una tumba en el cementerio de [('Montmartre', 'montmartre', 'PROPN')]. ([('Fragmento', 'fragmento', 'NOUN')])
# Consideraciones sobre los vestidos
# Gran batalla de [('Solferino', 'Solferino', 'PROPN')]
# [('Memorándum', 'Memorándum', 'NOUN'), ('especial', 'especial', 'ADJ'), ('por', 'por', 'ADP'), ('la', 'el', 'DET'), ('guerra', 'guerra', 'NOUN'), ('de', 'de', 'ADP'), ('Italia', 'Italia', 'PROPN')] especial por la guerra de Italia
# [('Batalla', 'batalla', 'NOUN'), ('de', 'de', 'ADP'), ('Solferino', 'Solferino', 'PROPN')] de Solferino. El emperador a la emperatriz
# [('Ejército', 'Ejército', 'PROPN'), ('de', 'de', 'ADP'), ('Italia', 'Italia', 'PROPN')] de Italia. Proclama
# La entrevista de [('Villafranca', 'villafranca', 'PROPN')]. Nuevos detalles
# El [('mariscal', 'mariscal', 'NOUN'), ('Vaillant', 'Vaillant', 'PROPN')] Vaillant, mayor general del ejército de [('Italia', 'Italia', 'PROPN')]
# [('Poesía', 'poesía', 'NOUN')]. Costumbres andaluzas. Un baile de candil
# A ('S. M.', 'PER'). M. el emperador [('Napoleón', 'napoleón', 'PROPN'), ('III', 'iii', 'NUM')] III ([('Fragmentos', 'fragmentos', 'NOUN')])
# Mi fotografía
# El festín de [('Baltasar', 'Baltasar', 'PROPN')]. Estudio bíblico
# Quién es el...
# La primera quincena del mes de agosto [… ]
# El general [('Garibaldi', 'garibaldi', 'PROPN')]
# En sus días
# A la [('Señora', 'señora', 'NOUN'), ('Doña', 'Doña', 'PROPN'), ('Emilia', 'emilia', 'PROPN'), ('Serrano', 'Serrano', 'PROPN'), ('de', 'de', 'ADP'), ('Wilson', 'wilson', 'PROPN')] Doña Emilia Serrano de Wilson en débil muestra de aprecio
# [('Offland', 'offland', 'PROPN')]
# La señorita [('doña', 'doña', 'NOUN'), ('María', 'María', 'PROPN'), ('Verdejo', 'Verdejo', 'PROPN')] María Verdejo y [('Durán', 'durán', 'PROPN')]
# Una cifra en un ciprés
# [('María', 'María', 'PROPN'), ('Leczinska', 'leczinska', 'PROPN')] Leczinska
# Composición de la ópera [('Otello', 'otello', 'PROPN')] por [('Rossini', 'Rossini', 'PROPN')]
# El robo del niño de la [('señora', 'señora', 'NOUN'), ('Hua', 'hua', 'PROPN')] Hua
# La señora [('doña', 'doña', 'NOUN'), ('Carolina', 'carolina', 'PROPN'), ('Coronado', 'Coronado', 'PROPN')] Carolina Coronado
# La granadina. Marcha guerrera
# El genio
# [('María', 'María', 'PROPN'), ('Leczinska', 'leczinska', 'PROPN')] Leczinska
# El coro de los ángeles
# El kaleidescopio
# El duelo de las mujeres
# Los secretos de la hermosura
# A la [('niña', 'niña', 'NOUN'), ('Adelaida', 'adelaida', 'PROPN')] Adelaida. En su día
# [('Esther', 'Esther', 'PROPN')]
# Origen de algunos instrumentos. La guitarra
# [('Tetuán', 'tetuán', 'PROPN')]
# El duelo de las mujeres. (Continuación.)
# Secretos de la hermosura. (Continuación)
# L a vuelta de la golondrina. (Fragmentos)
# El duelo de las mujeres. (Continuación.)
# Secretos de la hermosura. (Continuación)
# El sauce
# [('Balada', 'Balada', 'PROPN')]
# El duelo de las mujeres. (Continuación.)
# La hermana de [('Velázquez', 'velázquez', 'PROPN')]
# La cuaresma del amor
# Lo mejor de una niña
# El duelo de las mujeres. (Continuación.)
# El museo viviente: colección de cuadros sociales. Cuadro primero: [('doña', 'doña', 'NOUN'), ('Eulogia', 'Eulogia', 'PROPN')] Eulogia
# La hermana de [('Velázquez', 'velázquez', 'PROPN')]
# La oliva. A la paz entre [('España', 'España', 'PROPN')] y [('Marruecos', 'Marruecos', 'PROPN')]
# Descripción del teatro de ('D. José Piquer', 'PER'). José Piquer
# El duelo de las mujeres. (Continuación.)
# La hermana de [('Velázquez', 'velázquez', 'PROPN')]
# El ángel de la inclusa
# Los espejos mágicos. Cuento fantástico
# Cartas de [('Cuba', 'Cuba', 'PROPN')]. [('Cojimar', 'cojimar', 'PROPN')]
# Días pasados se hallaba en el bosque [('La', 'el', 'DET'), ('ópera', 'ópera', 'NOUN'), ('de', 'de', 'ADP'), ('Verdi', 'Verdi', 'PROPN'), ('El', 'el', 'DET'), ('marqués', 'marqués', 'PROPN'), ('de', 'de', 'ADP'), ('Casa', 'casa', 'PROPN'), ('Riera', 'riera', 'PROPN')] ópera de Verdi El marqués de Casa Riera No podemos resistir el deseo de copiar
# La cama de matrimonio. [('Balada', 'Balada', 'PROPN')]
# Las dos tumbas. [('Dolora', 'Dolora', 'PROPN')]
# A [('Colón', 'colón', 'PROPN')]
# Una madre
# Un baile de manga larga
# La heredad bendecida
# Esto y aquello
# [('Macahé', 'Macahé', 'PROPN')]
# A [('Emilia', 'emilia', 'PROPN')]. En su álbum
# La ascensión del [('Señor', 'señor', 'NOUN')]
# Una madre
# Cartas de [('Cuba', 'Cuba', 'PROPN')]. El conuco del indio
# Amor y fe
# Las dos rosas
# [('Griseldina', 'griseldina', 'PROPN')]
# ('[('Araceli', 'Araceli', 'PROPN'), ('Abril', 'abril', 'PROPN'), ('de', 'de', 'ADP'), ('Armendi', 'armendi', 'PROPN')] Abril de Armendi', 'PER') mi sobrina [('Araceli', 'Araceli', 'PROPN'), ('Abril', 'abril', 'PROPN'), ('de', 'de', 'ADP'), ('Armendi', 'armendi', 'PROPN')] Abril de Armendi
# El mensage
# [('Griseldina', 'griseldina', 'PROPN')]
# Cartas de [('Cuba', 'Cuba', 'PROPN')]. El conuco del indio
# Una caricia puede curar un defecto
# Sin princpio ni fin.
# La felicidad
# En el álbum de una niña
# El arte. [('Oda', 'oda', 'PROPN')]
# A una dama muy galanteada. En su álbum
# Sin princpio ni fin. Novela de costumbres contemporáneas
# La felicidad
# [('Periquito', 'periquito', 'PROPN'), ('el', 'el', 'DET'), ('Veleidoso', 'Veleidoso', 'PROPN')] el Veleidoso
# Cartas de [('Cuba', 'Cuba', 'PROPN')] (III). El conuco del indio
# A [('Santo', 'santo', 'PROPN'), ('Domingo', 'domingo', 'PROPN')] Domingo
# El toque de la oración
# [('Soledad', 'soledad', 'PROPN')]
# Sin princpio ni fin. Novela de costumbres contemporáneas
# Los bailes campestres en [('Santander', 'Santander', 'PROPN')]
# [('Periquito', 'periquito', 'PROPN'), ('el', 'el', 'DET'), ('Veleidoso', 'Veleidoso', 'PROPN')] el Veleidoso ([('Conclusion', 'conclusion', 'PROPN')])
# Duelos de amor
# [('Allende', 'allende', 'PROPN')] los mares mora
# A la señora [('doña', 'doña', 'NOUN'), ('Emila', 'Emila', 'PROPN'), ('Serrano', 'Serrano', 'PROPN'), ('de', 'de', 'ADP'), ('Wilson', 'wilson', 'PROPN')] Emila Serrano de Wilson en su álbum
# En el álbum de la señorita ('J. R.', 'PER'). R.
# Carta
# Cada cual en su lugar
# Duelos de amor (Conclusión.)
# [('Rolandseck', 'rolandseck', 'PROPN')]. Tradición
# Secretos del tocador
# La madre de la [('marquesa', 'marquesa', 'NOUN')]
# [('Poesía', 'poesía', 'NOUN')]
# Ilusión. A el...
# La violeta. [('Soneto', 'soneto', 'NOUN')]
# La verdad del sentimiento
# De la poesía. Su oportunidad y su objeto
# Cada cual en su lugar (Conclusión.)
# Viaje de [('SS', 'ss', 'PROPN'), ('.', '.', 'PUNCT'), ('MM', 'mm', 'PROPN')]. MM.
# [('Mariquita', 'mariquita', 'PROPN')]
# Entre las aventuras numerosas Cuando el general [('Bonaparte', 'bonaparte', 'PROPN')] Es notable lo siguiente
# La madre de la marquesa (Continuación)
# El [('sargento', 'sargento', 'NOUN'), ('Pérez', 'Pérez', 'PROPN')] Pérez. Episodio de dominación francesa en [('Santo', 'santo', 'PROPN'), ('Domingo', 'domingo', 'PROPN')] Domingo
# Sin princpio ni fin. Novela de costumbres contemporáneas
# Los pájaros
# Una flor
# La moneda de oro
# Matrimonios por anuncios Los baños de [('Biarritz', 'Biarritz', 'PROPN')] Hace pocos días
# La madre de la marquesa (Continuación)
# A [('Sevilla', 'Sevilla', 'PROPN')]
# [('Soneto', 'soneto', 'NOUN')]. Un año más
# [('Carta', 'Carta', 'PROPN'), ('I.', 'i.', 'PROPN'), ('Monserrat', 'monserrat', 'PROPN')] I. Monserrat
# La moneda de oro
# Un paseo por el lago negro
# La feria de [('Ucles', 'ucles', 'PROPN')]
# La madre de la marquesa (Continuación)
# [('Fábula', 'Fábula', 'PROPN')]. El cabello suelto
# [('Carta', 'Carta', 'PROPN'), ('II', 'ii', 'NUM')] II. [('Valencia', 'Valencia', 'PROPN')]
# La feria de [('Ucles', 'ucles', 'PROPN')]
# De la poesía. Su oportunidad y su objeto
# La moneda de oro
# Una duquesa octogenaria [('La', 'el', 'DET'), ('señora', 'señora', 'NOUN'), ('de', 'de', 'ADP'), ('J', 'j', 'PROPN')] señora de J El señor X Una aldeana enriquecida
# La escalera
# [('Carta', 'Carta', 'PROPN'), ('III', 'iii', 'NUM')] III. [('Barcelona', 'Barcelona', 'PROPN')]
# La moneda de oro ([('Conclusión', 'conclusión', 'NOUN')])
# El [('Brasil', 'Brasil', 'PROPN')]
# El alma de dudas
# El istmo de [('Panamá', 'Panamá', 'PROPN')]
# Una peregrinación a [('Saint', 'saint', 'PROPN'), ('Point', 'point', 'PROPN')] Point
# Sin destinos no hay amigos. Proverbio en tres cuadros
# El sombrero del emperador de [('Austria', 'Austria', 'PROPN')]
# El amor
# [('Feria', 'Feria', 'PROPN')] en [('Sevilla', 'Sevilla', 'PROPN')]
# El lentigo. De su tratamiento
# En la primera página de un álbum
# El mundo para unos. [('Soneto', 'soneto', 'NOUN')]
# El mundo para otros. [('Soneto', 'soneto', 'NOUN')]
# Última hora
# [('Francisco', 'francisco', 'PROPN'), ('José', 'José', 'PROPN')] José. [('Emperador', 'Emperador', 'PROPN'), ('de', 'de', 'ADP'), ('el', 'el', 'DET'), ('Austria', 'Austria', 'PROPN')] del Austria
# Constituido ya oficialmente el nuevo [('Ministerio', 'Ministerio', 'PROPN'), ('Inglés', 'Inglés', 'PROPN')] Inglés
# Parte oficial publicado por el [('Monitor', 'Monitor', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París sobre la atalla de [('Solferino', 'Solferino', 'PROPN')]
# Censo aproximativo En un periódico se lee lo siguiente [('Invento', 'invento', 'NOUN'), ('Histórico', 'histórico', 'PROPN')] Histórico
# Al señor de ('N.', 'PER'). y la [('señora', 'señora', 'NOUN'), ('*', '*', 'PUNCT'), ('*', '*', 'PUNCT')] ***
# El fauno de [('Goysevox', 'Goysevox', 'PROPN')]
# El prólogo. Episodio
# El collar
# El cabello rubio
# La esposa del sol
# Inauguración del teatro de ('D. José Piquer Oda Alzad', 'LOC'). José Piquer Oda Alzad vuestras tumbas
# Estudios sobre los primeros tiempos de la [('Rusia', 'Rusia', 'PROPN')]
# Estudios sobre los primeros tiempos de la [('Rusia', 'Rusia', 'PROPN')]. (Conclusión.)
# A [('Safo', 'Safo', 'PROPN')]
# Abnegación
# [('Sombreros', 'sombreros', 'NOUN'), ('de', 'de', 'ADP'), ('Alexandrine', 'alexandrine', 'PROPN')] de Alexandrine
# [('Sombreros', 'Sombreros', 'PROPN'), ("d'", "d'", 'ADP'), ('Alexandrine', 'alexandrine', 'PROPN')] d'Alexandrine
# [('Sombreros', 'Sombreros', 'PROPN'), ('De', 'de', 'ADP'), ('Alexandrine', 'alexandrine', 'PROPN')] De Alexandrine
# [('Sombreros', 'Sombreros', 'PROPN'), ('De', 'de', 'ADP'), ('Alexandrine', 'alexandrine', 'PROPN')] De Alexandrine
# [('Sombreros', 'Sombreros', 'PROPN'), ("d'", "d'", 'ADP'), ('Alexandrine', 'alexandrine', 'PROPN')] d'Alexandrine
# [('Sombreros', 'Sombreros', 'PROPN'), ("d'", "d'", 'ADP'), ('Alexandrine', 'alexandrine', 'PROPN')] d'Alexandrine
# [('Sombreros', 'Sombreros', 'PROPN'), ("d'", "d'", 'ADP'), ('Alexandrine', 'alexandrine', 'PROPN')] d'Alexandrine
# En la perfumería de [('Planchais', 'planchais', 'PROPN')]
# Recomendamos a nuestros lectores los pianos
# Casa de comisión para [('París', 'París', 'PROPN')]
# Las enfermedades del pecho
# Prevenimos a nuestros lectores
# [('Sombreros', 'Sombreros', 'PROPN'), ("d'", "d'", 'ADP'), ('Alexandrine', 'alexandrine', 'PROPN')] d'Alexandrine y [('Corsets', 'Corsets', 'PROPN'), ('Plastiques', 'Plastiques', 'PROPN'), ('Mme', 'Mme', 'PROPN')] Plastiques Mme. [('Bonvallet', 'Bonvallet', 'PROPN')]
# Se alquila una lindísima habitación
# Casas recomendadas y artículos en voga
# Corsets plastiques de [('Bonvallet', 'Bonvallet', 'PROPN')], Guantes, abanicos y parfumes de [('Faguer', 'Faguer', 'PROPN'), ('Labollée', 'labollée', 'PROPN')] Labollée, Joyas de cabellos [('Lemnnier', 'lemnnier', 'PROPN')], [('Porcelaines', 'porcelaines', 'PROPN')] et [('Cristaux', 'cristaux', 'PROPN'), ('Maison', 'maison', 'PROPN'), ('de', 'de', 'ADP'), ("l'Escalier", "l'Escalier", 'PROPN'), ('de', 'de', 'ADP'), ('Cristal', 'cristal', 'PROPN')] Maison de l'Escalier de Cristal
# Casas recomendadas
# Cintas y pasamanerías de la fábrica [('Sorré', 'sorré', 'PROPN'), ('Dehsle', 'dehsle', 'PROPN')] Dehsle, [('Corsets', 'Corsets', 'PROPN'), ('plastiques', 'plastiques', 'PROPN'), ('de', 'de', 'ADP'), ('Bonvallet', 'Bonvallet', 'PROPN')] plastiques de Bonvallet, [('Guantes', 'guantes', 'NOUN')], abanicos y parfumes de [('Faguer', 'Faguer', 'PROPN'), ('Labollée', 'labollée', 'PROPN')] Labollée, Joyas de cabellos [('Lemnnier', 'lemnnier', 'PROPN')], [('Porcelaines', 'porcelaines', 'PROPN'), ('et', 'et', 'PROPN'), ('Cristaux', 'cristaux', 'PROPN'), ('Maison', 'maison', 'PROPN'), ('de', 'de', 'ADP'), ("l'Escalier", "l'Escalier", 'PROPN'), ('de', 'de', 'ADP'), ('Cristal', 'cristal', 'PROPN')] et Cristaux Maison de l'Escalier de Cristal
# [('Lait', 'lait', 'PROPN')] antephelique. Pecas y manchas de la cara
# [('Camisas', 'Camisas', 'PROPN'), ('Claudio', 'Claudio', 'PROPN')] Claudio, [('Hermanos', 'hermano', 'PROPN')]
# Tintura inglesa instantánea
# Casa particular de [('Huéspedes', 'Huéspedes', 'PROPN')]
# [('Casa', 'casa', 'PROPN'), ('Delacroix', 'delacroix', 'PROPN')] Delacroix
# [('Jules', 'jules', 'PROPN'), ('Bloch', 'bloch', 'PROPN')] Bloch, dentista
# La [('Gaceta', 'gaceta', 'PROPN'), ('de', 'de', 'ADP'), ('Bellas', 'bellas', 'PROPN'), ('Artes', 'artes', 'PROPN')] de Bellas Artes
# Pecas y manchas de la cara
# Casas recomendadas
# Porta monedas Despierres
# [('Tarifs', 'tarifs', 'PROPN'), ('des', 'd', 'PROPN'), ('insertions', 'insertions', 'PROPN')] des insertions
# Cintas y pasamanerías de la fábrica [('Sorré', 'sorré', 'PROPN'), ('Dehsle', 'dehsle', 'PROPN')] Dehsle, [('Corsets', 'Corsets', 'PROPN'), ('plastiques', 'plastiques', 'PROPN'), ('de', 'de', 'ADP'), ('Bonvallet', 'Bonvallet', 'PROPN')] plastiques de Bonvallet, [('Guantes', 'guantes', 'NOUN')], abanicos y parfumes de [('Faguer', 'Faguer', 'PROPN'), ('Labollée', 'labollée', 'PROPN')] Labollée, Joyas de cabellos [('Lemnnier', 'lemnnier', 'PROPN')], [('Porcelaines', 'porcelaines', 'PROPN'), ('et', 'et', 'PROPN'), ('Cristaux', 'cristaux', 'PROPN'), ('Maison', 'maison', 'PROPN'), ('de', 'de', 'ADP'), ("l'Escalier", "l'Escalier", 'PROPN'), ('de', 'de', 'ADP'), ('Cristal', 'cristal', 'PROPN')] et Cristaux Maison de l'Escalier de Cristal
# [('Camisas', 'Camisas', 'PROPN'), ('Claudio', 'Claudio', 'PROPN')] Claudio, [('Hermanos', 'hermano', 'PROPN')]
# [('Nueva', 'nueva', 'PROPN'), ('Geografía', 'geografía', 'PROPN'), ('Sangansan', 'sangansan', 'PROPN')] Geografía Sangansan
# Casa particular de [('Huéspedes', 'Huéspedes', 'PROPN')]
# [('Casa', 'casa', 'PROPN'), ('Delacroix', 'delacroix', 'PROPN')] Delacroix
# [('Jules', 'jules', 'PROPN'), ('Bloch', 'bloch', 'PROPN')] Bloch, dentista
# [('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN')] Cristofle
# Casas recomendadas
# [('Tarifs', 'tarifs', 'PROPN'), ('des', 'd', 'PROPN'), ('insertions', 'insertions', 'PROPN')] des insertions
# Cintas y pasamanerías de la fábrica [('Sorré', 'sorré', 'PROPN'), ('Dehsle', 'dehsle', 'PROPN')] Dehsle, [('Corsets', 'Corsets', 'PROPN'), ('plastiques', 'plastiques', 'PROPN'), ('de', 'de', 'ADP'), ('Bonvallet', 'Bonvallet', 'PROPN')] plastiques de Bonvallet, [('Guantes', 'guantes', 'NOUN')], abanicos y parfumes de [('Faguer', 'Faguer', 'PROPN'), ('Labollée', 'labollée', 'PROPN')] Labollée, Joyas de cabellos [('Lemnnier', 'lemnnier', 'PROPN')], [('Porcelaines', 'porcelaines', 'PROPN'), ('et', 'et', 'PROPN'), ('Cristaux', 'cristaux', 'PROPN'), ('Maison', 'maison', 'PROPN'), ('de', 'de', 'ADP'), ("l'Escalier", "l'Escalier", 'PROPN'), ('de', 'de', 'ADP'), ('Cristal', 'cristal', 'PROPN')] et Cristaux Maison de l'Escalier de Cristal
# [('Camisas', 'Camisas', 'PROPN'), ('Claudio', 'Claudio', 'PROPN')] Claudio, [('Hermanos', 'hermano', 'PROPN')]
# [('Nueva', 'nueva', 'PROPN'), ('Geografía', 'geografía', 'PROPN'), ('Sangansan', 'sangansan', 'PROPN')] Geografía Sangansan
# Casa particular de [('Huéspedes', 'Huéspedes', 'PROPN')]
# [('Casa', 'casa', 'PROPN'), ('Delacroix', 'delacroix', 'PROPN')] Delacroix
# [('Jules', 'jules', 'PROPN'), ('Bloch', 'bloch', 'PROPN')] Bloch, dentista
# [('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN')] Cristofle
# Casas recomendadas
# [('Tarifs', 'tarifs', 'PROPN'), ('des', 'd', 'PROPN'), ('insertions', 'insertions', 'PROPN')] des insertions
# [('Camisas', 'Camisas', 'PROPN'), ('Claudio', 'Claudio', 'PROPN')] Claudio, [('Hermanos', 'hermano', 'PROPN')]
# [('Nueva', 'nueva', 'PROPN'), ('Geografía', 'geografía', 'PROPN'), ('Sangansan', 'sangansan', 'PROPN')] Geografía Sangansan
# Casa particular de [('Huéspedes', 'Huéspedes', 'PROPN')]
# [('Casa', 'casa', 'PROPN'), ('Delacroix', 'delacroix', 'PROPN')] Delacroix
# [('Jules', 'jules', 'PROPN'), ('Bloch', 'bloch', 'PROPN')] Bloch, dentista
# [('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN')] Cristofle
# Casas recomendadas
# [('Tarifs', 'tarifs', 'PROPN'), ('des', 'd', 'PROPN'), ('insertions', 'insertions', 'PROPN')] des insertions
# [('Camisas', 'Camisas', 'PROPN'), ('Claudio', 'Claudio', 'PROPN')] Claudio, [('Hermanos', 'hermano', 'PROPN')]
# [('Nueva', 'nueva', 'PROPN'), ('Geografía', 'geografía', 'PROPN'), ('Sangansan', 'sangansan', 'PROPN')] Geografía Sangansan
# Casa particular de [('Huéspedes', 'Huéspedes', 'PROPN')]
# [('Casa', 'casa', 'PROPN'), ('Delacroix', 'delacroix', 'PROPN')] Delacroix
# [('Jules', 'jules', 'PROPN'), ('Bloch', 'bloch', 'PROPN')] Bloch, dentista
# [('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN')] Cristofle
# Casas recomendadas
# [('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN')] Cristofle
# [('Camisas', 'Camisas', 'PROPN'), ('Claudio', 'Claudio', 'PROPN')] Claudio, [('Hermanos', 'hermano', 'PROPN')]
# [('Nueva', 'nueva', 'PROPN'), ('Geografía', 'geografía', 'PROPN'), ('Sangansan', 'sangansan', 'PROPN')] Geografía Sangansan
# Casa particular de [('Huéspedes', 'Huéspedes', 'PROPN')]
# [('Casa', 'casa', 'PROPN'), ('Delacroix', 'delacroix', 'PROPN')] Delacroix
# [('Jules', 'jules', 'PROPN'), ('Bloch', 'bloch', 'PROPN')] Bloch, dentista
# Casas recomendadas
# Cintas y pasamanerías de la fábrica [('Sorré', 'sorré', 'PROPN'), ('Dehsle', 'dehsle', 'PROPN')] Dehsle, [('Corsets', 'Corsets', 'PROPN'), ('plastiques', 'plastiques', 'PROPN'), ('de', 'de', 'ADP'), ('Bonvallet', 'Bonvallet', 'PROPN')] plastiques de Bonvallet, [('Guantes', 'guantes', 'NOUN')], abanicos y parfumes de [('Faguer', 'Faguer', 'PROPN'), ('Labollée', 'labollée', 'PROPN')] Labollée, Joyas de cabellos [('Lemnnier', 'lemnnier', 'PROPN')], [('Porcelaines', 'porcelaines', 'PROPN'), ('et', 'et', 'PROPN'), ('Cristaux', 'cristaux', 'PROPN'), ('Maison', 'maison', 'PROPN'), ('de', 'de', 'ADP'), ("l'Escalier", "l'Escalier", 'PROPN'), ('de', 'de', 'ADP'), ('Cristal', 'cristal', 'PROPN')] et Cristaux Maison de l'Escalier de Cristal
# [('Camisas', 'Camisas', 'PROPN'), ('Claudio', 'Claudio', 'PROPN')] Claudio, [('Hermanos', 'hermano', 'PROPN')]
# [('Nueva', 'nueva', 'PROPN'), ('Geografía', 'geografía', 'PROPN'), ('Sangansan', 'sangansan', 'PROPN')] Geografía Sangansan
# Casa particular de [('Huéspedes', 'Huéspedes', 'PROPN')]
# [('Casa', 'casa', 'PROPN'), ('Delacroix', 'delacroix', 'PROPN')] Delacroix
# [('Jules', 'jules', 'PROPN'), ('Bloch', 'bloch', 'PROPN')] Bloch, dentista
# [('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN')] Cristofle
# [('Camisas', 'Camisas', 'PROPN'), ('Claudio', 'Claudio', 'PROPN')] Claudio, [('Hermanos', 'hermano', 'PROPN')]
# [('Nueva', 'nueva', 'PROPN'), ('Geografía', 'geografía', 'PROPN'), ('Sangansan', 'sangansan', 'PROPN')] Geografía Sangansan
# Casa particular de [('Huéspedes', 'Huéspedes', 'PROPN')]
# [('Casa', 'casa', 'PROPN'), ('Delacroix', 'delacroix', 'PROPN')] Delacroix
# [('Jules', 'jules', 'PROPN'), ('Bloch', 'bloch', 'PROPN')] Bloch, dentista
# [('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN')] Cristofle
# Casas recomendadas
# Cintas y pasamanerías de la fábrica [('Sorré', 'sorré', 'PROPN'), ('Dehsle', 'dehsle', 'PROPN')] Dehsle, [('Corsets', 'Corsets', 'PROPN'), ('plastiques', 'plastiques', 'PROPN'), ('de', 'de', 'ADP'), ('Bonvallet', 'Bonvallet', 'PROPN')] plastiques de Bonvallet, [('Guantes', 'guantes', 'NOUN')], abanicos y parfumes de [('Faguer', 'Faguer', 'PROPN'), ('Labollée', 'labollée', 'PROPN')] Labollée, Joyas de cabellos [('Lemnnier', 'lemnnier', 'PROPN')], [('Porcelaines', 'porcelaines', 'PROPN'), ('et', 'et', 'PROPN'), ('Cristaux', 'cristaux', 'PROPN'), ('Maison', 'maison', 'PROPN'), ('de', 'de', 'ADP'), ("l'Escalier", "l'Escalier", 'PROPN'), ('de', 'de', 'ADP'), ('Cristal', 'cristal', 'PROPN')] et Cristaux Maison de l'Escalier de Cristal
# [('Camisas', 'Camisas', 'PROPN'), ('Claudio', 'Claudio', 'PROPN')] Claudio, [('Hermanos', 'hermano', 'PROPN')]
# [('Nueva', 'nueva', 'PROPN'), ('Geografía', 'geografía', 'PROPN'), ('Sangansan', 'sangansan', 'PROPN')] Geografía Sangansan
# Casa particular de [('Huéspedes', 'Huéspedes', 'PROPN')]
# [('Casa', 'casa', 'PROPN'), ('Delacroix', 'delacroix', 'PROPN')] Delacroix
# [('Jules', 'jules', 'PROPN'), ('Bloch', 'bloch', 'PROPN')] Bloch, dentista
# [('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN')] Cristofle
# Cintas y pasamanerías de la fábrica [('Sorré', 'sorré', 'PROPN'), ('Dehsle', 'dehsle', 'PROPN')] Dehsle, [('Corsets', 'Corsets', 'PROPN'), ('plastiques', 'plastiques', 'PROPN'), ('de', 'de', 'ADP'), ('Bonvallet', 'Bonvallet', 'PROPN')] plastiques de Bonvallet, [('Guantes', 'guantes', 'NOUN')], abanicos y parfumes de [('Faguer', 'Faguer', 'PROPN'), ('Labollée', 'labollée', 'PROPN')] Labollée, Joyas de cabellos [('Lemnnier', 'lemnnier', 'PROPN')], [('Porcelaines', 'porcelaines', 'PROPN'), ('et', 'et', 'PROPN'), ('Cristaux', 'cristaux', 'PROPN'), ('Maison', 'maison', 'PROPN'), ('de', 'de', 'ADP'), ("l'Escalier", "l'Escalier", 'PROPN'), ('de', 'de', 'ADP'), ('Cristal', 'cristal', 'PROPN')] et Cristaux Maison de l'Escalier de Cristal
# [('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN')] Cristofle
# Obras de la señora [('doña', 'doña', 'NOUN'), ('Emilia', 'emilia', 'PROPN'), ('Serrano', 'Serrano', 'PROPN'), ('de', 'de', 'ADP'), ('Wilson', 'wilson', 'PROPN')] Emilia Serrano de Wilson
# [('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN')] Cristofle
# Obras de la señora [('doña', 'doña', 'NOUN'), ('Emilia', 'emilia', 'PROPN'), ('Serrano', 'Serrano', 'PROPN'), ('de', 'de', 'ADP'), ('Wilson', 'wilson', 'PROPN')] Emilia Serrano de Wilson
# [('Platería', 'Platería', 'PROPN'), ('Cristofle', 'cristofle', 'PROPN')] Cristofle
# Obras de la señora [('doña', 'doña', 'NOUN'), ('Emilia', 'emilia', 'PROPN'), ('Serrano', 'Serrano', 'PROPN'), ('de', 'de', 'ADP'), ('Wilson', 'wilson', 'PROPN')] Emilia Serrano de Wilson
# [('Modes', 'Modes', 'PROPN'), ('de', 'de', 'ADP'), ('Paris', 'parís', 'PROPN')] de Paris. [('Petit', 'petit', 'PROPN'), ('Courrier', 'courrier', 'PROPN'), ('des', 'des', 'ADP'), ('Dames', 'dames', 'PROPN')] Courrier des Dames
# El [('Eco', 'Eco', 'PROPN'), ('Hispano', 'hispano', 'PROPN'), ('Americano', 'americano', 'PROPN')] Hispano Americano
# Obras de la señora [('doña', 'doña', 'NOUN'), ('Emilia', 'emilia', 'PROPN'), ('Serrano', 'Serrano', 'PROPN'), ('de', 'de', 'ADP'), ('Wilson', 'wilson', 'PROPN')] Emilia Serrano de Wilson
# El [('Eco', 'Eco', 'PROPN'), ('Hispano', 'hispano', 'PROPN'), ('Americano', 'americano', 'PROPN')] Hispano Americano
# Anuncio
# Obras de la señora [('doña', 'doña', 'NOUN'), ('Emilia', 'emilia', 'PROPN'), ('Serrano', 'Serrano', 'PROPN'), ('de', 'de', 'ADP'), ('Wilson', 'wilson', 'PROPN')] Emilia Serrano de Wilson
# Explicación de la lámina de tapicería
# Explicación de la lámina de tapicería
# Explicación del figurín
# [('Moda', 'Moda', 'PROPN'), ('de', 'de', 'ADP'), ('Caballeros', 'Caballeros', 'PROPN')] de Caballeros
# Explicación del figurín 1º
# Explicación del figurín 2º
# Descripción del figurín: primer y segundo traje
# Descripción del figurín: traje de la novia y de la madre
# Explicación del figurín
# Descripción del figurín de baile
# Figurín de visita
# Explicación del figurín
# Explicación del figurín
# Explicación del figurín
# Explicación del figurín
# Explicación del figurín
# Explicación del figurín
# Explicación de los figurines. Primero
# Explicación de los figurines. [('Segundo', 'segundo', 'ADJ')]
# Revista de la moda
# [('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París
# Revista de la moda
# [('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París
# Revista de la moda
# [('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París
# Revista de la moda
# [('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París
# Revista de la moda
# [('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París
# Revista de la moda
# Revista de modas, salones y teatros
# Revista de modas, salones y teatros
# Revista de modas, salones y teatros
# Revista de modas, salones y teatros
# Revista de modas, salones y teatros
# Revista histórica del mes
# [('Revista', 'revista', 'PROPN'), ('Parisense', 'Parisense', 'PROPN')] Parisense
# Revista de modas
# Revista histórica del mes
# [('Revista', 'revista', 'PROPN'), ('Parisense', 'Parisense', 'PROPN')] Parisense
# Revista de modas
# Revista histórica del mes
# [('Revista', 'revista', 'PROPN'), ('Parisense', 'Parisense', 'PROPN')] Parisense
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('Parisense', 'Parisense', 'PROPN')] Parisense
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('Parisense', 'Parisense', 'PROPN')] Parisense
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN')] Parisiense
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN')] Parisiense
# Revista histórico política
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN')] Parisiense
# Revista histórico política
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN')] Parisiense
# Revista histórico política
# Revista de teatros
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'), ('Madrid', 'Madrid', 'PROPN')] de Madrid
# Revista de teatros
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN')] Parisiense
# [('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'), ('Madrid', 'Madrid', 'PROPN')] de Madrid
# Revista de teatros
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN')] Parisiense
# [('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'), ('Madrid', 'Madrid', 'PROPN')] de Madrid
# Crónica parisiense
# Revista de teatros
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN')] Parisiense
# [('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'), ('Madrid', 'Madrid', 'PROPN')] de Madrid
# Revista de teatros
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN')] Parisiense
# [('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'), ('Madrid', 'Madrid', 'PROPN')] de Madrid
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN')] Parisiense
# [('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'), ('Madrid', 'Madrid', 'PROPN')] de Madrid
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN')] Parisiense
# [('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'), ('Madrid', 'Madrid', 'PROPN')] de Madrid
# [('Revista', 'revista', 'PROPN'), ('Parisiense', 'parisiense', 'PROPN')] Parisiense
# [('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'), ('Madrid', 'Madrid', 'PROPN')] de Madrid
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'), ('Madrid', 'Madrid', 'PROPN')] de Madrid
# [('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París
# [('Teatros', 'Teatros', 'PROPN')]
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'), ('Madrid', 'Madrid', 'PROPN')] de Madrid
# [('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'), ('Madrid', 'Madrid', 'PROPN')] de Madrid
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'), ('Madrid', 'Madrid', 'PROPN')] de Madrid
# [('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'), ('Madrid', 'Madrid', 'PROPN')] de Madrid
# [('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'), ('Madrid', 'Madrid', 'PROPN')] de Madrid
# [('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'), ('Madrid', 'Madrid', 'PROPN')] de Madrid
# [('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París
# Revista de modas
# Revista de modas
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'), ('Madrid', 'Madrid', 'PROPN')] de Madrid
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'), ('Madrid', 'Madrid', 'PROPN')] de Madrid
# [('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París
# Revista de modas
# [('Revista', 'revista', 'PROPN'), ('de', 'de', 'ADP'), ('Madrid', 'Madrid', 'PROPN')] de Madrid
# [('Revista', 'revista', 'NOUN'), ('de', 'de', 'ADP'), ('París', 'París', 'PROPN')] de París
# Revista de modas
# Revista histórica del mes
# Revista histórica del mes
# Crónica parisiense
# Revista histórica del mes
# Revista histórica del mes
# Crónica parisiense
# Revista histórica del mes
# Revista histórica del mes
# Revista histórica del mes
# Revista histórica del mes
# Crónica parisiense
# Revista histórica del mes
# Revista histórica del mes
# Revista histórica del mes
# Revista histórica del mes
# Crónica parisiense
# Revista histórica del mes
# Revista histórica del mes
# Crónica parisiense
# Revista histórica del mes
# Crónica parisiense
# Crónica parisiense
# Crónica parisiense
# Crónica parisiense
